# %% [markdown]
# #Maestría en "Analítica de Datos"
# ---
# Nombre: Oscar Daniel Tunjano Rojas
#
# Código: 1070015630
#
# Fecha: 2025 Agosto 28
# ---
# Descripción: Web scraping Ministerio de Tecnologías de la información y las comunicaciones
#
# ---

# %% [markdown]
# # 0 Conenctar con Drive

# %%
# habilitamos drive de google desde colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1 Librerias

# %%
# !pip install requests
# !pip install beautifulsoup4
# !pip install pymongo
# !pip install lxml
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.10.5)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.15.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (5.4.0)

# %%
# ==============================
# 1. LIBRERÍAS
# ==============================
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urljoin
import os
from time import sleep

# %% [markdown]
# # 1.1 Conexión con Mongo

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.12/dist-packages (4.15.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from pymongo) (2.8.0)

# %% [markdown]
# # 1.2 Librerias especiales

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import json, os, time

# %% [markdown]
# # 2 Extracción de texto HTML

# %% [markdown]
# # 2.1 Cargar url

# %%
BASE_URL = 'https://normograma.mintic.gov.co/mintic/compilacion/compilacion_normativa_sector_tic.html'

# %% [markdown]
# # 2.2 Obtener pag hijas

# %%
def obtener_paginas_hijas(url):
    """Extrae todas las subpáginas hijas (.htm/.html) de la compilación MINTIC."""
    headers = {'User-Agent': 'Mozilla/5.0'}
    resp = requests.get(url, headers=headers)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.content, 'lxml')

    links = []
    for a in soup.find_all('a', href=True):
        href = a['href']
        full_url = urljoin(url, href)
        if full_url.endswith('.htm') or full_url.endswith('.html'):
            links.append(full_url)
    return list(set(links))

# %% [markdown]
# # 2.3 Extraer texto

# %%
def extraer_texto_norma(url):
    """Extrae título y cuerpo textual de una norma del portal MINTIC."""
    headers = {'User-Agent': 'Mozilla/5.0'}
    resp = requests.get(url, headers=headers, timeout=20)
    resp.raise_for_status()
    soup = BeautifulSoup(resp.content, 'lxml')

    # título
    titulo = soup.title.text.strip() if soup.title else "Sin título"

    # buscar texto normativo dentro del contenido principal
    texto_div = soup.find('div', class_='textoNorma') or soup.find('body')
    parrafos = [p.get_text(strip=True) for p in texto_div.find_all('p')] if texto_div else []
    texto = "\n".join(parrafos)

    return {'titulo': titulo, 'url': url, 'texto': texto}

# %% [markdown]
# # 2.4  Guardar JSON de cada norma

# %%
json_output_dir = '/content/drive/MyDrive/BIG DATA/web_scraping/mintic_normas_json'
os.makedirs(json_output_dir, exist_ok=True)

# Obtener todas las normas
paginas_hijas = obtener_paginas_hijas(BASE_URL)
print(f" Se encontraron {len(paginas_hijas)} páginas hijas.")

errores = []
for i, link in enumerate(paginas_hijas):
    try:
        print(f" Procesando norma {i+1}/{len(paginas_hijas)}: {link}")
        data = extraer_texto_norma(link)
        json_path = os.path.join(json_output_dir, f"norma_mintic_{i+1}.json")
        with open(json_path, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=4, ensure_ascii=False)
    except Exception as e:
        print(f" Error procesando {link}: {e}")
        errores.append(link)
    time.sleep(1)

print(f"\n Se generaron {len(paginas_hijas) - len(errores)} archivos JSON en {json_output_dir}")
if errores:
    print(f" No se pudieron procesar {len(errores)} normas.")
# Out:
#  Se encontraron 71 páginas hijas.
#  Procesando norma 1/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_dapr_departamento_administrativo_presidencia_republica.html
#  Procesando norma 2/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc
71: https://normograma.mintic.gov.co/mintic/compilacion/cndstd_ministerio_tecnologias_informacion_comunicaciones.html
#  Procesando norma 48/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_superintendencia_industria_comercio.html
#  Procesando norma 49/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_ministerio_culturas_artes_saberes.html
#  Procesando norma 50/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_agencia_nacional_defensa_juridica_estado.html
#  Procesando norma 51/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_contaduria_general_nacion.html
#  Procesando norma 52/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_dane_departamento_administrativo_nacional_estadistica.html
#  Procesando norma 53/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_dafp_departamento_administrativo_funcion_publica.html
#  Procesando norma 54/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_ministerio_tecnologias_informacion_comunicaciones.html
#  Procesando norma 55/71: https://normograma.mintic.gov.co/mintic/compilacion/herramientas_busqueda.html
#  Procesando norma 56/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_dian_direccion_impuestos_aduanas_nacionales.html
#  Procesando norma 57/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_ministerio_minas_energia.html
#  Procesando norma 58/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstd_ministerio_salud_proteccion_social.html
#  Procesando norma 59/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_icbf_instituto_colombiano_bienestar_familiar.html
#  Procesando norma 60/71: https://normograma.mintic.gov.co/mintic/index.html
#  Procesando norma 61/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_consejo_nacional_electoral.html
#  Procesando norma 62/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_contraloria_general_republica.html
#  Procesando norma 63/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstda_comision_comunidad_andina.html
#  Procesando norma 64/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstc_comision_nacional_servicio_civil.html
#  Procesando norma 65/71: https://normograma.mintic.gov.co/mintic/compilacion/cndsta_agencia_nacional_defensa_juridica_estado.html
#  Procesando norma 66/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_dafp_departamento_administrativo_funcion_publica.html
#  Procesando norma 67/71: https://normograma.mintic.gov.co/mintic/compilacion/compilacion_normativa_sector_tic.html
#  Procesando norma 68/71: https://normograma.mintic.gov.co/mintic/compilacion/cndsta_cntv_comision_nacional_television.html
#  Procesando norma 69/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstd_agencia_nacional_defensa_juridica_estado.html
#  Procesando norma 70/71: https://normograma.mintic.gov.co/mintic/compilacion/normativa_organizacional_mintic.html
#  Procesando norma 71/71: https://normograma.mintic.gov.co/mintic/compilacion/cndstr_ministerio_salud_proteccion_social.html
#
#  Se generaron 70 archivos JSON en /content/drive/MyDrive/BIG DATA/web_scraping/mintic_normas_json
#  No se pudieron procesar 1 normas.

# %% [markdown]
# # 3 Cargar JSON  a MONGODB

# %%
from pymongo import MongoClient
import os, json

# %%
#  Conexión a tu cluster de MongoDB Atlas
uri = "mongodb+srv://OscarDanTR:Trojas1973@cluster0.9ydjhbu.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
client = MongoClient(uri)

#  Crear base y colección
db_name = 'mintic'
collection_name = 'normatividad_html'
db = client[db_name]
collection = db[collection_name]
collection_fecha = db['fecha']

print(f" Conectado a MongoDB — Base: {db_name}, Colección: {collection_name}")
# Out:
#  Conectado a MongoDB — Base: mintic, Colección: normatividad_html

# %%
#  Ruta donde están tus JSON
json_output_dir = '/content/drive/MyDrive/BIG DATA/web_scraping/mintic_normas_json'
json_archivos = [f for f in os.listdir(json_output_dir) if f.endswith('.json')]

# %% [markdown]
# # 3.1 Cargar JSON

# %%
#  Cargar cada JSON
contar_cargados = 0
json_no_cargados = []

print(f" Cargando {len(json_archivos)} archivos JSON a MongoDB...")

for archivo in json_archivos:
    try:
        ruta = os.path.join(json_output_dir, archivo)
        with open(ruta, 'r', encoding='utf-8') as f:
            data = json.load(f)
        insert_result = collection.insert_one(data)
        if insert_result.inserted_id:
            contar_cargados += 1
            print(f" {archivo} cargado con éxito")
        else:
            json_no_cargados.append(archivo)
    except Exception as e:
        print(f" Error cargando {archivo}: {e}")
        json_no_cargados.append(archivo)

print(f"\n Se cargaron {contar_cargados} JSON correctamente a MongoDB.")
if json_no_cargados:
    print(f" No se pudieron cargar {len(json_no_cargados)} archivos.")
# Out:
#  Cargando 70 archivos JSON a MongoDB...
#  norma_mintic_1.json cargado con éxito
#  norma_mintic_2.json cargado con éxito
#  norma_mintic_3.json cargado con éxito
#  norma_mintic_4.json cargado con éxito
#  norma_mintic_5.json cargado con éxito
#  norma_mintic_6.json cargado con éxito
#  norma_mintic_7.json cargado con éxito
#  norma_mintic_8.json cargado con éxito
#  norma_mintic_9.json cargado con éxito
#  norma_mintic_10.json cargado con éxito
#  norma_mintic_11.json cargado con éxito
#  norma_mintic_12.json cargado con éxito
#  norma_mintic_13.json cargado con éxito
#  norma_mintic_14.json cargado con éxito
#  norma_mintic_16.json cargado con éxito
#  norma_mintic_17.json cargado con éxito
#  norma_mintic_18.json cargado con éxito
#  norma_mintic_19.json cargado con éxito
#  norma_mintic_20.json cargado con éxito
#  norma_mintic_21.json cargado con éxito
#  norma_mintic_22.json cargado con éxito
#  norma_mintic_23.json cargado con éxito
#  norma_mintic_24.json cargado con éxito
#  norma_mintic_25.json cargado con éxito
#  norma_mintic_26.json cargado con éxito
#  norma_mintic_27.json cargado con éxito
#  norma_mintic_28.json cargado con éxito
#  norma_mintic_29.json cargado con éxito
#  norma_mintic_30.json cargado con éxito
#  norma_mintic_31.json cargado con éxito
#  norma_mintic_32.json cargado con éxito
#  norma_mintic_33.json cargado con éxito
#  norma_mintic_34.json cargado con éxito
#  norma_mintic_35.json cargado con éxito
#  norma_mintic_36.json cargado con éxito
#  norma_mintic_37.json cargado con éxito
#  norma_mintic_38.json cargado con éxito
#  norma_mintic_39.json cargado con éxito
#  norma_mintic_40.json cargado con éxito
#  norma_mintic_41.json cargado con éxito
#  norma_mintic_42.json cargado con éxito
#  norma_mintic_43.json cargado con éxito
#  norma_mintic_44.json cargado con éxito
#  norma_mintic_45.json cargado con éxito
#  norma_mintic_46.json cargado con éxito
#  norma_mintic_47.json cargado con éxito
#  norma_mintic_48.json cargado con éxito
#  norma_mintic_49.json cargado con éxito
#  norma_mintic_50.json cargado con éxito
#  norma_mintic_51.json cargado con éxito
#  norma_mintic_52.json cargado con éxito
#  norma_mintic_53.json cargado con éxito
#  norma_mintic_54.json cargado con éxito
#  norma_mintic_55.json cargado con éxito
#  norma_mintic_56.json cargado con éxito
#  norma_mintic_57.json cargado con éxito
#  norma_mintic_58.json cargado con éxito
#  norma_mintic_59.json cargado con éxito
#  norma_mintic_60.json cargado con éxito
#  norma_mintic_61.json cargado con éxito
#  norma_mintic_62.json cargado con éxito
#  norma_mintic_63.json cargado con éxito
#  norma_mintic_64.json cargado con éxito
#  norma_mintic_65.json cargado con éxito
#  norma_mintic_66.json cargado con éxito
#  norma_mintic_67.json cargado con éxito
#  norma_mintic_68.json cargado con éxito
#  norma_mintic_69.json cargado con éxito
#  norma_mintic_70.json cargado con éxito
#  norma_mintic_71.json cargado con éxito
#
#  Se cargaron 70 JSON correctamente a MongoDB.
