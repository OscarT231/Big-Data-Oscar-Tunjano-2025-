# %% [markdown]
# #Maestría en "Analítica de Datos"
# ---
# Nombre: Oscar Daniel Tunjano Rojas
# Código:
# Fecha: 2025 Agosto 21
# ---
# Descripción: Este libro trabaja ejercicios Analítica ETL estadística descriptiva

# %% [markdown]
# #Cargar Librerias

# %%
import pandas as pd
import os
import numpy as np
import sqlite3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Cargar Información

# %%
file_path_csv ="/content/drive/MyDrive/BIG DATA/Población_Base_de_Datos_Única_de_Afiliados_BDUA_del_régimen_contributivo_20250828.csv"

# %%
try:
  df=pd.read_csv(file_path_csv)
except FileNotFoundError:
  print(f"El archivo {file_path_csv} no fue encontrado")
except Exception as e:
  print(f"Ocurrió un error al cargar el archivo: {e}")

# %%
pd.set_option('display.max_columns', None)
display(df.head())
# Out:
#       Género Grupo etario Código de la entidad        Nombre de la entidad  \
# 0  Masculino      45 a 50               ESSC24       COOSALUD EPS S.A. -CM
# 1   Femenino         > 75               EPS037              NUEVA EPS S.A.
# 2  Masculino      15 a 19               EPS037              NUEVA EPS S.A.
# 3   Femenino      15 a 19               EPS017        EPS FAMISANAR S.A.S.
# 4  Masculino      45 a 50               ESSC62  ASMET SALUD EPS S.A.S. -CM
#
#         Régimen Tipo de afiliado   Estado del afiliado  \
# 0  Contributivo        COTIZANTE                Activo
# 1  Contributivo        COTIZANTE                Activo
# 2  Contributivo        COTIZANTE  Protección Laboral C
# 3  Contributivo     BENEFICIARIO                Activo
# 4  Contributivo        COTIZANTE                Activo
#
#   Condición del beneficiario         Zona de Afiliación  Departamento  \
# 0                  NO APLICA  Urbana-Cabecera Municipal     MAGDALENA
# 1                  NO APLICA                     Urbana       BOLIVAR
# 2                  NO APLICA                     Urbana        ARAUCA
# 3                 ESTUDIANTE  Urbana-Cabecera Municipal  CUNDINAMARCA
# 4                  NO APLICA          Rural - Dispersal         CAUCA
#
#   Municipio tps_nvl_ssb_id                       Nivel del Sisbén  \
# 0   PIVIJAY            NaN                                    NaN
# 1   CALAMAR              1                   POBLACIÓN CON SISBEN
# 2    ARAUCA              N  VÍCTIMAS DEL CONFLICTO ARMADO INTERNO
# 3  MOSQUERA            NaN                                    NaN
# 4    SUAREZ              1                   POBLACIÓN CON SISBEN
#
#   Cantidad de registros
# 0                     6
# 1                     1
# 2                     1
# 3                     2
# 4                     1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656598 entries, 0 to 656597
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Género                      656598 non-null  object
#  1   Grupo etario                656598 non-null  object
#  2   Código de la entidad        656598 non-null  object
#  3   Nombre de la entidad        656598 non-null  object
#  4   Régimen                     656598 non-null  object
#  5   Tipo de afiliado            656598 non-null  object
#  6   Estado del afiliado         656598 non-null  object
#  7   Condición del beneficiario  656598 non-null  object
#  8   Zona de Afiliación          656598 non-null  object
#  9   Departamento                656598 non-null  object
#  10  Municipio                   656598 non-null  object
#  11  tps_nvl_ssb_id              369349 non-null  object
#  12  Nivel del Sisbén            369250 non-null  object
#  13  Cantidad de registros       656598 non-null  object
# dtypes: object(14)
# memory usage: 70.1+ MB

# %%
df.describe()
# Out:
#            Género Grupo etario Código de la entidad Nombre de la entidad  \
# count      656598       656598               656598               656598
# unique          2           12                   31                   31
# top     Masculino      19 a 45               EPS037       NUEVA EPS S.A.
# freq       332480       156230               278042               278042
#
#              Régimen Tipo de afiliado Estado del afiliado  \
# count         656598           656598              656598
# unique             1                3                   2
# top     Contributivo        COTIZANTE              Activo
# freq          656598           338182              613592
#
#        Condición del beneficiario Zona de Afiliación Departamento  \
# count                      656598             656598       656598
# unique                          3                  6           33
# top                     NO APLICA             Urbana    ANTIOQUIA
# freq                       629227             298692        83198
#
#           Municipio tps_nvl_ssb_id      Nivel del Sisbén Cantidad de registros
# count        656598         369349                369250                656598
# unique         1035              4                    19                  3034
# top     BOGOTA D.C.              1  POBLACIÓN CON SISBEN                     1
# freq           6251         143052                242862                285920

# %% [markdown]
# # ETL Transformación de los datos

# %%
# Convert 'Cantidad de registros' to numeric, coercing errors, then to integer
df['Cantidad de registros'] = pd.to_numeric(df['Cantidad de registros'], errors='coerce')
df['Cantidad de registros'] = df['Cantidad de registros'].fillna(0).astype(int)
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656598 entries, 0 to 656597
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Género                      656598 non-null  object
#  1   Grupo etario                656598 non-null  object
#  2   Código de la entidad        656598 non-null  object
#  3   Nombre de la entidad        656598 non-null  object
#  4   Régimen                     656598 non-null  object
#  5   Tipo de afiliado            656598 non-null  object
#  6   Estado del afiliado         656598 non-null  object
#  7   Condición del beneficiario  656598 non-null  object
#  8   Zona de Afiliación          656598 non-null  object
#  9   Departamento                656598 non-null  object
#  10  Municipio                   656598 non-null  object
#  11  tps_nvl_ssb_id              369349 non-null  object
#  12  Nivel del Sisbén            369250 non-null  object
#  13  Cantidad de registros       656598 non-null  int64
# dtypes: int64(1), object(13)
# memory usage: 70.1+ MB
# None

# %%
columnas_a_convertir =["Departamento","Municipio","Código de la entidad","Nombre de la entidad","Nivel del Sisbén"]
for columna in columnas_a_convertir:
  if columna in df.columns:
    df[columna]=df[columna].astype(str)

# %% [markdown]
# # Estadisticas desprictivas

# %%
df['Género'].value_counts()
# Out:
# Género
# Masculino    332480
# Femenino     324118
# Name: count, dtype: int64

# %%
df_eps= df.groupby('Nombre de la entidad')['Cantidad de registros'].sum()
#calcular porcentaje
total_registros = df['Cantidad de registros'].sum()
entidad_porcentaje = (df_eps / total_registros) * 100
resultado_df = pd.DataFrame({'Cantidad de Registros': df_eps, 'Porcentaje': entidad_porcentaje})
resultado_df = resultado_df.sort_values(by='Porcentaje', ascending=False)
display(resultado_df.head())
#display(df_eps.head())
# Out:
#                                                     Cantidad de Registros  \
# Nombre de la entidad
# NUEVA EPS S.A.                                                    3191312
# SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGI...                1026566
# ENTIDAD PROMOTORA DE SALUD SANITAS S.A.S.                          956870
# EPS SURAMERICANA S.A.                                              639941
# EPS FAMISANAR S.A.S.                                               619655
#
#                                                     Porcentaje
# Nombre de la entidad
# NUEVA EPS S.A.                                       37.240613
# SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGI...   11.979383
# ENTIDAD PROMOTORA DE SALUD SANITAS S.A.S.            11.166074
# EPS SURAMERICANA S.A.                                 7.467711
# EPS FAMISANAR S.A.S.                                  7.230986

# %% [markdown]
# # 5 Creación de BD SQLITE Y TABLAS

# %%
#crear carpeta sqlite y subcarpeta dbua
db_path="/content/drive/MyDrive/BIG DATA/DataSets_TMP/SQLITE/dbua.db"
db_dir =os.path.dirname(db_path)
if os.path.exists(db_dir):
  print(f"El directorio {db_dir} existe.")
else:
  os.makedirs(db_dir)
  print(f"El directorio {db_dir} fue creado.")
# Out:
# El directorio /content/drive/MyDrive/BIG DATA/DataSets_TMP/SQLITE fue creado.

# %%
try:
  conn=sqlite3.connect(db_path)
  cursor=conn.cursor()          #objeto que va a interactiar con la bd (dml/ddl)
  print("conectado")
except sqlite3.Error as e:
  print(f"Error al conectar a la base de datos: {e}")
# Out:
# conectado

# %% [markdown]
# # 5.1 Creando tablas papas (maestras)
# creación de bases de datos

# %%
cursor.execute('''
CREATE TABLE IF NOT EXISTS Departamento (
    Id_Departamento INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Departamento TEXT UNIQUE NOT NULL
)
''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS Sisben (
    Id_Sisben INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Sisben TEXT UNIQUE NOT NULL
)
''')

cursor.execute('''
CREATE TABLE IF NOT EXISTS Eps (
    codigo_Eps TEXT PRIMARY KEY,
    Nombre_Eps TEXT UNIQUE NOT NULL,
    regimen TEXT
)
''')

# %% [markdown]
# # 5.2  llenando las tablas maestras

# %%
#funcion para cargar datos en tablas maestras (departamento, sisben, eps)
def cargar_datos_a_tablas_maestras(df,db_path,columna, tabla_destino):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  valores_unicos =df[columna].unique()
  for valor in valores_unicos:
    if(pd.notna(valor)): #ignorar valores NaN
      try:
        cursor.execute(f"INSERT OR IGNORE INTO {tabla_destino} (Nombre_{tabla_destino.replace('_','')}) VALUES (?)", (valor,))
      except sqlite3.Error as e:
        print(f"Error al insertar en la tabla {tabla_destino}: {e}")
        pass
  conn.commit()
  conn.close()

# %%
cargar_datos_a_tablas_maestras(df,db_path,"Departamento","Departamento")
cargar_datos_a_tablas_maestras(df,db_path,"Nivel del Sisbén","Sisben")

# %%
def revisar_contenido_de_una_tabla(tabla_nombre, whereColumna='',whereValor='', limit=10, order_by_columna=None, order_asc=True):
  conn=sqlite3.connect(db_path)
  cursor=conn.cursor()
  cursor.execute("SELECT COUNT(*) FROM "+tabla_nombre)
  total_registros=cursor.fetchone()[0]
  print(f"Total de registros en la tabla {tabla_nombre}: {total_registros}")
  sql="SELECT * FROM "+tabla_nombre
  params = ()
  if len(whereColumna)>0:
    sql+=" WHERE "+whereColumna+"=?"
    params = (whereValor,)
  if(order_by_columna):
    orderbyTipo="ASC" if order_asc else "DESC"
    sql+=f" ORDER BY {order_by_columna} {orderbyTipo}"
  sql+=" LIMIT "+str(limit)
  print(sql)
  cursor.execute(sql, params)
  resultados=cursor.fetchall()
  for fila in resultados:
    print(fila)
  conn.close()

# %%
revisar_contenido_de_una_tabla("Departamento",'','',100,'Id_departamento')
# Out:
# Total de registros en la tabla Departamento: 33
# SELECT * FROM Departamento ORDER BY Id_departamento ASC LIMIT 100
# (1, 'MAGDALENA')
# (2, 'BOLIVAR')
# (3, 'ARAUCA')
# (4, 'CUNDINAMARCA')
# (5, 'CAUCA')
# (6, 'VALLE')
# (7, 'CALDAS')
# (8, 'CASANARE')
# (9, 'TOLIMA')
# (10, 'NORTE DE SANTANDER')
# (11, 'BOYACA')
# (12, 'CAQUETA')
# (13, 'ANTIOQUIA')
# (14, 'CESAR')
# (15, 'CORDOBA')
# (16, 'QUINDIO')
# (17, 'HUILA')
# (18, 'AMAZONAS')
# (19, 'META')
# (20, 'NARINO')
# (21, 'SUCRE')
# (22, 'SANTANDER')
# (23, 'RISARALDA')
# (24, 'ATLANTICO')
# (25, 'BOGOTA D.C.')
# (26, 'VAUPES')
# (27, 'LA GUAJIRA')
# (28, 'SAN ANDRES')
# (29, 'PUTUMAYO')
# (30, 'CHOCO')
# (31, 'VICHADA')
# (32, 'GUAINIA')
# (33, 'GUAVIARE')

# %%
revisar_contenido_de_una_tabla("Sisben",'','',100,'nombre_sisben')
# Out:
# Total de registros en la tabla Sisben: 20
# SELECT * FROM Sisben ORDER BY nombre_sisben ASC LIMIT 100
# (14, 'ADULTO MAYOR EN CENTROS DE PROTECCIÓN')
# (4, 'COMUNIDADES INDÍGENAS')
# (8, 'HABITANTE DE LA CALLE')
# (10, 'LOS VOLUNTARIOS ACREDITADOS Y ACTIVOS DE LA DEFENSA CIVIL COLOMBIANA CRUZ ROJA COLOMBIANA Y CUERPOS DE BOMBEROS')
# (20, 'MENORES DESVINCULADOS DEL CONFLICTO ARMADO BAJO LA PROTECCIÓN DEL ICBF.')
# (16, 'MIGRANTES COLOMBIANOS REPATRIADOS QUE HAN RETORNADO VOLUNTARIAMENTE AL PAÍS O HAN SIDO DEPORTADOS O EXPULSADOS DE TERRITORIO EXTRANJERO.')
# (7, 'NIÑOS-NIÑAS-ADOLESCENTES Y JÓVENES EN PROCESO ADMINISTRATIVO PARA EL RESTABLECIMIENTO DE SUS DERECHOS')
# (19, 'PERSONAS CON DISCAPACIDAD EN CENTROS DE PROTECCIÓN')
# (12, 'PERSONAS EN PRISIÓN DOMICILIARIA A CARGO DEL INPEC.')
# (17, 'PERSONAS QUE DEJEN DE SER MADRES COMUNITARIAS.')
# (2, 'POBLACIÓN CON SISBEN')
# (6, 'POBLACIÓN DESMOVILIZADA Y/O MIEMBROS DEL GRUPO ARMADO ILEGAL QUE CELEBREN ACUERDOS DE PAZ CON EL GOBIERNO NACIONAL')
# (18, 'POBLACIÓN INFANTIL VULNERABLE BAJO PROTECCIÓN DE INSTITUCIONES DIFERENTES AL ICBF')
# (11, 'POBLACIÓN PERTENECIENTE AL SISTEMA DE RESPONSABILIDAD PENAL PARA ADOLESCENTES A CARGO DEL ICBF')
# (9, 'POBLACIÓN RECLUSA A CARGO DE LA ENTIDAD TERRITORIAL')
# (13, 'PROGRAMA EN PROTECCIÓN A TESTIGOS')
# (5, 'RECIÉN NACIDO Y MENOR DE EDAD DE PADRES NO AFILIADOS')
# (15, 'RROM (GITANO)')
# (3, 'VÍCTIMAS DEL CONFLICTO ARMADO INTERNO')
# (1, 'nan')

# %% [markdown]
# #5.3 Crear tablas hijas
# municipio

# %%
cursor.execute('''
CREATE TABLE IF NOT EXISTS Municipio (
    Id_Municipio INTEGER PRIMARY KEY AUTOINCREMENT,
    Nombre_Municipio TEXT NOT NULL,
    Id_Departamento INTEGER,
    FOREIGN KEY (Id_Departamento) REFERENCES Departamento(Id_Departamento),
    UNIQUE (Nombre_Municipio, Id_Departamento)
)
''')
conn.commit()
conn.close()

# %%
#para cada municipio buscarle su departamento
def cargar_municipios(df,pd_path):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  tot_creados=0
  for index,row in df.iterrows():
    departamento  =row['Departamento']
    municipio     =row['Municipio']
    cursor.execute("SELECT Id_Departamento FROM Departamento WHERE Nombre_Departamento=?", (departamento,))
    departamento_id=cursor.fetchone()
    if departamento_id:
      departamento_id=departamento_id[0]
      try:
        cursor.execute("INSERT OR IGNORE INTO Municipio (Nombre_Municipio, Id_Departamento) VALUES (?, ?)", (municipio, departamento_id))
        tot_creados+=1
        print(f"creado {tot_creados} => {municipio} en el dpto {departamento} ")
      except sqlite3.sqlite3.IntegrityError:
        pass
    else:
      print(f"ERRROR: Departamento {departamento} para el municipio {municipio} no encontrado")
  conn.commit()
  conn.close()

# %%
cargar_municipios(df,db_path)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# creado 651599 => MARINILLA en el dpto ANTIOQUIA
# creado 651600 => SANTA MARTA en el dpto MAGDALENA
# creado 651601 => LA TEBAIDA en el dpto QUINDIO
# creado 651602 => PADILLA en el dpto CAUCA
# creado 651603 => SABANALARGA en el dpto ATLANTICO
# creado 651604 => QUIBDO en el dpto CHOCO
# creado 651605 => LA PAZ en el dpto SANTANDER
# creado 651606 => VALLE DE SAN JOSE en el dpto SANTANDER
# creado 651607 => TURBO en el dpto ANTIOQUIA
# creado 651608 => MANTA en el dpto CUNDINAMARCA
# creado 651609 => AGUACHICA en el dpto CESAR
# creado 651610 => COLON en el dpto PUTUMAYO
# creado 651611 => MERCADERES en el dpto CAUCA
# creado 651612 => CACERES en el dpto ANTIOQUIA
# creado 651613 => LA URIBE en el dpto META
# creado 651614 => CHIPAQUE en el dpto CUNDINAMARCA
# creado 651615 => SAN BERNARDO en el dpto NARINO
# creado 651616 => ESPINAL en el dpto TOLIMA
# creado 651617 => LIBANO en el dpto TOLIMA
# creado 651618 => MARSELLA en el dpto RISARALDA
# creado 651619 => SALAZAR en el dpto NORTE DE SANTANDER
# creado 651620 => SUCRE en el dpto SUCRE
# creado 651621 => TUNJA en el dpto BOYACA
# creado 651622 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 651623 => FLORIDA en el dpto VALLE
# creado 651624 => MEDELLIN en el dpto ANTIOQUIA
# creado 651625 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651626 => YUMBO en el dpto VALLE
# creado 651627 => RIONEGRO en el dpto ANTIOQUIA
# creado 651628 => YUMBO en el dpto VALLE
# creado 651629 => TAURAMENA en el dpto CASANARE
# creado 651630 => ZARZAL en el dpto VALLE
# creado 651631 => PAIPA en el dpto BOYACA
# creado 651632 => BETULIA en el dpto SANTANDER
# creado 651633 => CONCORDIA en el dpto MAGDALENA
# creado 651634 => MADRID en el dpto CUNDINAMARCA
# creado 651635 => PONEDERA en el dpto ATLANTICO
# creado 651636 => ARMENIA en el dpto QUINDIO
# creado 651637 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651638 => MESETAS en el dpto META
# creado 651639 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 651640 => SONSON en el dpto ANTIOQUIA
# creado 651641 => SUPIA en el dpto CALDAS
# creado 651642 => PALOCABILDO en el dpto TOLIMA
# creado 651643 => TURBACO en el dpto BOLIVAR
# creado 651644 => MONTERIA en el dpto CORDOBA
# creado 651645 => NEIVA en el dpto HUILA
# creado 651646 => SOTARA en el dpto CAUCA
# creado 651647 => PAUNA en el dpto BOYACA
# creado 651648 => BARRANQUILLA en el dpto ATLANTICO
# creado 651649 => YUMBO en el dpto VALLE
# creado 651650 => LLORO en el dpto CHOCO
# creado 651651 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 651652 => SAN VICENTE DEL CAGUAN en el dpto CAQUETA
# creado 651653 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 651654 => ILES en el dpto NARINO
# creado 651655 => LA UNION en el dpto ANTIOQUIA
# creado 651656 => NEIVA en el dpto HUILA
# creado 651657 => VITERBO en el dpto CALDAS
# creado 651658 => LA JAGUA DE IBIRICO en el dpto CESAR
# creado 651659 => SUPIA en el dpto CALDAS
# creado 651660 => LLORO en el dpto CHOCO
# creado 651661 => CARTAGO en el dpto VALLE
# creado 651662 => ANAPOIMA en el dpto CUNDINAMARCA
# creado 651663 => TIBU en el dpto NORTE DE SANTANDER
# creado 651664 => SAN JUAN DE ARAMA en el dpto META
# creado 651665 => SOLITA en el dpto CAQUETA
# creado 651666 => EL CERRITO en el dpto VALLE
# creado 651667 => CHIA en el dpto CUNDINAMARCA
# creado 651668 => SANTIAGO DE CALI en el dpto VALLE
# creado 651669 => VALLE DE SAN JOSE en el dpto SANTANDER
# creado 651670 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 651671 => SIBATE en el dpto CUNDINAMARCA
# creado 651672 => MIRITIÑPARANA en el dpto AMAZONAS
# creado 651673 => CAJICA en el dpto CUNDINAMARCA
# creado 651674 => GACHANCIPA en el dpto CUNDINAMARCA
# creado 651675 => URIBIA en el dpto LA GUAJIRA
# creado 651676 => PALMIRA en el dpto VALLE
# creado 651677 => ARMENIA en el dpto QUINDIO
# creado 651678 => BURITICA en el dpto ANTIOQUIA
# creado 651679 => TAMALAMEQUE en el dpto CESAR
# creado 651680 => CHIA en el dpto CUNDINAMARCA
# creado 651681 => PALMAR DE VARELA en el dpto ATLANTICO
# creado 651682 => TURBACO en el dpto BOLIVAR
# creado 651683 => ARAUCA en el dpto ARAUCA
# creado 651684 => SAN CAYETANO en el dpto NORTE DE SANTANDER
# creado 651685 => BELLO en el dpto ANTIOQUIA
# creado 651686 => SOGAMOSO en el dpto BOYACA
# creado 651687 => TOTA en el dpto BOYACA
# creado 651688 => LIBORINA en el dpto ANTIOQUIA
# creado 651689 => SACAMA en el dpto CASANARE
# creado 651690 => PUERTO TRIUNFO en el dpto ANTIOQUIA
# creado 651691 => MONIQUIRA en el dpto BOYACA
# creado 651692 => SALAMINA en el dpto CALDAS
# creado 651693 => SANTA ROSALIA en el dpto VICHADA
# creado 651694 => SAN ANTERO en el dpto CORDOBA
# creado 651695 => NEMOCON en el dpto CUNDINAMARCA
# creado 651696 => SAN ANDRES en el dpto ANTIOQUIA
# creado 651697 => MEDIO BAUDO en el dpto CHOCO
# creado 651698 => ITSMINA en el dpto CHOCO
# creado 651699 => COPACABANA en el dpto ANTIOQUIA
# creado 651700 => SANTIAGO DE CALI en el dpto VALLE
# creado 651701 => RIOSUCIO en el dpto CALDAS
# creado 651702 => GUAMAL en el dpto MAGDALENA
# creado 651703 => EL BANCO en el dpto MAGDALENA
# creado 651704 => LORICA en el dpto CORDOBA
# creado 651705 => LA URIBE en el dpto META
# creado 651706 => FUENTE DE ORO en el dpto META
# creado 651707 => SAN ESTANISLAO en el dpto BOLIVAR
# creado 651708 => PIENDAMO en el dpto CAUCA
# creado 651709 => EL CERRITO en el dpto VALLE
# creado 651710 => PAMPLONITA en el dpto NORTE DE SANTANDER
# creado 651711 => GUARNE en el dpto ANTIOQUIA
# creado 651712 => SAN ANDRES en el dpto SANTANDER
# creado 651713 => RIOBLANCO en el dpto TOLIMA
# creado 651714 => CARTAGENA en el dpto BOLIVAR
# creado 651715 => VIOTA en el dpto CUNDINAMARCA
# creado 651716 => LA CEJA en el dpto ANTIOQUIA
# creado 651717 => TAMALAMEQUE en el dpto CESAR
# creado 651718 => BUCARAMANGA en el dpto SANTANDER
# creado 651719 => LEJANIAS en el dpto META
# creado 651720 => MANI en el dpto CASANARE
# creado 651721 => PEREIRA en el dpto RISARALDA
# creado 651722 => LA UNION en el dpto SUCRE
# creado 651723 => VALLEDUPAR en el dpto CESAR
# creado 651724 => YALI en el dpto ANTIOQUIA
# creado 651725 => AGRADO en el dpto HUILA
# creado 651726 => FUENTE DE ORO en el dpto META
# creado 651727 => YOPAL en el dpto CASANARE
# creado 651728 => SAN JOSE DE URE en el dpto CORDOBA
# creado 651729 => SOLEDAD en el dpto ATLANTICO
# creado 651730 => GIGANTE en el dpto HUILA
# creado 651731 => CICUCO en el dpto BOLIVAR
# creado 651732 => DUITAMA en el dpto BOYACA
# creado 651733 => RAQUIRA en el dpto BOYACA
# creado 651734 => DAGUA en el dpto VALLE
# creado 651735 => BUCARAMANGA en el dpto SANTANDER
# creado 651736 => VILLANUEVA en el dpto BOLIVAR
# creado 651737 => FLORENCIA en el dpto CAQUETA
# creado 651738 => VILLAVICENCIO en el dpto META
# creado 651739 => MOCOA en el dpto PUTUMAYO
# creado 651740 => GIRON en el dpto SANTANDER
# creado 651741 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 651742 => POPAYAN en el dpto CAUCA
# creado 651743 => EL DORADO en el dpto META
# creado 651744 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 651745 => MANAURE BALCON DEL CESAR en el dpto CESAR
# creado 651746 => ESPINAL en el dpto TOLIMA
# creado 651747 => LA PALMA en el dpto CUNDINAMARCA
# creado 651748 => PUERTO SALGAR en el dpto CUNDINAMARCA
# creado 651749 => SANTIAGO DE CALI en el dpto VALLE
# creado 651750 => SINCELEJO en el dpto SUCRE
# creado 651751 => OVEJAS en el dpto SUCRE
# creado 651752 => RIO VIEJO en el dpto BOLIVAR
# creado 651753 => REMEDIOS en el dpto ANTIOQUIA
# creado 651754 => NATAGAIMA en el dpto TOLIMA
# creado 651755 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651756 => TABIO en el dpto CUNDINAMARCA
# creado 651757 => MANIZALES en el dpto CALDAS
# creado 651758 => JARDIN en el dpto ANTIOQUIA
# creado 651759 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 651760 => RETIRO en el dpto ANTIOQUIA
# creado 651761 => GACHALA en el dpto CUNDINAMARCA
# creado 651762 => CICUCO en el dpto BOLIVAR
# creado 651763 => COVEÑAS en el dpto SUCRE
# creado 651764 => BUCARAMANGA en el dpto SANTANDER
# creado 651765 => BARRANCAS en el dpto LA GUAJIRA
# creado 651766 => MARIQUITA en el dpto TOLIMA
# creado 651767 => LA PINTADA en el dpto ANTIOQUIA
# creado 651768 => MARULANDA en el dpto CALDAS
# creado 651769 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651770 => CAREPA en el dpto ANTIOQUIA
# creado 651771 => SASAIMA en el dpto CUNDINAMARCA
# creado 651772 => PUERTO CAICEDO en el dpto PUTUMAYO
# creado 651773 => SANTIAGO en el dpto PUTUMAYO
# creado 651774 => ENVIGADO en el dpto ANTIOQUIA
# creado 651775 => PACHO en el dpto CUNDINAMARCA
# creado 651776 => LA PAZ  ROBLES en el dpto CESAR
# creado 651777 => LA TEBAIDA en el dpto QUINDIO
# creado 651778 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 651779 => VALLEDUPAR en el dpto CESAR
# creado 651780 => CAQUEZA en el dpto CUNDINAMARCA
# creado 651781 => RIOHACHA en el dpto LA GUAJIRA
# creado 651782 => GUACAMAYAS en el dpto BOYACA
# creado 651783 => MADRID en el dpto CUNDINAMARCA
# creado 651784 => RIOHACHA en el dpto LA GUAJIRA
# creado 651785 => SAN AGUSTIN en el dpto HUILA
# creado 651786 => VILLANUEVA en el dpto CASANARE
# creado 651787 => LORICA en el dpto CORDOBA
# creado 651788 => LOS PATIOS en el dpto NORTE DE SANTANDER
# creado 651789 => PIEDRAS en el dpto TOLIMA
# creado 651790 => LLORO en el dpto CHOCO
# creado 651791 => CHIPAQUE en el dpto CUNDINAMARCA
# creado 651792 => TUMACO en el dpto NARINO
# creado 651793 => MONIQUIRA en el dpto BOYACA
# creado 651794 => CASTILLA LA NUEVA en el dpto META
# creado 651795 => GUAMAL en el dpto MAGDALENA
# creado 651796 => CHINAVITA en el dpto BOYACA
# creado 651797 => CAÑASGORDAS en el dpto ANTIOQUIA
# creado 651798 => VILLANUEVA en el dpto SANTANDER
# creado 651799 => BUENAVENTURA en el dpto VALLE
# creado 651800 => ACACIAS en el dpto META
# creado 651801 => ARMENIA en el dpto QUINDIO
# creado 651802 => SANTIAGO DE CALI en el dpto VALLE
# creado 651803 => LEBRIJA en el dpto SANTANDER
# creado 651804 => TABIO en el dpto CUNDINAMARCA
# creado 651805 => CAUCASIA en el dpto ANTIOQUIA
# creado 651806 => MALAMBO en el dpto ATLANTICO
# creado 651807 => SAN GIL en el dpto SANTANDER
# creado 651808 => BARRANCABERMEJA en el dpto SANTANDER
# creado 651809 => SILVANIA en el dpto CUNDINAMARCA
# creado 651810 => CHIPAQUE en el dpto CUNDINAMARCA
# creado 651811 => YOPAL en el dpto CASANARE
# creado 651812 => DUITAMA en el dpto BOYACA
# creado 651813 => MANI en el dpto CASANARE
# creado 651814 => ZARZAL en el dpto VALLE
# creado 651815 => COLON en el dpto PUTUMAYO
# creado 651816 => GRANADA en el dpto META
# creado 651817 => SOACHA en el dpto CUNDINAMARCA
# creado 651818 => ACACIAS en el dpto META
# creado 651819 => TUQUERRES en el dpto NARINO
# creado 651820 => CURUMANI en el dpto CESAR
# creado 651821 => LA CALERA en el dpto CUNDINAMARCA
# creado 651822 => ONZAGA en el dpto SANTANDER
# creado 651823 => SANTIAGO DE CALI en el dpto VALLE
# creado 651824 => MANIZALES en el dpto CALDAS
# creado 651825 => ARAUCA en el dpto ARAUCA
# creado 651826 => PUERTO ASIS en el dpto PUTUMAYO
# creado 651827 => BELLO en el dpto ANTIOQUIA
# creado 651828 => MADRID en el dpto CUNDINAMARCA
# creado 651829 => SEVILLA en el dpto VALLE
# creado 651830 => OROCUE en el dpto CASANARE
# creado 651831 => PALOCABILDO en el dpto TOLIMA
# creado 651832 => SAN ANDRES DE SOTAVENTO en el dpto CORDOBA
# creado 651833 => AMALFI en el dpto ANTIOQUIA
# creado 651834 => ARAUQUITA en el dpto ARAUCA
# creado 651835 => GACHANTIVA en el dpto BOYACA
# creado 651836 => BELALCAZAR en el dpto CALDAS
# creado 651837 => SANTA MARTA en el dpto MAGDALENA
# creado 651838 => QUIBDO en el dpto CHOCO
# creado 651839 => SAN RAFAEL en el dpto ANTIOQUIA
# creado 651840 => TIERRALTA en el dpto CORDOBA
# creado 651841 => MIRAFLORES en el dpto BOYACA
# creado 651842 => EL RETEN en el dpto MAGDALENA
# creado 651843 => VILLA RICA en el dpto CAUCA
# creado 651844 => EL CARMEN en el dpto CHOCO
# creado 651845 => AGUAZUL en el dpto CASANARE
# creado 651846 => GALAPA en el dpto ATLANTICO
# creado 651847 => BUENAVISTA en el dpto QUINDIO
# creado 651848 => JARDIN en el dpto ANTIOQUIA
# creado 651849 => TULUA en el dpto VALLE
# creado 651850 => CAJICA en el dpto CUNDINAMARCA
# creado 651851 => BUGALAGRANDE en el dpto VALLE
# creado 651852 => MONTERIA en el dpto CORDOBA
# creado 651853 => SUAN en el dpto ATLANTICO
# creado 651854 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651855 => COPACABANA en el dpto ANTIOQUIA
# creado 651856 => SILVANIA en el dpto CUNDINAMARCA
# creado 651857 => PENSILVANIA en el dpto CALDAS
# creado 651858 => YONDO en el dpto ANTIOQUIA
# creado 651859 => GUACARI en el dpto VALLE
# creado 651860 => FACATATIVA en el dpto CUNDINAMARCA
# creado 651861 => MARIQUITA en el dpto TOLIMA
# creado 651862 => SAN AGUSTIN en el dpto HUILA
# creado 651863 => SAN ONOFRE en el dpto SUCRE
# creado 651864 => SUAN en el dpto ATLANTICO
# creado 651865 => SAN VICENTE DEL CAGUAN en el dpto CAQUETA
# creado 651866 => EL COPEY en el dpto CESAR
# creado 651867 => CHIQUINQUIRA en el dpto BOYACA
# creado 651868 => JESUS MARIA en el dpto SANTANDER
# creado 651869 => CALOTO en el dpto CAUCA
# creado 651870 => TOCANCIPA en el dpto CUNDINAMARCA
# creado 651871 => EL MOLINO en el dpto LA GUAJIRA
# creado 651872 => ROLDANILLO en el dpto VALLE
# creado 651873 => LA CUMBRE en el dpto VALLE
# creado 651874 => LA VIRGINIA en el dpto RISARALDA
# creado 651875 => SANTA MARIA en el dpto BOYACA
# creado 651876 => MOSQUERA en el dpto NARINO
# creado 651877 => ASTREA en el dpto CESAR
# creado 651878 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 651879 => SONSON en el dpto ANTIOQUIA
# creado 651880 => TOCA en el dpto BOYACA
# creado 651881 => GUACHUCAL en el dpto NARINO
# creado 651882 => SANTA MARTA en el dpto MAGDALENA
# creado 651883 => MONTELIBANO en el dpto CORDOBA
# creado 651884 => CIMITARRA en el dpto SANTANDER
# creado 651885 => VALLE DE SAN JOSE en el dpto SANTANDER
# creado 651886 => TOCA en el dpto BOYACA
# creado 651887 => PALOCABILDO en el dpto TOLIMA
# creado 651888 => FLORENCIA en el dpto CAQUETA
# creado 651889 => AYAPEL en el dpto CORDOBA
# creado 651890 => DAGUA en el dpto VALLE
# creado 651891 => CAJICA en el dpto CUNDINAMARCA
# creado 651892 => ARBOLETES en el dpto ANTIOQUIA
# creado 651893 => SAN RAFAEL en el dpto ANTIOQUIA
# creado 651894 => RIVERA en el dpto HUILA
# creado 651895 => MUTATA en el dpto ANTIOQUIA
# creado 651896 => MEDIO ATRATO en el dpto CHOCO
# creado 651897 => NARIÑO en el dpto CUNDINAMARCA
# creado 651898 => VALLE DEL GUAMUEZ en el dpto PUTUMAYO
# creado 651899 => MARGARITA en el dpto BOLIVAR
# creado 651900 => OBANDO en el dpto VALLE
# creado 651901 => TAMINANGO en el dpto NARINO
# creado 651902 => SESQUILE en el dpto CUNDINAMARCA
# creado 651903 => CHINACOTA en el dpto NORTE DE SANTANDER
# creado 651904 => BARANOA en el dpto ATLANTICO
# creado 651905 => PITALITO en el dpto HUILA
# creado 651906 => ALTOS DEL ROSARIO en el dpto BOLIVAR
# creado 651907 => MONGUI en el dpto BOYACA
# creado 651908 => SONSON en el dpto ANTIOQUIA
# creado 651909 => ORTEGA en el dpto TOLIMA
# creado 651910 => PUEBLO RICO en el dpto RISARALDA
# creado 651911 => SANTA ANA en el dpto MAGDALENA
# creado 651912 => SANTO TOMAS en el dpto ATLANTICO
# creado 651913 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 651914 => VILLAMARIA en el dpto CALDAS
# creado 651915 => FUNZA en el dpto CUNDINAMARCA
# creado 651916 => SAN ANDRES DE SOTAVENTO en el dpto CORDOBA
# creado 651917 => SALENTO en el dpto QUINDIO
# creado 651918 => SESQUILE en el dpto CUNDINAMARCA
# creado 651919 => LA GLORIA en el dpto CESAR
# creado 651920 => FLORIDABLANCA en el dpto SANTANDER
# creado 651921 => LETICIA en el dpto AMAZONAS
# creado 651922 => GRANADA en el dpto META
# creado 651923 => MANIZALES en el dpto CALDAS
# creado 651924 => MONTENEGRO en el dpto QUINDIO
# creado 651925 => BELLO en el dpto ANTIOQUIA
# creado 651926 => MONTECRISTO en el dpto BOLIVAR
# creado 651927 => PUERTO ASIS en el dpto PUTUMAYO
# creado 651928 => VILLAVICENCIO en el dpto META
# creado 651929 => PUERRES en el dpto NARINO
# creado 651930 => DAGUA en el dpto VALLE
# creado 651931 => RICAURTE en el dpto NARINO
# creado 651932 => TULUA en el dpto VALLE
# creado 651933 => SOACHA en el dpto CUNDINAMARCA
# creado 651934 => PUEBLO RICO en el dpto RISARALDA
# creado 651935 => SEVILLA en el dpto VALLE
# creado 651936 => MEDELLIN en el dpto ANTIOQUIA
# creado 651937 => VILLAMARIA en el dpto CALDAS
# creado 651938 => TURBACO en el dpto BOLIVAR
# creado 651939 => PUERTO LLERAS en el dpto META
# creado 651940 => SAN FRANCISCO en el dpto ANTIOQUIA
# creado 651941 => SAN ANTERO en el dpto CORDOBA
# creado 651942 => PARATEBUENO en el dpto CUNDINAMARCA
# creado 651943 => MOMPOS en el dpto BOLIVAR
# creado 651944 => CACERES en el dpto ANTIOQUIA
# creado 651945 => MAGANGUE en el dpto BOLIVAR
# creado 651946 => URIBIA en el dpto LA GUAJIRA
# creado 651947 => LA VEGA en el dpto CAUCA
# creado 651948 => PACORA en el dpto CALDAS
# creado 651949 => SUPATA en el dpto CUNDINAMARCA
# creado 651950 => DOLORES en el dpto TOLIMA
# creado 651951 => BOAVITA en el dpto BOYACA
# creado 651952 => NECHI en el dpto ANTIOQUIA
# creado 651953 => LA VICTORIA en el dpto VALLE
# creado 651954 => GUARNE en el dpto ANTIOQUIA
# creado 651955 => SUSA en el dpto CUNDINAMARCA
# creado 651956 => CORINTO en el dpto CAUCA
# creado 651957 => LA VIRGINIA en el dpto RISARALDA
# creado 651958 => TUNJA en el dpto BOYACA
# creado 651959 => PACORA en el dpto CALDAS
# creado 651960 => ARMENIA en el dpto QUINDIO
# creado 651961 => SUTATAUSA en el dpto CUNDINAMARCA
# creado 651962 => SANTA ROSA DE OSOS en el dpto ANTIOQUIA
# creado 651963 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 651964 => MANZANARES en el dpto CALDAS
# creado 651965 => TIERRALTA en el dpto CORDOBA
# creado 651966 => SUAZA en el dpto HUILA
# creado 651967 => CUMARAL en el dpto META
# creado 651968 => YUMBO en el dpto VALLE
# creado 651969 => TITIRIBI en el dpto ANTIOQUIA
# creado 651970 => GUACA en el dpto SANTANDER
# creado 651971 => OIBA en el dpto SANTANDER
# creado 651972 => LA DORADA en el dpto CALDAS
# creado 651973 => TUNJA en el dpto BOYACA
# creado 651974 => PALERMO en el dpto HUILA
# creado 651975 => CAJIBIO en el dpto CAUCA
# creado 651976 => QUIBDO en el dpto CHOCO
# creado 651977 => TUNJA en el dpto BOYACA
# creado 651978 => PARAMO en el dpto SANTANDER
# creado 651979 => ARACATACA en el dpto MAGDALENA
# creado 651980 => ABREGO en el dpto NORTE DE SANTANDER
# creado 651981 => GUARNE en el dpto ANTIOQUIA
# creado 651982 => SAN ROQUE en el dpto ANTIOQUIA
# creado 651983 => RIO QUITO en el dpto CHOCO
# creado 651984 => SANTA MARTA en el dpto MAGDALENA
# creado 651985 => BETANIA en el dpto ANTIOQUIA
# creado 651986 => ARIGUANI en el dpto MAGDALENA
# creado 651987 => CALARCA en el dpto QUINDIO
# creado 651988 => EL DONCELLO en el dpto CAQUETA
# creado 651989 => S.ANTONIO TEQUENDAMA en el dpto CUNDINAMARCA
# creado 651990 => SUESCA en el dpto CUNDINAMARCA
# creado 651991 => AMBALEMA en el dpto TOLIMA
# creado 651992 => FUNDACION en el dpto MAGDALENA
# creado 651993 => LA SIERRA en el dpto CAUCA
# creado 651994 => SAN ANTONIO en el dpto TOLIMA
# creado 651995 => SANTA ROSALIA en el dpto VICHADA
# creado 651996 => TENA en el dpto CUNDINAMARCA
# creado 651997 => SANTA MARIA en el dpto BOYACA
# creado 651998 => MEDINA en el dpto CUNDINAMARCA
# creado 651999 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 652000 => VALLEDUPAR en el dpto CESAR
# creado 652001 => SOACHA en el dpto CUNDINAMARCA
# creado 652002 => NECOCLI en el dpto ANTIOQUIA
# creado 652003 => GRANADA en el dpto ANTIOQUIA
# creado 652004 => PLANETA RICA en el dpto CORDOBA
# creado 652005 => ARAUQUITA en el dpto ARAUCA
# creado 652006 => SAN PEDRO en el dpto VALLE
# creado 652007 => CASTILLA LA NUEVA en el dpto META
# creado 652008 => SANTO DOMINGO en el dpto ANTIOQUIA
# creado 652009 => SOLEDAD en el dpto ATLANTICO
# creado 652010 => HONDA en el dpto TOLIMA
# creado 652011 => TUNJA en el dpto BOYACA
# creado 652012 => FLORIDA en el dpto VALLE
# creado 652013 => OVEJAS en el dpto SUCRE
# creado 652014 => TOCAIMA en el dpto CUNDINAMARCA
# creado 652015 => GRANADA en el dpto ANTIOQUIA
# creado 652016 => JAMUNDI en el dpto VALLE
# creado 652017 => ZARZAL en el dpto VALLE
# creado 652018 => GUATICA en el dpto RISARALDA
# creado 652019 => PAZ DE ARIPORO en el dpto CASANARE
# creado 652020 => SAN PEDRO en el dpto ANTIOQUIA
# creado 652021 => BARRANCAS en el dpto LA GUAJIRA
# creado 652022 => EL BAGRE en el dpto ANTIOQUIA
# creado 652023 => PALMIRA en el dpto VALLE
# creado 652024 => BOLIVAR en el dpto CAUCA
# creado 652025 => SAN ONOFRE en el dpto SUCRE
# creado 652026 => GOMEZ PLATA en el dpto ANTIOQUIA
# creado 652027 => PUPIALES en el dpto NARINO
# creado 652028 => YAGUARA en el dpto HUILA
# creado 652029 => LOS PATIOS en el dpto NORTE DE SANTANDER
# creado 652030 => RIOHACHA en el dpto LA GUAJIRA
# creado 652031 => APARTADO en el dpto ANTIOQUIA
# creado 652032 => BELEN DE LOS ANDAQUIES en el dpto CAQUETA
# creado 652033 => SANTA MARTA en el dpto MAGDALENA
# creado 652034 => GUAMAL en el dpto META
# creado 652035 => PIENDAMO en el dpto CAUCA
# creado 652036 => FLORIDABLANCA en el dpto SANTANDER
# creado 652037 => SAN MARTIN en el dpto META
# creado 652038 => FONSECA en el dpto LA GUAJIRA
# creado 652039 => LA UNION en el dpto NARINO
# creado 652040 => CAUCASIA en el dpto ANTIOQUIA
# creado 652041 => VENTAQUEMADA en el dpto BOYACA
# creado 652042 => GIRON en el dpto SANTANDER
# creado 652043 => CAICEDONIA en el dpto VALLE
# creado 652044 => BUGALAGRANDE en el dpto VALLE
# creado 652045 => RIONEGRO en el dpto ANTIOQUIA
# creado 652046 => EL PASO en el dpto CESAR
# creado 652047 => MARMATO en el dpto CALDAS
# creado 652048 => LA DORADA en el dpto CALDAS
# creado 652049 => RIOSUCIO en el dpto CALDAS
# creado 652050 => VILLAVICENCIO en el dpto META
# creado 652051 => BUCARAMANGA en el dpto SANTANDER
# creado 652052 => CHIA en el dpto CUNDINAMARCA
# creado 652053 => CALIMA en el dpto VALLE
# creado 652054 => CHIGORODO en el dpto ANTIOQUIA
# creado 652055 => SABANALARGA en el dpto ATLANTICO
# creado 652056 => MONTERIA en el dpto CORDOBA
# creado 652057 => EL RETEN en el dpto MAGDALENA
# creado 652058 => PUERTO LIBERTADOR en el dpto CORDOBA
# creado 652059 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652060 => LENGUAZAQUE en el dpto CUNDINAMARCA
# creado 652061 => LA JAGUA DEL PILAR en el dpto LA GUAJIRA
# creado 652062 => PEQUE en el dpto ANTIOQUIA
# creado 652063 => LANDAZURI en el dpto SANTANDER
# creado 652064 => HONDA en el dpto TOLIMA
# creado 652065 => CALDAS en el dpto ANTIOQUIA
# creado 652066 => CIMITARRA en el dpto SANTANDER
# creado 652067 => LA URIBE en el dpto META
# creado 652068 => HATILLO DE LOBA en el dpto BOLIVAR
# creado 652069 => SABANA DE TORRES en el dpto SANTANDER
# creado 652070 => BUENAVENTURA en el dpto VALLE
# creado 652071 => NEIVA en el dpto HUILA
# creado 652072 => CAJICA en el dpto CUNDINAMARCA
# creado 652073 => PASTO en el dpto NARINO
# creado 652074 => LA JAGUA DE IBIRICO en el dpto CESAR
# creado 652075 => SINCELEJO en el dpto SUCRE
# creado 652076 => SIACHOQUE en el dpto BOYACA
# creado 652077 => AMBALEMA en el dpto TOLIMA
# creado 652078 => YARUMAL en el dpto ANTIOQUIA
# creado 652079 => ARAUQUITA en el dpto ARAUCA
# creado 652080 => NARIÑO en el dpto ANTIOQUIA
# creado 652081 => CALARCA en el dpto QUINDIO
# creado 652082 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 652083 => PUEBLO NUEVO en el dpto CORDOBA
# creado 652084 => JUAN DE ACOSTA en el dpto ATLANTICO
# creado 652085 => EL COPEY en el dpto CESAR
# creado 652086 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 652087 => IQUIRA en el dpto HUILA
# creado 652088 => LA PRIMAVERA en el dpto VICHADA
# creado 652089 => CAÑASGORDAS en el dpto ANTIOQUIA
# creado 652090 => CUMARAL en el dpto META
# creado 652091 => SANTA MARTA en el dpto MAGDALENA
# creado 652092 => PASTO en el dpto NARINO
# creado 652093 => SAN ONOFRE en el dpto SUCRE
# creado 652094 => RISARALDA en el dpto CALDAS
# creado 652095 => RICAURTE en el dpto CUNDINAMARCA
# creado 652096 => YUMBO en el dpto VALLE
# creado 652097 => SOACHA en el dpto CUNDINAMARCA
# creado 652098 => TENJO en el dpto CUNDINAMARCA
# creado 652099 => QUIBDO en el dpto CHOCO
# creado 652100 => YOPAL en el dpto CASANARE
# creado 652101 => CHINACOTA en el dpto NORTE DE SANTANDER
# creado 652102 => LA MACARENA en el dpto META
# creado 652103 => LA APARTADA en el dpto CORDOBA
# creado 652104 => SANTIAGO DE CALI en el dpto VALLE
# creado 652105 => SANTIAGO DE CALI en el dpto VALLE
# creado 652106 => USIACURI en el dpto ATLANTICO
# creado 652107 => RESTREPO en el dpto META
# creado 652108 => SUAREZ en el dpto CAUCA
# creado 652109 => MAICAO en el dpto LA GUAJIRA
# creado 652110 => TRUJILLO en el dpto VALLE
# creado 652111 => MAICAO en el dpto LA GUAJIRA
# creado 652112 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 652113 => TURBO en el dpto ANTIOQUIA
# creado 652114 => IBAGUE en el dpto TOLIMA
# creado 652115 => EL GUAMO en el dpto BOLIVAR
# creado 652116 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 652117 => JAMUNDI en el dpto VALLE
# creado 652118 => CHAPARRAL en el dpto TOLIMA
# creado 652119 => MADRID en el dpto CUNDINAMARCA
# creado 652120 => PLANADAS en el dpto TOLIMA
# creado 652121 => IBAGUE en el dpto TOLIMA
# creado 652122 => YALI en el dpto ANTIOQUIA
# creado 652123 => VENTAQUEMADA en el dpto BOYACA
# creado 652124 => VILLAMARIA en el dpto CALDAS
# creado 652125 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652126 => GUACHETA en el dpto CUNDINAMARCA
# creado 652127 => MAHATES en el dpto BOLIVAR
# creado 652128 => SAN FRANCISCO en el dpto CUNDINAMARCA
# creado 652129 => SANTO TOMAS en el dpto ATLANTICO
# creado 652130 => CONDOTO en el dpto CHOCO
# creado 652131 => TOGUI en el dpto BOYACA
# creado 652132 => VALDIVIA en el dpto ANTIOQUIA
# creado 652133 => LA DORADA en el dpto CALDAS
# creado 652134 => RAQUIRA en el dpto BOYACA
# creado 652135 => FUNZA en el dpto CUNDINAMARCA
# creado 652136 => PUERTO BERRIO en el dpto ANTIOQUIA
# creado 652137 => TOLUVIEJO en el dpto SUCRE
# creado 652138 => SOMONDOCO en el dpto BOYACA
# creado 652139 => LA ESPERANZA en el dpto NORTE DE SANTANDER
# creado 652140 => MACEO en el dpto ANTIOQUIA
# creado 652141 => YUMBO en el dpto VALLE
# creado 652142 => CUCAITA en el dpto BOYACA
# creado 652143 => EL COCUY en el dpto BOYACA
# creado 652144 => CONCEPCION en el dpto ANTIOQUIA
# creado 652145 => SOLEDAD en el dpto ATLANTICO
# creado 652146 => SURATA en el dpto SANTANDER
# creado 652147 => EL RETEN en el dpto MAGDALENA
# creado 652148 => SANTA BARBARA en el dpto NARINO
# creado 652149 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 652150 => CALIFORNIA en el dpto SANTANDER
# creado 652151 => SUESCA en el dpto CUNDINAMARCA
# creado 652152 => SAN MIGUEL en el dpto SANTANDER
# creado 652153 => BUGA en el dpto VALLE
# creado 652154 => CUCUNUBA en el dpto CUNDINAMARCA
# creado 652155 => CAMPOALEGRE en el dpto HUILA
# creado 652156 => SANTA MARTA en el dpto MAGDALENA
# creado 652157 => TURMEQUE en el dpto BOYACA
# creado 652158 => CAUCASIA en el dpto ANTIOQUIA
# creado 652159 => GAMARRA en el dpto CESAR
# creado 652160 => EL PLAYON en el dpto SANTANDER
# creado 652161 => TAUSA en el dpto CUNDINAMARCA
# creado 652162 => CIENAGA en el dpto MAGDALENA
# creado 652163 => PRADERA en el dpto VALLE
# creado 652164 => ROLDANILLO en el dpto VALLE
# creado 652165 => MUTISCUA en el dpto NORTE DE SANTANDER
# creado 652166 => ARACATACA en el dpto MAGDALENA
# creado 652167 => SAN ROQUE en el dpto ANTIOQUIA
# creado 652168 => PUERTO RICO en el dpto META
# creado 652169 => TIQUISIO en el dpto BOLIVAR
# creado 652170 => YUMBO en el dpto VALLE
# creado 652171 => PAEZ en el dpto BOYACA
# creado 652172 => TOCANCIPA en el dpto CUNDINAMARCA
# creado 652173 => QUIBDO en el dpto CHOCO
# creado 652174 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 652175 => PENSILVANIA en el dpto CALDAS
# creado 652176 => BUCARAMANGA en el dpto SANTANDER
# creado 652177 => TARQUI en el dpto HUILA
# creado 652178 => HOBO en el dpto HUILA
# creado 652179 => BETULIA en el dpto ANTIOQUIA
# creado 652180 => TENJO en el dpto CUNDINAMARCA
# creado 652181 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652182 => MONIQUIRA en el dpto BOYACA
# creado 652183 => RIOSUCIO en el dpto CHOCO
# creado 652184 => BARBOSA en el dpto ANTIOQUIA
# creado 652185 => UBATE en el dpto CUNDINAMARCA
# creado 652186 => JARDIN en el dpto ANTIOQUIA
# creado 652187 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 652188 => RESTREPO en el dpto META
# creado 652189 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652190 => CERETE en el dpto CORDOBA
# creado 652191 => SAMANIEGO en el dpto NARINO
# creado 652192 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 652193 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 652194 => SAN LORENZO en el dpto NARINO
# creado 652195 => FLANDES en el dpto TOLIMA
# creado 652196 => VILLAVICENCIO en el dpto META
# creado 652197 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652198 => GACHANCIPA en el dpto CUNDINAMARCA
# creado 652199 => MELGAR en el dpto TOLIMA
# creado 652200 => VILLANUEVA en el dpto SANTANDER
# creado 652201 => MARIQUITA en el dpto TOLIMA
# creado 652202 => JAMUNDI en el dpto VALLE
# creado 652203 => BUSBANZA en el dpto BOYACA
# creado 652204 => CIENAGA en el dpto MAGDALENA
# creado 652205 => UTICA en el dpto CUNDINAMARCA
# creado 652206 => BUCARAMANGA en el dpto SANTANDER
# creado 652207 => AMAGA en el dpto ANTIOQUIA
# creado 652208 => YUMBO en el dpto VALLE
# creado 652209 => YOTOCO en el dpto VALLE
# creado 652210 => NOBSA en el dpto BOYACA
# creado 652211 => CARTAGENA en el dpto BOLIVAR
# creado 652212 => ZARZAL en el dpto VALLE
# creado 652213 => MAHATES en el dpto BOLIVAR
# creado 652214 => GUAMO en el dpto TOLIMA
# creado 652215 => SAN GIL en el dpto SANTANDER
# creado 652216 => FACATATIVA en el dpto CUNDINAMARCA
# creado 652217 => BUCARAMANGA en el dpto SANTANDER
# creado 652218 => SAN JUAN DEL CESAR en el dpto LA GUAJIRA
# creado 652219 => SACHICA en el dpto BOYACA
# creado 652220 => MEDELLIN en el dpto ANTIOQUIA
# creado 652221 => SORACA en el dpto BOYACA
# creado 652222 => SILOS en el dpto NORTE DE SANTANDER
# creado 652223 => ARMENIA en el dpto QUINDIO
# creado 652224 => RIOSUCIO en el dpto CHOCO
# creado 652225 => IBAGUE en el dpto TOLIMA
# creado 652226 => GIRON en el dpto SANTANDER
# creado 652227 => COGUA en el dpto CUNDINAMARCA
# creado 652228 => SINCE en el dpto SUCRE
# creado 652229 => LA VEGA en el dpto CUNDINAMARCA
# creado 652230 => OCAÑA en el dpto NORTE DE SANTANDER
# creado 652231 => RIOSUCIO en el dpto CHOCO
# creado 652232 => CHAPARRAL en el dpto TOLIMA
# creado 652233 => TABIO en el dpto CUNDINAMARCA
# creado 652234 => MONIQUIRA en el dpto BOYACA
# creado 652235 => SOGAMOSO en el dpto BOYACA
# creado 652236 => ARMENIA en el dpto QUINDIO
# creado 652237 => BELEN DE UMBRIA en el dpto RISARALDA
# creado 652238 => LLORO en el dpto CHOCO
# creado 652239 => GALERAS en el dpto SUCRE
# creado 652240 => ROLDANILLO en el dpto VALLE
# creado 652241 => CANDELARIA en el dpto VALLE
# creado 652242 => ARMENIA en el dpto QUINDIO
# creado 652243 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652244 => TITIRIBI en el dpto ANTIOQUIA
# creado 652245 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 652246 => TABIO en el dpto CUNDINAMARCA
# creado 652247 => LA UNION en el dpto VALLE
# creado 652248 => ARMENIA en el dpto QUINDIO
# creado 652249 => SARAVENA en el dpto ARAUCA
# creado 652250 => SINCE en el dpto SUCRE
# creado 652251 => CAMPO DE LA CRUZ en el dpto ATLANTICO
# creado 652252 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652253 => CANDELARIA en el dpto VALLE
# creado 652254 => GIRON en el dpto SANTANDER
# creado 652255 => TIBANA en el dpto BOYACA
# creado 652256 => TIERRALTA en el dpto CORDOBA
# creado 652257 => SANTA ROSA DEL SUR en el dpto BOLIVAR
# creado 652258 => PUERTO COLOMBIA en el dpto ATLANTICO
# creado 652259 => LINARES en el dpto NARINO
# creado 652260 => ENVIGADO en el dpto ANTIOQUIA
# creado 652261 => SOLEDAD en el dpto ATLANTICO
# creado 652262 => RIONEGRO en el dpto ANTIOQUIA
# creado 652263 => IBAGUE en el dpto TOLIMA
# creado 652264 => MONIQUIRA en el dpto BOYACA
# creado 652265 => SAN PELAYO en el dpto CORDOBA
# creado 652266 => MOCOA en el dpto PUTUMAYO
# creado 652267 => PAZ DE ARIPORO en el dpto CASANARE
# creado 652268 => COMBITA en el dpto BOYACA
# creado 652269 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 652270 => URUMITA en el dpto LA GUAJIRA
# creado 652271 => SAN PEDRO DE URABA en el dpto ANTIOQUIA
# creado 652272 => INIRIDA en el dpto GUAINIA
# creado 652273 => VALLEDUPAR en el dpto CESAR
# creado 652274 => SAMANA en el dpto CALDAS
# creado 652275 => LA CEJA en el dpto ANTIOQUIA
# creado 652276 => IBAGUE en el dpto TOLIMA
# creado 652277 => BELLO en el dpto ANTIOQUIA
# creado 652278 => TIERRALTA en el dpto CORDOBA
# creado 652279 => SANTA ROSA DE OSOS en el dpto ANTIOQUIA
# creado 652280 => SORACA en el dpto BOYACA
# creado 652281 => GUATEQUE en el dpto BOYACA
# creado 652282 => YARUMAL en el dpto ANTIOQUIA
# creado 652283 => PUERTO RICO en el dpto CAQUETA
# creado 652284 => AMAGA en el dpto ANTIOQUIA
# creado 652285 => MARULANDA en el dpto CALDAS
# creado 652286 => SITIONUEVO en el dpto MAGDALENA
# creado 652287 => RESTREPO en el dpto META
# creado 652288 => MEDELLIN en el dpto ANTIOQUIA
# creado 652289 => TURBO en el dpto ANTIOQUIA
# creado 652290 => ARMENIA en el dpto QUINDIO
# creado 652291 => GALAPA en el dpto ATLANTICO
# creado 652292 => TUNJA en el dpto BOYACA
# creado 652293 => SEVILLA en el dpto VALLE
# creado 652294 => BECERRIL en el dpto CESAR
# creado 652295 => SUSA en el dpto CUNDINAMARCA
# creado 652296 => TIQUISIO en el dpto BOLIVAR
# creado 652297 => TELLO en el dpto HUILA
# creado 652298 => GUADALUPE en el dpto SANTANDER
# creado 652299 => SAN CARLOS en el dpto CORDOBA
# creado 652300 => VICTORIA en el dpto CALDAS
# creado 652301 => CARACOLI en el dpto ANTIOQUIA
# creado 652302 => FLORIDABLANCA en el dpto SANTANDER
# creado 652303 => BUGA en el dpto VALLE
# creado 652304 => CONDOTO en el dpto CHOCO
# creado 652305 => SUPIA en el dpto CALDAS
# creado 652306 => SAN FRANCISCO en el dpto CUNDINAMARCA
# creado 652307 => CARMEN DE APICALA en el dpto TOLIMA
# creado 652308 => MONTELIBANO en el dpto CORDOBA
# creado 652309 => LOURDES en el dpto NORTE DE SANTANDER
# creado 652310 => BARRANQUILLA en el dpto ATLANTICO
# creado 652311 => SANTANA en el dpto BOYACA
# creado 652312 => IBAGUE en el dpto TOLIMA
# creado 652313 => VISTA HERMOSA en el dpto META
# creado 652314 => EL ROSAL en el dpto CUNDINAMARCA
# creado 652315 => PALERMO en el dpto HUILA
# creado 652316 => ARMENIA en el dpto QUINDIO
# creado 652317 => BARRANCABERMEJA en el dpto SANTANDER
# creado 652318 => TORO en el dpto VALLE
# creado 652319 => PLANETA RICA en el dpto CORDOBA
# creado 652320 => ITUANGO en el dpto ANTIOQUIA
# creado 652321 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 652322 => ITSMINA en el dpto CHOCO
# creado 652323 => URAMITA en el dpto ANTIOQUIA
# creado 652324 => FREDONIA en el dpto ANTIOQUIA
# creado 652325 => MAJAGUAL en el dpto SUCRE
# creado 652326 => TRUJILLO en el dpto VALLE
# creado 652327 => RESTREPO en el dpto META
# creado 652328 => ICONONZO en el dpto TOLIMA
# creado 652329 => VISTA HERMOSA en el dpto META
# creado 652330 => PELAYA en el dpto CESAR
# creado 652331 => CASTILLA LA NUEVA en el dpto META
# creado 652332 => BARANOA en el dpto ATLANTICO
# creado 652333 => ITUANGO en el dpto ANTIOQUIA
# creado 652334 => SEGOVIA en el dpto ANTIOQUIA
# creado 652335 => MESETAS en el dpto META
# creado 652336 => SALDAÑA en el dpto TOLIMA
# creado 652337 => FLORIDA en el dpto VALLE
# creado 652338 => CHIRIGUANA en el dpto CESAR
# creado 652339 => PUERTO COLOMBIA en el dpto GUAINIA
# creado 652340 => URIBIA en el dpto LA GUAJIRA
# creado 652341 => SAN MARCOS en el dpto SUCRE
# creado 652342 => NEIRA en el dpto CALDAS
# creado 652343 => IBAGUE en el dpto TOLIMA
# creado 652344 => TASCO en el dpto BOYACA
# creado 652345 => IBAGUE en el dpto TOLIMA
# creado 652346 => MONTERIA en el dpto CORDOBA
# creado 652347 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 652348 => EL RETEN en el dpto MAGDALENA
# creado 652349 => GIRARDOT en el dpto CUNDINAMARCA
# creado 652350 => POPAYAN en el dpto CAUCA
# creado 652351 => URIBIA en el dpto LA GUAJIRA
# creado 652352 => SILVANIA en el dpto CUNDINAMARCA
# creado 652353 => GACHANCIPA en el dpto CUNDINAMARCA
# creado 652354 => VENADILLO en el dpto TOLIMA
# creado 652355 => SOACHA en el dpto CUNDINAMARCA
# creado 652356 => LA UNION en el dpto ANTIOQUIA
# creado 652357 => RAQUIRA en el dpto BOYACA
# creado 652358 => PUEBLO RICO en el dpto RISARALDA
# creado 652359 => GIGANTE en el dpto HUILA
# creado 652360 => IBAGUE en el dpto TOLIMA
# creado 652361 => TAURAMENA en el dpto CASANARE
# creado 652362 => GIRARDOT en el dpto CUNDINAMARCA
# creado 652363 => SIBATE en el dpto CUNDINAMARCA
# creado 652364 => LA JAGUA DE IBIRICO en el dpto CESAR
# creado 652365 => REPELON en el dpto ATLANTICO
# creado 652366 => LA CRUZ en el dpto NARINO
# creado 652367 => SAN FRANCISCO en el dpto CUNDINAMARCA
# creado 652368 => GIRON en el dpto SANTANDER
# creado 652369 => SABANALARGA en el dpto ATLANTICO
# creado 652370 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652371 => PUERTO LLERAS en el dpto META
# creado 652372 => INIRIDA en el dpto GUAINIA
# creado 652373 => URRAO en el dpto ANTIOQUIA
# creado 652374 => FLORESTA en el dpto BOYACA
# creado 652375 => S.ANTONIO TEQUENDAMA en el dpto CUNDINAMARCA
# creado 652376 => CHACHAGUI en el dpto NARINO
# creado 652377 => COLOMBIA en el dpto HUILA
# creado 652378 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 652379 => MARULANDA en el dpto CALDAS
# creado 652380 => YONDO en el dpto ANTIOQUIA
# creado 652381 => BARRANQUILLA en el dpto ATLANTICO
# creado 652382 => SEGOVIA en el dpto ANTIOQUIA
# creado 652383 => FILANDIA en el dpto QUINDIO
# creado 652384 => BELEN DE UMBRIA en el dpto RISARALDA
# creado 652385 => MONITOS en el dpto CORDOBA
# creado 652386 => CARTAGENA en el dpto BOLIVAR
# creado 652387 => RICAURTE en el dpto NARINO
# creado 652388 => VILLANUEVA en el dpto LA GUAJIRA
# creado 652389 => PRADERA en el dpto VALLE
# creado 652390 => ARANZAZU en el dpto CALDAS
# creado 652391 => DON MATIAS en el dpto ANTIOQUIA
# creado 652392 => CONCORDIA en el dpto ANTIOQUIA
# creado 652393 => CLEMENCIA en el dpto BOLIVAR
# creado 652394 => CHIQUINQUIRA en el dpto BOYACA
# creado 652395 => CARTAGO en el dpto VALLE
# creado 652396 => SANTIAGO DE CALI en el dpto VALLE
# creado 652397 => PENSILVANIA en el dpto CALDAS
# creado 652398 => EL AGUILA en el dpto VALLE
# creado 652399 => SALAMINA en el dpto CALDAS
# creado 652400 => PLANETA RICA en el dpto CORDOBA
# creado 652401 => CORDOBA en el dpto QUINDIO
# creado 652402 => ARAUCA en el dpto ARAUCA
# creado 652403 => JAMUNDI en el dpto VALLE
# creado 652404 => SAN PABLO en el dpto BOLIVAR
# creado 652405 => PUERTO BOYACA en el dpto BOYACA
# creado 652406 => MANI en el dpto CASANARE
# creado 652407 => ARMENIA en el dpto QUINDIO
# creado 652408 => BARBOSA en el dpto SANTANDER
# creado 652409 => DISTRACCION en el dpto LA GUAJIRA
# creado 652410 => PUENTE NACIONAL en el dpto SANTANDER
# creado 652411 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 652412 => MOTAVITA en el dpto BOYACA
# creado 652413 => MEDINA en el dpto CUNDINAMARCA
# creado 652414 => CHIRIGUANA en el dpto CESAR
# creado 652415 => VALLEDUPAR en el dpto CESAR
# creado 652416 => GUASCA en el dpto CUNDINAMARCA
# creado 652417 => DUITAMA en el dpto BOYACA
# creado 652418 => BARICHARA en el dpto SANTANDER
# creado 652419 => EL CHARCO en el dpto NARINO
# creado 652420 => ALGECIRAS en el dpto HUILA
# creado 652421 => RESTREPO en el dpto META
# creado 652422 => SINCE en el dpto SUCRE
# creado 652423 => PAZ DE ARIPORO en el dpto CASANARE
# creado 652424 => SAMACA en el dpto BOYACA
# creado 652425 => VENECIA en el dpto ANTIOQUIA
# creado 652426 => BUCARAMANGA en el dpto SANTANDER
# creado 652427 => GUACHUCAL en el dpto NARINO
# creado 652428 => CANTON DE SAN PABLO en el dpto CHOCO
# creado 652429 => MAICAO en el dpto LA GUAJIRA
# creado 652430 => MACEO en el dpto ANTIOQUIA
# creado 652431 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 652432 => CHINCHINA en el dpto CALDAS
# creado 652433 => PALERMO en el dpto HUILA
# creado 652434 => FONSECA en el dpto LA GUAJIRA
# creado 652435 => TUNJA en el dpto BOYACA
# creado 652436 => MITU en el dpto VAUPES
# creado 652437 => LA PAZ  ROBLES en el dpto CESAR
# creado 652438 => EL BAGRE en el dpto ANTIOQUIA
# creado 652439 => APARTADO en el dpto ANTIOQUIA
# creado 652440 => PLANETA RICA en el dpto CORDOBA
# creado 652441 => PIEDECUESTA en el dpto SANTANDER
# creado 652442 => ACACIAS en el dpto META
# creado 652443 => CHIA en el dpto CUNDINAMARCA
# creado 652444 => ARENAL en el dpto BOLIVAR
# creado 652445 => SAN ALBERTO en el dpto CESAR
# creado 652446 => LIBANO en el dpto TOLIMA
# creado 652447 => CHAPARRAL en el dpto TOLIMA
# creado 652448 => YUMBO en el dpto VALLE
# creado 652449 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652450 => MONTENEGRO en el dpto QUINDIO
# creado 652451 => GIRARDOTA en el dpto ANTIOQUIA
# creado 652452 => HELICONIA en el dpto ANTIOQUIA
# creado 652453 => EL COLEGIO en el dpto CUNDINAMARCA
# creado 652454 => GACHANCIPA en el dpto CUNDINAMARCA
# creado 652455 => QUIBDO en el dpto CHOCO
# creado 652456 => BARBOSA en el dpto SANTANDER
# creado 652457 => EL TAMBO en el dpto NARINO
# creado 652458 => MARINILLA en el dpto ANTIOQUIA
# creado 652459 => TURBACO en el dpto BOLIVAR
# creado 652460 => GUASCA en el dpto CUNDINAMARCA
# creado 652461 => CARMEN DEL DARIEN en el dpto CHOCO
# creado 652462 => GINEBRA en el dpto VALLE
# creado 652463 => INZA en el dpto CAUCA
# creado 652464 => MEDELLIN en el dpto ANTIOQUIA
# creado 652465 => SAN FERNANDO en el dpto BOLIVAR
# creado 652466 => TUBARA en el dpto ATLANTICO
# creado 652467 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652468 => TOGUI en el dpto BOYACA
# creado 652469 => MARINILLA en el dpto ANTIOQUIA
# creado 652470 => SARAVENA en el dpto ARAUCA
# creado 652471 => BUENAVISTA en el dpto CORDOBA
# creado 652472 => UNE en el dpto CUNDINAMARCA
# creado 652473 => LURUACO en el dpto ATLANTICO
# creado 652474 => TURBO en el dpto ANTIOQUIA
# creado 652475 => UNE en el dpto CUNDINAMARCA
# creado 652476 => BETULIA en el dpto ANTIOQUIA
# creado 652477 => MEDELLIN en el dpto ANTIOQUIA
# creado 652478 => GUALMATAN en el dpto NARINO
# creado 652479 => JAMUNDI en el dpto VALLE
# creado 652480 => PLANETA RICA en el dpto CORDOBA
# creado 652481 => SEVILLA en el dpto VALLE
# creado 652482 => CHACHAGUI en el dpto NARINO
# creado 652483 => HATO COROZAL en el dpto CASANARE
# creado 652484 => MARIA LA BAJA en el dpto BOLIVAR
# creado 652485 => VIOTA en el dpto CUNDINAMARCA
# creado 652486 => SOPETRAN en el dpto ANTIOQUIA
# creado 652487 => SANTIAGO DE CALI en el dpto VALLE
# creado 652488 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652489 => ZAMBRANO en el dpto BOLIVAR
# creado 652490 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 652491 => MADRID en el dpto CUNDINAMARCA
# creado 652492 => ACHI en el dpto BOLIVAR
# creado 652493 => GUAMAL en el dpto META
# creado 652494 => SOGAMOSO en el dpto BOYACA
# creado 652495 => MARINILLA en el dpto ANTIOQUIA
# creado 652496 => ARAUCA en el dpto ARAUCA
# creado 652497 => RIONEGRO en el dpto ANTIOQUIA
# creado 652498 => BARRANCABERMEJA en el dpto SANTANDER
# creado 652499 => PUERTO NARE en el dpto ANTIOQUIA
# creado 652500 => ROVIRA en el dpto TOLIMA
# creado 652501 => VALDIVIA en el dpto ANTIOQUIA
# creado 652502 => LA TEBAIDA en el dpto QUINDIO
# creado 652503 => CARTAGENA en el dpto BOLIVAR
# creado 652504 => QUIMBAYA en el dpto QUINDIO
# creado 652505 => NEIVA en el dpto HUILA
# creado 652506 => SIMITI en el dpto BOLIVAR
# creado 652507 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652508 => RESTREPO en el dpto VALLE
# creado 652509 => MANAURE BALCON DEL CESAR en el dpto CESAR
# creado 652510 => MARIA LA BAJA en el dpto BOLIVAR
# creado 652511 => FORTUL en el dpto ARAUCA
# creado 652512 => CANALETE en el dpto CORDOBA
# creado 652513 => VALLEDUPAR en el dpto CESAR
# creado 652514 => VALDIVIA en el dpto ANTIOQUIA
# creado 652515 => TUQUERRES en el dpto NARINO
# creado 652516 => SANTA ANA en el dpto MAGDALENA
# creado 652517 => SINCELEJO en el dpto SUCRE
# creado 652518 => LA CALERA en el dpto CUNDINAMARCA
# creado 652519 => SIBATE en el dpto CUNDINAMARCA
# creado 652520 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652521 => CERINZA en el dpto BOYACA
# creado 652522 => MIRAFLORES en el dpto BOYACA
# creado 652523 => MADRID en el dpto CUNDINAMARCA
# creado 652524 => SOGAMOSO en el dpto BOYACA
# creado 652525 => BARRANQUILLA en el dpto ATLANTICO
# creado 652526 => BUENAVENTURA en el dpto VALLE
# creado 652527 => PEREIRA en el dpto RISARALDA
# creado 652528 => NATAGAIMA en el dpto TOLIMA
# creado 652529 => GUADUAS en el dpto CUNDINAMARCA
# creado 652530 => BUGA en el dpto VALLE
# creado 652531 => PASTO en el dpto NARINO
# creado 652532 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 652533 => VILLAPINZON en el dpto CUNDINAMARCA
# creado 652534 => SEVILLA en el dpto VALLE
# creado 652535 => PAZ DE ARIPORO en el dpto CASANARE
# creado 652536 => MARINILLA en el dpto ANTIOQUIA
# creado 652537 => ARMENIA en el dpto QUINDIO
# creado 652538 => VIJES en el dpto VALLE
# creado 652539 => MEDELLIN en el dpto ANTIOQUIA
# creado 652540 => SAHAGUN en el dpto CORDOBA
# creado 652541 => ACANDI en el dpto CHOCO
# creado 652542 => VALLEDUPAR en el dpto CESAR
# creado 652543 => SAN ANTERO en el dpto CORDOBA
# creado 652544 => LOS PALMITOS en el dpto SUCRE
# creado 652545 => ITAGUI en el dpto ANTIOQUIA
# creado 652546 => ROSAS en el dpto CAUCA
# creado 652547 => CASABIANCA en el dpto TOLIMA
# creado 652548 => HONDA en el dpto TOLIMA
# creado 652549 => UBATE en el dpto CUNDINAMARCA
# creado 652550 => TOTORO en el dpto CAUCA
# creado 652551 => GUACHETA en el dpto CUNDINAMARCA
# creado 652552 => MANIZALES en el dpto CALDAS
# creado 652553 => OIBA en el dpto SANTANDER
# creado 652554 => CAUCASIA en el dpto ANTIOQUIA
# creado 652555 => GOMEZ PLATA en el dpto ANTIOQUIA
# creado 652556 => CIENAGA en el dpto MAGDALENA
# creado 652557 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 652558 => CARTAGENA en el dpto BOLIVAR
# creado 652559 => UNION PANAMERICANA en el dpto CHOCO
# creado 652560 => EL LITORAL DEL SAN JUAN en el dpto CHOCO
# creado 652561 => ABREGO en el dpto NORTE DE SANTANDER
# creado 652562 => YOPAL en el dpto CASANARE
# creado 652563 => SABANAGRANDE en el dpto ATLANTICO
# creado 652564 => TOLUVIEJO en el dpto SUCRE
# creado 652565 => VILLA RICA en el dpto CAUCA
# creado 652566 => PAIPA en el dpto BOYACA
# creado 652567 => DUITAMA en el dpto BOYACA
# creado 652568 => FUNZA en el dpto CUNDINAMARCA
# creado 652569 => CAICEDO en el dpto ANTIOQUIA
# creado 652570 => TAUSA en el dpto CUNDINAMARCA
# creado 652571 => MARMATO en el dpto CALDAS
# creado 652572 => SEVILLA en el dpto VALLE
# creado 652573 => CARTAGENA en el dpto BOLIVAR
# creado 652574 => SINCELEJO en el dpto SUCRE
# creado 652575 => SAMANIEGO en el dpto NARINO
# creado 652576 => URIBIA en el dpto LA GUAJIRA
# creado 652577 => CARTAGO en el dpto VALLE
# creado 652578 => FRONTINO en el dpto ANTIOQUIA
# creado 652579 => ALCALA en el dpto VALLE
# creado 652580 => BUCARAMANGA en el dpto SANTANDER
# creado 652581 => LA VEGA en el dpto CAUCA
# creado 652582 => NUEVA GRANADA en el dpto MAGDALENA
# creado 652583 => CABUYARO en el dpto META
# creado 652584 => RIONEGRO en el dpto SANTANDER
# creado 652585 => ANDES en el dpto ANTIOQUIA
# creado 652586 => EL CHARCO en el dpto NARINO
# creado 652587 => SILVANIA en el dpto CUNDINAMARCA
# creado 652588 => GIRON en el dpto SANTANDER
# creado 652589 => SIMIJACA en el dpto CUNDINAMARCA
# creado 652590 => CAUCASIA en el dpto ANTIOQUIA
# creado 652591 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 652592 => CAMPO DE LA CRUZ en el dpto ATLANTICO
# creado 652593 => BUGALAGRANDE en el dpto VALLE
# creado 652594 => MONTERIA en el dpto CORDOBA
# creado 652595 => ACACIAS en el dpto META
# creado 652596 => PACHO en el dpto CUNDINAMARCA
# creado 652597 => MORALES en el dpto BOLIVAR
# creado 652598 => QUINCHIA en el dpto RISARALDA
# creado 652599 => GUADUAS en el dpto CUNDINAMARCA
# creado 652600 => PUEBLO NUEVO en el dpto CORDOBA
# creado 652601 => PLATO en el dpto MAGDALENA
# creado 652602 => LEBRIJA en el dpto SANTANDER
# creado 652603 => BUENAVENTURA en el dpto VALLE
# creado 652604 => COELLO en el dpto TOLIMA
# creado 652605 => PIEDECUESTA en el dpto SANTANDER
# creado 652606 => RIO DE ORO en el dpto CESAR
# creado 652607 => PORE en el dpto CASANARE
# creado 652608 => BARRANCABERMEJA en el dpto SANTANDER
# ...
# creado 656262 => INIRIDA en el dpto GUAINIA
# creado 656263 => SAN FRANCISCO en el dpto CUNDINAMARCA
# creado 656264 => YUMBO en el dpto VALLE
# creado 656265 => EL CARMEN en el dpto CHOCO
# creado 656266 => CHIQUINQUIRA en el dpto BOYACA
# creado 656267 => ENVIGADO en el dpto ANTIOQUIA
# creado 656268 => SOLEDAD en el dpto ATLANTICO
# creado 656269 => CHINCHINA en el dpto CALDAS
# creado 656270 => CIENAGA DE ORO en el dpto CORDOBA
# creado 656271 => SIBATE en el dpto CUNDINAMARCA
# creado 656272 => CIENAGA DE ORO en el dpto CORDOBA
# creado 656273 => LERIDA en el dpto TOLIMA
# creado 656274 => GUACARI en el dpto VALLE
# creado 656275 => GUARNE en el dpto ANTIOQUIA
# creado 656276 => IBAGUE en el dpto TOLIMA
# creado 656277 => CHIA en el dpto CUNDINAMARCA
# creado 656278 => SAN JERONIMO en el dpto ANTIOQUIA
# creado 656279 => TUNJA en el dpto BOYACA
# creado 656280 => ITAGUI en el dpto ANTIOQUIA
# creado 656281 => CHINACOTA en el dpto NORTE DE SANTANDER
# creado 656282 => CARTAGO en el dpto VALLE
# creado 656283 => CARTAGENA en el dpto BOLIVAR
# creado 656284 => SANTO TOMAS en el dpto ATLANTICO
# creado 656285 => DUITAMA en el dpto BOYACA
# creado 656286 => EL CERRITO en el dpto VALLE
# creado 656287 => QUETAME en el dpto CUNDINAMARCA
# creado 656288 => GIRARDOT en el dpto CUNDINAMARCA
# creado 656289 => SAN ROQUE en el dpto ANTIOQUIA
# creado 656290 => SINCELEJO en el dpto SUCRE
# creado 656291 => AIPE en el dpto HUILA
# creado 656292 => ELIAS en el dpto HUILA
# creado 656293 => ACACIAS en el dpto META
# creado 656294 => TIQUISIO en el dpto BOLIVAR
# creado 656295 => TURBACO en el dpto BOLIVAR
# creado 656296 => TIBU en el dpto NORTE DE SANTANDER
# creado 656297 => QUINCHIA en el dpto RISARALDA
# creado 656298 => EL DONCELLO en el dpto CAQUETA
# creado 656299 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 656300 => CHIGORODO en el dpto ANTIOQUIA
# creado 656301 => LA SIERRA en el dpto CAUCA
# creado 656302 => TUQUERRES en el dpto NARINO
# creado 656303 => MAGANGUE en el dpto BOLIVAR
# creado 656304 => SALGAR en el dpto ANTIOQUIA
# creado 656305 => MACANAL en el dpto BOYACA
# creado 656306 => CARCASI en el dpto SANTANDER
# creado 656307 => RICAURTE en el dpto NARINO
# creado 656308 => PASTO en el dpto NARINO
# creado 656309 => JENESANO en el dpto BOYACA
# creado 656310 => CUBARA en el dpto BOYACA
# creado 656311 => MORALES en el dpto CAUCA
# creado 656312 => HELICONIA en el dpto ANTIOQUIA
# creado 656313 => SUPATA en el dpto CUNDINAMARCA
# creado 656314 => PENSILVANIA en el dpto CALDAS
# creado 656315 => FLORIDABLANCA en el dpto SANTANDER
# creado 656316 => CERRITO en el dpto SANTANDER
# creado 656317 => HATO COROZAL en el dpto CASANARE
# creado 656318 => TONA en el dpto SANTANDER
# creado 656319 => PIEDECUESTA en el dpto SANTANDER
# creado 656320 => CONTRATACION en el dpto SANTANDER
# creado 656321 => CUBARRAL en el dpto META
# creado 656322 => GIRON en el dpto SANTANDER
# creado 656323 => ARAUQUITA en el dpto ARAUCA
# creado 656324 => LA CEJA en el dpto ANTIOQUIA
# creado 656325 => PITALITO en el dpto HUILA
# creado 656326 => AYAPEL en el dpto CORDOBA
# creado 656327 => BARRANQUILLA en el dpto ATLANTICO
# creado 656328 => ENVIGADO en el dpto ANTIOQUIA
# creado 656329 => PURISIMA en el dpto CORDOBA
# creado 656330 => ZONA BANANERA en el dpto MAGDALENA
# creado 656331 => VILLANUEVA en el dpto CASANARE
# creado 656332 => BARRANQUILLA en el dpto ATLANTICO
# creado 656333 => ZIPAQUIRA en el dpto CUNDINAMARCA
# creado 656334 => GUAMAL en el dpto META
# creado 656335 => TURBACO en el dpto BOLIVAR
# creado 656336 => PASTO en el dpto NARINO
# creado 656337 => QUIMBAYA en el dpto QUINDIO
# creado 656338 => YARUMAL en el dpto ANTIOQUIA
# creado 656339 => PORE en el dpto CASANARE
# creado 656340 => VILLA DEL ROSARIO en el dpto NORTE DE SANTANDER
# creado 656341 => PASTO en el dpto NARINO
# creado 656342 => ARJONA en el dpto BOLIVAR
# creado 656343 => OVEJAS en el dpto SUCRE
# creado 656344 => GIRARDOT en el dpto CUNDINAMARCA
# creado 656345 => SASAIMA en el dpto CUNDINAMARCA
# creado 656346 => VILLAGARZON en el dpto PUTUMAYO
# creado 656347 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 656348 => VALPARAISO en el dpto ANTIOQUIA
# creado 656349 => MARSELLA en el dpto RISARALDA
# creado 656350 => SANTA MARTA en el dpto MAGDALENA
# creado 656351 => LA DORADA en el dpto CALDAS
# creado 656352 => BELEN en el dpto NARINO
# creado 656353 => LA JAGUA DE IBIRICO en el dpto CESAR
# creado 656354 => ORTEGA en el dpto TOLIMA
# creado 656355 => ENCISO en el dpto SANTANDER
# creado 656356 => VILLANUEVA en el dpto CASANARE
# creado 656357 => GAMA en el dpto CUNDINAMARCA
# creado 656358 => VALDIVIA en el dpto ANTIOQUIA
# creado 656359 => TOCANCIPA en el dpto CUNDINAMARCA
# creado 656360 => EL CERRITO en el dpto VALLE
# creado 656361 => TAME en el dpto ARAUCA
# creado 656362 => CUMARAL en el dpto META
# creado 656363 => IBAGUE en el dpto TOLIMA
# creado 656364 => BARRANCABERMEJA en el dpto SANTANDER
# creado 656365 => CHITA en el dpto BOYACA
# creado 656366 => LORICA en el dpto CORDOBA
# creado 656367 => SAN PABLO en el dpto BOLIVAR
# creado 656368 => VICTORIA en el dpto CALDAS
# creado 656369 => GUASCA en el dpto CUNDINAMARCA
# creado 656370 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 656371 => OROCUE en el dpto CASANARE
# creado 656372 => PLANETA RICA en el dpto CORDOBA
# creado 656373 => CHINCHINA en el dpto CALDAS
# creado 656374 => NEIVA en el dpto HUILA
# creado 656375 => PUENTE NACIONAL en el dpto SANTANDER
# creado 656376 => SINCELEJO en el dpto SUCRE
# creado 656377 => CISNEROS en el dpto ANTIOQUIA
# creado 656378 => BUCARAMANGA en el dpto SANTANDER
# creado 656379 => EL CARMEN DE BOLIVAR en el dpto BOLIVAR
# creado 656380 => TUQUERRES en el dpto NARINO
# creado 656381 => SOPO en el dpto CUNDINAMARCA
# creado 656382 => GACHANTIVA en el dpto BOYACA
# creado 656383 => RETIRO en el dpto ANTIOQUIA
# creado 656384 => EL CERRITO en el dpto VALLE
# creado 656385 => LA CUMBRE en el dpto VALLE
# creado 656386 => PUERTO TEJADA en el dpto CAUCA
# creado 656387 => CAUCASIA en el dpto ANTIOQUIA
# creado 656388 => BELLO en el dpto ANTIOQUIA
# creado 656389 => BARANOA en el dpto ATLANTICO
# creado 656390 => ALVARADO en el dpto TOLIMA
# creado 656391 => DIBULLA en el dpto LA GUAJIRA
# creado 656392 => CANDELARIA en el dpto VALLE
# creado 656393 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 656394 => CURUMANI en el dpto CESAR
# creado 656395 => SOACHA en el dpto CUNDINAMARCA
# creado 656396 => URIBIA en el dpto LA GUAJIRA
# creado 656397 => LORICA en el dpto CORDOBA
# creado 656398 => POPAYAN en el dpto CAUCA
# creado 656399 => PUERTO BOYACA en el dpto BOYACA
# creado 656400 => PRADERA en el dpto VALLE
# creado 656401 => EL BANCO en el dpto MAGDALENA
# creado 656402 => CHIMA en el dpto CORDOBA
# creado 656403 => FLORESTA en el dpto BOYACA
# creado 656404 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 656405 => CUCUTA en el dpto NORTE DE SANTANDER
# creado 656406 => NOCAIMA en el dpto CUNDINAMARCA
# creado 656407 => GIRARDOTA en el dpto ANTIOQUIA
# creado 656408 => CONDOTO en el dpto CHOCO
# creado 656409 => MISTRATO en el dpto RISARALDA
# creado 656410 => VILLAGARZON en el dpto PUTUMAYO
# creado 656411 => TENA en el dpto CUNDINAMARCA
# creado 656412 => HELICONIA en el dpto ANTIOQUIA
# creado 656413 => PAZ DE ARIPORO en el dpto CASANARE
# creado 656414 => SANTA MARIA en el dpto HUILA
# creado 656415 => ARACATACA en el dpto MAGDALENA
# creado 656416 => PUERTO LOPEZ en el dpto META
# creado 656417 => RIOHACHA en el dpto LA GUAJIRA
# creado 656418 => AMBALEMA en el dpto TOLIMA
# creado 656419 => TITIRIBI en el dpto ANTIOQUIA
# creado 656420 => SAMANA en el dpto CALDAS
# creado 656421 => SANTUARIO en el dpto ANTIOQUIA
# creado 656422 => SAN VICENTE en el dpto ANTIOQUIA
# creado 656423 => TOLU en el dpto SUCRE
# creado 656424 => BUESACO en el dpto NARINO
# creado 656425 => TURBACO en el dpto BOLIVAR
# creado 656426 => MEDELLIN en el dpto ANTIOQUIA
# creado 656427 => CASABIANCA en el dpto TOLIMA
# creado 656428 => AQUITANIA en el dpto BOYACA
# creado 656429 => CONCORDIA en el dpto ANTIOQUIA
# creado 656430 => ANSERMA en el dpto CALDAS
# creado 656431 => POPAYAN en el dpto CAUCA
# creado 656432 => BUCARAMANGA en el dpto SANTANDER
# creado 656433 => FILADELFIA en el dpto CALDAS
# creado 656434 => PUPIALES en el dpto NARINO
# creado 656435 => SASAIMA en el dpto CUNDINAMARCA
# creado 656436 => URIBIA en el dpto LA GUAJIRA
# creado 656437 => CHITAGA en el dpto NORTE DE SANTANDER
# creado 656438 => SABANETA en el dpto ANTIOQUIA
# creado 656439 => CAIMITO en el dpto SUCRE
# creado 656440 => YOPAL en el dpto CASANARE
# creado 656441 => ANORI en el dpto ANTIOQUIA
# creado 656442 => TOTA en el dpto BOYACA
# creado 656443 => ARBELAEZ en el dpto CUNDINAMARCA
# creado 656444 => CAQUEZA en el dpto CUNDINAMARCA
# creado 656445 => RIONEGRO en el dpto SANTANDER
# creado 656446 => SAN RAFAEL en el dpto ANTIOQUIA
# creado 656447 => ANTIOQUIA en el dpto ANTIOQUIA
# creado 656448 => ARMENIA en el dpto QUINDIO
# creado 656449 => FACATATIVA en el dpto CUNDINAMARCA
# creado 656450 => RONCESVALLES en el dpto TOLIMA
# creado 656451 => TUNJA en el dpto BOYACA
# creado 656452 => ANOLAIMA en el dpto CUNDINAMARCA
# creado 656453 => QUINCHIA en el dpto RISARALDA
# creado 656454 => LA MESA en el dpto CUNDINAMARCA
# creado 656455 => ALBANIA en el dpto LA GUAJIRA
# creado 656456 => TALAIGUA NUEVO en el dpto BOLIVAR
# creado 656457 => CARTAGO en el dpto VALLE
# creado 656458 => BECERRIL en el dpto CESAR
# creado 656459 => DOLORES en el dpto TOLIMA
# creado 656460 => SAN JUAN DE BETULIA en el dpto SUCRE
# creado 656461 => DON MATIAS en el dpto ANTIOQUIA
# creado 656462 => BOLIVAR en el dpto ANTIOQUIA
# creado 656463 => RIOHACHA en el dpto LA GUAJIRA
# creado 656464 => GENOVA en el dpto QUINDIO
# creado 656465 => BOLIVAR en el dpto VALLE
# creado 656466 => TAMESIS en el dpto ANTIOQUIA
# creado 656467 => COROZAL en el dpto SUCRE
# creado 656468 => IPIALES en el dpto NARINO
# creado 656469 => COGUA en el dpto CUNDINAMARCA
# creado 656470 => ARJONA en el dpto BOLIVAR
# creado 656471 => EL CERRITO en el dpto VALLE
# creado 656472 => FLORIDA en el dpto VALLE
# creado 656473 => PAMPLONA en el dpto NORTE DE SANTANDER
# creado 656474 => RIOHACHA en el dpto LA GUAJIRA
# creado 656475 => VENECIA en el dpto CUNDINAMARCA
# creado 656476 => CARTAGO en el dpto VALLE
# creado 656477 => JERICO en el dpto ANTIOQUIA
# creado 656478 => ARBELAEZ en el dpto CUNDINAMARCA
# creado 656479 => CHOCONTA en el dpto CUNDINAMARCA
# creado 656480 => CODAZZI en el dpto CESAR
# creado 656481 => OPORAPA en el dpto HUILA
# creado 656482 => AMALFI en el dpto ANTIOQUIA
# creado 656483 => PALERMO en el dpto HUILA
# creado 656484 => BALBOA en el dpto CAUCA
# creado 656485 => VILLAVICENCIO en el dpto META
# creado 656486 => YACUANQUER en el dpto NARINO
# creado 656487 => PUERTO RICO en el dpto CAQUETA
# creado 656488 => TOCANCIPA en el dpto CUNDINAMARCA
# creado 656489 => PLATO en el dpto MAGDALENA
# creado 656490 => SAN MARTIN en el dpto META
# creado 656491 => CAIMITO en el dpto SUCRE
# creado 656492 => SOCHA en el dpto BOYACA
# creado 656493 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 656494 => SANTA ROSA DE CABAL en el dpto RISARALDA
# creado 656495 => SANTIAGO DE CALI en el dpto VALLE
# creado 656496 => CUMARIBO en el dpto VICHADA
# creado 656497 => FLORIDA en el dpto VALLE
# creado 656498 => SARDINATA en el dpto NORTE DE SANTANDER
# creado 656499 => MUTATA en el dpto ANTIOQUIA
# creado 656500 => TUQUERRES en el dpto NARINO
# creado 656501 => CIENAGA en el dpto MAGDALENA
# creado 656502 => PLANETA RICA en el dpto CORDOBA
# creado 656503 => GUAYABAL en el dpto TOLIMA
# creado 656504 => SAN JOAQUIN en el dpto SANTANDER
# creado 656505 => REMEDIOS en el dpto ANTIOQUIA
# creado 656506 => MORICHAL NUEVO en el dpto GUAINIA
# creado 656507 => MUZO en el dpto BOYACA
# creado 656508 => CUBARA en el dpto BOYACA
# creado 656509 => BOGOTA D.C. en el dpto BOGOTA D.C.
# creado 656510 => LORICA en el dpto CORDOBA
# creado 656511 => CARMEN DE VIBORAL en el dpto ANTIOQUIA
# creado 656512 => SAN ANTERO en el dpto CORDOBA
# creado 656513 => CAMPOALEGRE en el dpto HUILA
# creado 656514 => LA VIRGINIA en el dpto RISARALDA
# creado 656515 => ARMENIA en el dpto QUINDIO
# creado 656516 => CODAZZI en el dpto CESAR
# creado 656517 => BUCARAMANGA en el dpto SANTANDER
# creado 656518 => MALAMBO en el dpto ATLANTICO
# creado 656519 => ARGELIA en el dpto VALLE
# creado 656520 => APULO en el dpto CUNDINAMARCA
# creado 656521 => VALLEDUPAR en el dpto CESAR
# creado 656522 => CANDELARIA en el dpto VALLE
# creado 656523 => TAMESIS en el dpto ANTIOQUIA
# creado 656524 => AGUADAS en el dpto CALDAS
# creado 656525 => MAGANGUE en el dpto BOLIVAR
# creado 656526 => LORICA en el dpto CORDOBA
# creado 656527 => EL AGUILA en el dpto VALLE
# creado 656528 => CONVENCION en el dpto NORTE DE SANTANDER
# creado 656529 => BARBOSA en el dpto ANTIOQUIA
# creado 656530 => SAN JUANITO en el dpto META
# creado 656531 => CIENAGA en el dpto MAGDALENA
# creado 656532 => TITIRIBI en el dpto ANTIOQUIA
# creado 656533 => MONTELIBANO en el dpto CORDOBA
# creado 656534 => LA CUMBRE en el dpto VALLE
# creado 656535 => LEBRIJA en el dpto SANTANDER
# creado 656536 => EL PASO en el dpto CESAR
# creado 656537 => SABANA DE TORRES en el dpto SANTANDER
# creado 656538 => TIBU en el dpto NORTE DE SANTANDER
# creado 656539 => ARANZAZU en el dpto CALDAS
# creado 656540 => LA PALMA en el dpto CUNDINAMARCA
# creado 656541 => SANTANDER DE QUILICHAO en el dpto CAUCA
# creado 656542 => SARAVENA en el dpto ARAUCA
# creado 656543 => MONTELIBANO en el dpto CORDOBA
# creado 656544 => PEREIRA en el dpto RISARALDA
# creado 656545 => SANTA ISABEL en el dpto TOLIMA
# creado 656546 => SAN MARTIN DE LOBA en el dpto BOLIVAR
# creado 656547 => MOMIL en el dpto CORDOBA
# creado 656548 => SAN BERNARDO en el dpto NARINO
# creado 656549 => SARAVENA en el dpto ARAUCA
# creado 656550 => YUMBO en el dpto VALLE
# creado 656551 => TOGUI en el dpto BOYACA
# creado 656552 => EL PEÑON en el dpto BOLIVAR
# creado 656553 => PITALITO en el dpto HUILA
# creado 656554 => FUSAGASUGA en el dpto CUNDINAMARCA
# creado 656555 => PUERTO TRIUNFO en el dpto ANTIOQUIA
# creado 656556 => SAN VICENTE en el dpto ANTIOQUIA
# creado 656557 => CARMEN DE CARUPA en el dpto CUNDINAMARCA
# creado 656558 => SAN MARTIN en el dpto META
# creado 656559 => EL TAMBO en el dpto CAUCA
# creado 656560 => MUZO en el dpto BOYACA
# creado 656561 => BELLO en el dpto ANTIOQUIA
# creado 656562 => GUATAPE en el dpto ANTIOQUIA
# creado 656563 => CALDAS en el dpto ANTIOQUIA
# creado 656564 => CAUCASIA en el dpto ANTIOQUIA
# creado 656565 => VALLEDUPAR en el dpto CESAR
# creado 656566 => TUNJA en el dpto BOYACA
# creado 656567 => SAN ANDRES DE SOTAVENTO en el dpto CORDOBA
# creado 656568 => CONCEPCION en el dpto ANTIOQUIA
# creado 656569 => CURITI en el dpto SANTANDER
# creado 656570 => BETULIA en el dpto SANTANDER
# creado 656571 => PUERTO TEJADA en el dpto CAUCA
# creado 656572 => SANTIAGO DE CALI en el dpto VALLE
# creado 656573 => SINCELEJO en el dpto SUCRE
# creado 656574 => GIRON en el dpto SANTANDER
# creado 656575 => SANTIAGO DE CALI en el dpto VALLE
# creado 656576 => COROZAL en el dpto SUCRE
# creado 656577 => BUGALAGRANDE en el dpto VALLE
# creado 656578 => NEIRA en el dpto CALDAS
# creado 656579 => DOS QUEBRADAS en el dpto RISARALDA
# creado 656580 => ROSAS en el dpto CAUCA
# creado 656581 => BELLO en el dpto ANTIOQUIA
# creado 656582 => MARMATO en el dpto CALDAS
# creado 656583 => SABANETA en el dpto ANTIOQUIA
# creado 656584 => BETULIA en el dpto SANTANDER
# creado 656585 => SANTA BARBARA en el dpto NARINO
# creado 656586 => FUQUENE en el dpto CUNDINAMARCA
# creado 656587 => NATAGA en el dpto HUILA
# creado 656588 => HATONUEVO en el dpto LA GUAJIRA
# creado 656589 => TULUA en el dpto VALLE
# creado 656590 => LA CEJA en el dpto ANTIOQUIA
# creado 656591 => LA TEBAIDA en el dpto QUINDIO
# creado 656592 => NEIVA en el dpto HUILA
# creado 656593 => PROVIDENCIA en el dpto SAN ANDRES
# creado 656594 => CUCUNUBA en el dpto CUNDINAMARCA
# creado 656595 => GUAMAL en el dpto META
# creado 656596 => GUATAPE en el dpto ANTIOQUIA
# creado 656597 => SALAMINA en el dpto MAGDALENA
# creado 656598 => PUEBLO NUEVO en el dpto CORDOBA

# %%
revisar_contenido_de_una_tabla("Municipio",'','',10,'nombre_Municipio')
# Out:
# Total de registros en la tabla Municipio: 1122
# SELECT * FROM Municipio ORDER BY nombre_Municipio ASC LIMIT 10
# (804, 'ABEJORRAL', 13)
# (746, 'ABREGO', 10)
# (8040, 'ABRIAQUI', 13)
# (1010, 'ACACIAS', 19)
# (855, 'ACANDI', 30)
# (3186, 'ACEVEDO', 17)
# (1367, 'ACHI', 2)
# (205, 'AGRADO', 17)
# (2650, 'AGUA DE DIOS', 4)
# (96, 'AGUACHICA', 14)

# %% [markdown]
# # 5.4 Cargar EPS

# %%
def cargar_datos_eps(df,db_path,regimen="Contributivo"):
 conn= sqlite3.connect(db_path)
 cursor=conn.cursor()
 total_creados=0
 valores_unicos = df[['Código de la entidad','Nombre de la entidad']].drop_duplicates()
 for index,row in valores_unicos.iterrows():
  codigo_eps= row['Código de la entidad']
  nombre_eps= row['Nombre de la entidad']
  try:
    cursor.execute("INSERT OR IGNORE INTO Eps (codigo_Eps, Nombre_Eps, Regimen) VALUES (?, ?,?)", (codigo_eps, nombre_eps,regimen))
    total_creados+=1
    print(f"creado {total_creados} => {nombre_eps} con el código {codigo_eps}")
  except sqlite3.IntegrityError as e:
    print(f"No fue posible crear la EPS {nombre_eps} con el código {codigo_eps} due to {e}")
    pass
 conn.commit()
 conn.close()

# %%
cargar_datos_eps(df,db_path)
# Out:
# creado 1 => COOSALUD EPS S.A. -CM con el código ESSC24
# creado 2 => NUEVA EPS S.A. con el código EPS037
# creado 3 => EPS FAMISANAR S.A.S. con el código EPS017
# creado 4 => ASMET SALUD EPS S.A.S. -CM con el código ESSC62
# creado 5 => COOSALUD EPS S.A. con el código EPS042
# creado 6 => CAJA DE COMPENSACIÓN FAMILIAR COMPENSAR con el código EPS008
# creado 7 => NUEVA EPS S.A. -CM con el código EPS041
# creado 8 => ENTIDAD PROMOTORA DE SALUD SANITAS S.A.S. con el código EPS005
# creado 9 => SALUD TOTAL ENTIDAD PROMOTORA DE SALUD DEL REGIMEN CONTRIBUTIVO Y DEL REGIMEN SUBSIDIADO S.A. con el código EPS002
# creado 10 => ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ENTIDAD PROMOTORA DE SALUD - MUTUAL SER EPS con el código EPS048
# creado 11 => EPS SURAMERICANA S.A. con el código EPS010
# creado 12 => ENTIDAD PROMOTORA DE SALUD MALLAMAS EPSI -CM con el código EPSIC5
# creado 13 => ALIANZA MEDELLIN ANTIOQUIA EPS S.A.S. "SAVIA SALUD EPS" -CM con el código EPS040
# creado 14 => ASOCIACION MUTUAL SER EMPRESA SOLIDARIA DE SALUD ENTIDAD PROMOTORA DE SALUD - MUTUAL SER EPS -CM con el código ESSC07
# creado 15 => FONDO PASIVO SOCIAL DE LOS FERROCARRILES NACIONALES con el código EAS027
# creado 16 => EMSSANAR S.A.S. -CM con el código ESSC18
# creado 17 => ASOCIACIÓN INDÍGENA DEL CAUCA A.I.C. EPSI -CM con el código EPSIC3
# creado 18 => ALIANSALUD EPS S.A. con el código EPS001
# creado 19 => CAJACOPI EPS S.A.S -CM con el código CCFC55
# creado 20 => EMPRESA PROMOTORA DE SALUD INDÍGENA ANAS WAYUU EPSI -CM con el código EPSIC4
# creado 21 => ENTIDAD PROMOTORA DE SALUD SERVICIO OCCIDENTAL DE SALUD S.A. S.O.S. con el código EPS018
# creado 22 => EPS FAMILIAR DE COLOMBIA S.A.S. -CM con el código CCFC33
# creado 23 => CAPRESOCA E.P.S. -CM con el código EPSC25
# creado 24 => CAPITAL SALUD ENTIDAD PROMOTORA DE SALUD DEL RÉGIMEN SUBSIDIADO SAS "CAPITAL SALUD EPS-S S.A.S." -CM con el código EPSC34
# creado 25 => CAJA DE COMPENSACION FAMILIAR DEL VALLE DEL CAUCA "COMFENALCO VALLE DE LA GENTE con el código EPS012
# creado 26 => ASOCIACIÓN DE CABILDOS INDÍGENAS DEL CESAR Y GUAJIRA "DUSAKAWI A.R.S.I." -CM con el código EPSIC1
# creado 27 => PIJAOS SALUD EPSI -CM con el código EPSIC6
# creado 28 => CAJA DE COMPENSACIÓN FAMILIAR DEL CHOCÓ -CM con el código CCFC20
# creado 29 => FUNDACIÓN SALUD MIA con el código EPS046
# creado 30 => EMPRESAS PUBLICAS DE MEDELLIN - DEPARTAMENTO MEDICO con el código EAS016
# creado 31 => CAJA DE COMPENSACIÓN FAMILIAR DEL ORIENTE COLOMBIANO "COMFAORIENTE" -CM con el código CCFC50

# %%
revisar_contenido_de_una_tabla("Municipio",'','',10,'nombre_Municipio')
# Out:
# Total de registros en la tabla Municipio: 1122
# SELECT * FROM Municipio ORDER BY nombre_Municipio ASC LIMIT 10
# (804, 'ABEJORRAL', 13)
# (746, 'ABREGO', 10)
# (8040, 'ABRIAQUI', 13)
# (1010, 'ACACIAS', 19)
# (855, 'ACANDI', 30)
# (3186, 'ACEVEDO', 17)
# (1367, 'ACHI', 2)
# (205, 'AGRADO', 17)
# (2650, 'AGUA DE DIOS', 4)
# (96, 'AGUACHICA', 14)

# %% [markdown]
# #5.5 Crear tabla nieta "detalle"

# %%
conn= sqlite3.connect(db_path)
cursor=conn.cursor()
cursor.execute('''
CREATE TABLE IF NOT EXISTS Detalle (
    Id_Detalle INTEGER PRIMARY KEY AUTOINCREMENT,
    Id_Municipio INTEGER,
    Id_Sisben INTEGER,
    codigo_Eps TEXT,
    Genero TEXT,
    Grupo_etario TEXT,
    Tipo_afiliado TEXT,
    Estado_afiliado TEXT,
    Condicion_beneficiario TEXT,
    Regimen TEXT,
    Zona_afiliacion TEXT,
    Cantidad_registros INTEGER,
    FOREIGN KEY (Id_Municipio) REFERENCES Municipio(Id_Municipio),
    FOREIGN KEY (Id_Sisben) REFERENCES Sisben(Id_Sisben),
    FOREIGN KEY (codigo_Eps) REFERENCES Eps(codigo_Eps)
)
''')
conn.commit()
conn.close()

# %%
def cargar_detalle(df,db_path):
  conn= sqlite3.connect(db_path)
  cursor=conn.cursor()
  total_creados=0
  for index,row in df.iterrows():
    municipio   =row['Municipio']
    departamento=row['Departamento']
    #--------para obtener el id del sisben
    if (row['Nivel del Sisbén'] is None):
      id_sisben=0
    else:
      sisben=row['Nivel del Sisbén']
      cursor.execute("SELECT Id_Sisben FROM Sisben WHERE Nombre_Sisben=?", (sisben,))
      sisben_id=cursor.fetchone()
      if sisben_id:
        id_sisben=sisben_id[0]
      else:
        print(f"ERRROR: Sisben {sisben} para el municipio {municipio} no encontrado")
    #----------para obtener id del municipio
    cursor.execute("SELECT Id_Municipio FROM Municipio WHERE Nombre_Municipio=? AND Id_Departamento=(SELECT Id_Departamento FROM Departamento WHERE Nombre_Departamento=?)", (municipio,departamento))
    municipio_id=cursor.fetchone()
    if municipio_id:
      municipio_id=municipio_id[0]
    else:
      print(f"ERRROR: Municipio {municipio} para el departamento {departamento} no encontrado")
    #--------------guarde cada registro en la tabla---
    try:
      cursor.execute('''
      INSERT INTO Detalle (Id_Municipio, Id_Sisben, codigo_Eps, Genero, Grupo_etario, Tipo_afiliado, Estado_afiliado, Condicion_beneficiario, Regimen, Zona_afiliacion, Cantidad_registros)
      VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                    (municipio_id,
                      id_sisben,
                      row['Código de la entidad'],
                      row['Género'],
                      row['Grupo etario'],
                      row['Tipo de afiliado'],
                      row['Estado del afiliado'],
                      row['Condición del beneficiario'],
                      row['Régimen'],
                      row['Zona de Afiliación'],
                      row['Cantidad de registros']
                    ))
      total_creados+=1
      print(f"creado {total_creados}")
    except sqlite3.IntegrityError as e:
      print(f"No fue posible crear el registro due to {e}")
      pass
  conn.commit()
  conn.close()

# %%
cargar_detalle(df,db_path)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# creado 656415
# creado 656416
# creado 656417
# creado 656418
# creado 656419
# creado 656420
# creado 656421
# creado 656422
# creado 656423
# creado 656424
# creado 656425
# creado 656426
# creado 656427
# creado 656428
# creado 656429
# creado 656430
# creado 656431
# creado 656432
# creado 656433
# creado 656434
# creado 656435
# creado 656436
# creado 656437
# creado 656438
# creado 656439
# creado 656440
# creado 656441
# creado 656442
# creado 656443
# creado 656444
# creado 656445
# creado 656446
# creado 656447
# creado 656448
# creado 656449
# creado 656450
# creado 656451
# creado 656452
# creado 656453
# creado 656454
# creado 656455
# creado 656456
# creado 656457
# creado 656458
# creado 656459
# creado 656460
# creado 656461
# creado 656462
# creado 656463
# creado 656464
# creado 656465
# creado 656466
# creado 656467
# creado 656468
# creado 656469
# creado 656470
# creado 656471
# creado 656472
# creado 656473
# creado 656474
# creado 656475
# creado 656476
# creado 656477
# creado 656478
# creado 656479
# creado 656480
# creado 656481
# creado 656482
# creado 656483
# creado 656484
# creado 656485
# creado 656486
# creado 656487
# creado 656488
# creado 656489
# creado 656490
# creado 656491
# creado 656492
# creado 656493
# creado 656494
# creado 656495
# creado 656496
# creado 656497
# creado 656498
# creado 656499
# creado 656500
# creado 656501
# creado 656502
# creado 656503
# creado 656504
# creado 656505
# creado 656506
# creado 656507
# creado 656508
# creado 656509
# creado 656510
# creado 656511
# creado 656512
# creado 656513
# creado 656514
# creado 656515
# creado 656516
# creado 656517
# creado 656518
# creado 656519
# creado 656520
# creado 656521
# creado 656522
# creado 656523
# creado 656524
# creado 656525
# creado 656526
# creado 656527
# creado 656528
# creado 656529
# creado 656530
# creado 656531
# creado 656532
# creado 656533
# creado 656534
# creado 656535
# creado 656536
# creado 656537
# creado 656538
# creado 656539
# creado 656540
# creado 656541
# creado 656542
# creado 656543
# creado 656544
# creado 656545
# creado 656546
# creado 656547
# creado 656548
# creado 656549
# creado 656550
# creado 656551
# creado 656552
# creado 656553
# creado 656554
# creado 656555
# creado 656556
# creado 656557
# creado 656558
# creado 656559
# creado 656560
# creado 656561
# creado 656562
# creado 656563
# creado 656564
# creado 656565
# creado 656566
# creado 656567
# creado 656568
# creado 656569
# creado 656570
# creado 656571
# creado 656572
# creado 656573
# creado 656574
# creado 656575
# creado 656576
# creado 656577
# creado 656578
# creado 656579
# creado 656580
# creado 656581
# creado 656582
# creado 656583
# creado 656584
# creado 656585
# creado 656586
# creado 656587
# creado 656588
# creado 656589
# creado 656590
# creado 656591
# creado 656592
# creado 656593
# creado 656594
# creado 656595
# creado 656596
# creado 656597
# creado 656598

# %%
revisar_contenido_de_una_tabla("Detalle",'','',10)
# Out:
# Total de registros en la tabla Detalle: 656598
# SELECT * FROM Detalle LIMIT 10
# (1, 1, 1, 'ESSC24', 'Masculino', '45 a 50', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Urbana-Cabecera Municipal', 6)
# (2, 2, 2, 'EPS037', 'Femenino', '> 75', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Urbana', 1)
# (3, 3, 3, 'EPS037', 'Masculino', '15 a 19', 'COTIZANTE', 'Protección Laboral C', 'NO APLICA', 'Contributivo', 'Urbana', 1)
# (4, 4, 1, 'EPS017', 'Femenino', '15 a 19', 'BENEFICIARIO', 'Activo', 'ESTUDIANTE', 'Contributivo', 'Urbana-Cabecera Municipal', 2)
# (5, 5, 2, 'ESSC62', 'Masculino', '45 a 50', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Rural - Dispersal', 1)
# (6, 6, 3, 'EPS042', 'Femenino', '55 a 60', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Rural', 1)
# (7, 7, 3, 'EPS037', 'Masculino', '15 a 19', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Urbana', 8)
# (8, 8, 1, 'EPS008', 'Femenino', '55 a 60', 'BENEFICIARIO', 'Protección Laboral C', 'NO APLICA', 'Contributivo', 'Urbana', 4)
# (9, 9, 4, 'EPS037', 'Masculino', '45 a 50', 'COTIZANTE', 'Activo', 'NO APLICA', 'Contributivo', 'Rural', 1)
# (10, 10, 2, 'EPS037', 'Femenino', '5 a 15', 'BENEFICIARIO', 'Activo', 'NO APLICA', 'Contributivo', 'Rural', 14)

# %% [markdown]
# #6 Integrar con tutelas radicadas

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
url_forder_csv="/content/drive/MyDrive/BIG DATA/Tutelas clase 2"
listado_archivos= [f for f in os.listdir(url_forder_csv) if f.endswith(".csv")]
print(listado_archivos)
columnas_nombre=[
    "clasificacion",
    "num_expediente",
    "fecha_Radica",
    "demandante",
    "demandado",
    "primera_instancia",
    "segunda_instancia",
    "num_23Digitos",
    "providencia",
    "fechaSentencia"
]
df_tutelas=pd.DataFrame(columns=columnas_nombre)
display (df_tutelas)
# Out:
# ['tutelas_con_providencias_2021.csv', 'tutelas_con_providencias_2025.csv', 'tutelas_con_providencias_2024.csv', 'tutelas_con_providencias_2023.csv', 'tutelas_con_providencias_2022.csv']
# Empty DataFrame
# Columns: [clasificacion, num_expediente, fecha_Radica, demandante, demandado, primera_instancia, segunda_instancia, num_23Digitos, providencia, fechaSentencia]
# Index: []

# %%
def cargar_data_desde_archivo_csv(ruta_archivo):
  try:
      df_temporal = pd.read_csv(ruta_archivo,sep=';',header=None,encoding='latin-1',on_bad_lines='skip')
      #agregarle nombre de columnas al df creado
      df_temporal.columns=columnas_nombre
      if (len(df_temporal.columns)==len(columnas_nombre)):
        print(f" archivo {os.path.basename(ruta_archivo)} cargada exitosamente")
        return df_temporal
      else:
        print(f"archivo no trabajado {os.path.basename(ruta_archivo)} no tiene 10 columnas")
        return None

  except Exception as e:
      print(f"Error al procesar el archivo {os.path.basename(ruta_archivo)}: {str(e)}")
      return None

# %%
df_list=[]  #lista de df resultante de los datos de cada uno de los CSV
with ThreadPoolExecutor() as executor:
  future_to_file= {executor.submit(cargar_data_desde_archivo_csv,os.path.join(url_forder_csv,archivo_nombre)):archivo_nombre for archivo_nombre in listado_archivos}
  for future in as_completed(future_to_file):
    df=future.result()
    if df is not None:
      df_list.append(df)
#--------una vez termine de cargar todos los CSV combinelos en el dataframa df_tutelas
if df_list:
  df_tutelas= pd.concat(df_list,ignore_index=True)
  # reemplazar las palabras "NULL" por none
  df_tutelas.replace("NULL",None,inplace=True)
  display(df_tutelas.head())
# Out:
#  archivo tutelas_con_providencias_2021.csv cargada exitosamente
# /tmp/ipython-input-3430010226.py:3: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_temporal = pd.read_csv(ruta_archivo,sep=';',header=None,encoding='latin-1',on_bad_lines='skip')
#  archivo tutelas_con_providencias_2022.csv cargada exitosamente
#  archivo tutelas_con_providencias_2025.csv cargada exitosamente
#  archivo tutelas_con_providencias_2023.csv cargada exitosamente
#  archivo tutelas_con_providencias_2024.csv cargada exitosamente
#            clasificacion num_expediente         fecha_Radica  \
# 0  ï»¿Acciones de Tutela       T8531729  2021-12-16 00:00:00
# 1     Acciones de Tutela       T8531726  2021-12-16 00:00:00
# 2     Acciones de Tutela       T8531728  2021-12-16 00:00:00
# 3     Acciones de Tutela       T8531723  2021-12-16 00:00:00
# 4     Acciones de Tutela       T8531727  2021-12-16 00:00:00
#
#                                           demandante  \
# 0  VAZQUEZ CUADROS BAYRON EMILIO Y OTROS EN REPRE...
# 1                             ESCORCIA JORGE ARMANDO
# 2                       ARCINIEGAS MEDRANO CLEMENCIA
# 3                        SERRANO ROJAS CAMILO ANDRES
# 4                        GOMEZ QUINTERO EDILSA MARIA
#
#                                       demandado  \
# 0  SOCIEDAD DE ACTIVOS ESPECIALES S.A.E. S.A.S.
# 1             ALCALDIA MUNICIPAL DE SANTA LUCIA
# 2                           COLPENCIONES Y OTRO
# 3            SECRETARIA DE MOVILIDAD DE CAQUEZA
# 4                           CAJACOPI EPS Y OTRO
#
#                                    primera_instancia  \
# 0  BOGOTA,CUNDINAMARCA, TRIBUNAL SUPERIOR DE BOGO...
# 1  SANTA LUCIA,ATLANTICO, JUZGADO 1 PROMISCUO MUN...
# 2  BARRANQUILLA,ATLANTICO, JUZGADO 11 LABORAL DEL...
# 3  CAQUEZA,CUNDINAMARCA, JUZGADO 1 PROMISCUO MUNI...
# 4        CURUMANI,CESAR, JUZGADO PROMISCUO MUNICIPAL
#
#                                    segunda_instancia num_23Digitos  \
# 0                                                 --            --
# 1  SABANALARGA,ATLANTICO, JUZGADO 2 PROMISCUO DEL...            --
# 2  BARRANQUILLA,ATLANTICO, TRIBUNAL SUPERIOR SALA...            --
# 3                                                 --            --
# 4       CHIRIGUANA,CESAR, JUZGADO PENAL DEL CIRCUITO            --
#
#   providencia           fechaSentencia
# 0          --                      NaN
# 1          --                      NaN
# 2    T-274/22  2022-07-28 00:00:00.000
# 3          --                      NaN
# 4          --                      NaN

# %%
df_tutelas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3371223 entries, 0 to 3371222
# Data columns (total 10 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   clasificacion      object
#  1   num_expediente     object
#  2   fecha_Radica       object
#  3   demandante         object
#  4   demandado          object
#  5   primera_instancia  object
#  6   segunda_instancia  object
#  7   num_23Digitos      object
#  8   providencia        object
#  9   fechaSentencia     object
# dtypes: object(10)
# memory usage: 257.2+ MB

# %% [markdown]
# #6.1 extarer los expedientes donde los demandados eps

# %%
df_tutelas_eps=df_tutelas[df_tutelas['demandado'].str.contains("EPS",na=False)]
display(df_tutelas_eps.head())
df_tutelas_eps.count()
# Out:
#          clasificacion num_expediente         fecha_Radica  \
# 4   Acciones de Tutela       T8531727  2021-12-16 00:00:00
# 10  Acciones de Tutela       T8531722  2021-12-16 00:00:00
# 17  Acciones de Tutela       T8531705  2021-12-16 00:00:00
# 21  Acciones de Tutela       T8531702  2021-12-16 00:00:00
# 25  Acciones de Tutela       T8531700  2021-12-16 00:00:00
#
#                                            demandante             demandado  \
# 4                         GOMEZ QUINTERO EDILSA MARIA   CAJACOPI EPS Y OTRO
# 10  ARAGON CORREA ANDREA AO DE NUÃEZ BARACALDO KE...    CONVIDA EPS T OTRO
# 17                      QUIROZ RODRIGUEZ LIDIS ESTHER  LA NUEVA EPS Y OTROS
# 21                          HERNANDEZ GOMEZ SEBASTIAN          COOSALUD EPS
# 25                                  ROZO PARRA WILMAR     CAPITAL SALUD EPS
#
#                                     primera_instancia  \
# 4         CURUMANI,CESAR, JUZGADO PROMISCUO MUNICIPAL
# 10  CAQUEZA,CUNDINAMARCA, JUZGADO 1 PROMISCUO MUNI...
# 17        PAILITAS,CESAR, JUZGADO PROMISCUO MUNICIPAL
# 21  CHIGORODO,ANTIOQUIA, JUZGADO 1 PROMISCUO MUNIC...
# 25        ACACIAS,META, JUZGADO 1 PROMISCUO MUNICIPAL
#
#                                segunda_instancia num_23Digitos providencia  \
# 4   CHIRIGUANA,CESAR, JUZGADO PENAL DEL CIRCUITO            --          --
# 10                                            --            --          --
# 17  CHIRIGUANA,CESAR, JUZGADO PENAL DEL CIRCUITO            --          --
# 21  CHIRIGUANA,CESAR, JUZGADO PENAL DEL CIRCUITO            --          --
# 25                                            --            --          --
#
#    fechaSentencia
# 4             NaN
# 10            NaN
# 17            NaN
# 21            NaN
# 25            NaN
# clasificacion        848569
# num_expediente       848569
# fecha_Radica         848569
# demandante           848569
# demandado            848569
# primera_instancia    848568
# segunda_instancia    545324
# num_23Digitos        848569
# providencia          848568
# fechaSentencia          167
# dtype: int64

# %% [markdown]
# #6.2 Extraer las EPS dbua.db(sqlite)

# %%
conn= sqlite3.connect(db_path)
df_eps=pd.read_sql_query("SELECT * FROM Eps",conn)
conn.close()
display(df_eps.head())
# Out:
#   codigo_Eps                  Nombre_Eps       regimen
# 0     ESSC24       COOSALUD EPS S.A. -CM  Contributivo
# 1     EPS037              NUEVA EPS S.A.  Contributivo
# 2     EPS017        EPS FAMISANAR S.A.S.  Contributivo
# 3     ESSC62  ASMET SALUD EPS S.A.S. -CM  Contributivo
# 4     EPS042           COOSALUD EPS S.A.  Contributivo

# %% [markdown]
# #6.3 Contar las tutelas en contra de cada EPS (df_eps)

# %%
df_eps['total_tutelas']=0
demandados_encontrados =set()
for index,row in df_eps.iterrows():
  eps_nombre=row['Nombre_Eps']
  matching_tutelas = df_tutelas_eps[df_tutelas_eps['demandado'].str.contains(eps_nombre,na=False,case=False)]  #mejorar el código "NUEVA EPS"
  total_tutelas=matching_tutelas.shape[0]
  #df_eps.at[index,'total_tutelas']=total_tutelas
  df_eps.loc[index,'total_tutelas']=total_tutelas
  demandados_encontrados.update(matching_tutelas['demandado'].tolist())

demandados_no_encontrados=set(df_tutelas_eps['demandado'].unique())-demandados_encontrados
print(f"EPS demandadas encontrados: {len(demandados_encontrados)}")
print(f"EPS demandadas NO encontradas: {len(demandados_no_encontrados)}")
for demandado in demandados_no_encontrados:
  print(demandado)
# Out:
# EPS demandadas encontrados: 389
# EPS demandadas NO encontradas: 24012
# SUPERINTENDENCIA NACIONAL DE SALUD EPS SANITAS
# CAPITAL  SALUD EPS Y OTRO
# ASOACION INDIGENA DEL CAUCA  AIC - EPSI Y OTROS
# DIRECTOR GENERAL SUBDIRECTOR INGENIERÃ­A EPSA
# EPS MUTUAL SER Y OTROS
# SALUD VIDA EPS EN LIQUIDACIÃN.
# SERVICIO OCCIDENTAL DE SALUD EPS SOS EPS
# NUEVA EPS Y IPS COMFACAUCA
# FUNDACION INSTITUTO NEUROLOGICO DE COLOMBIA Y SAVIA SALUD EPS
# EPS SANITAS SAS Y FARMACIA HERINCO
# SAVIA SALUD EPS  Y  OTRO
# COLPENSIONES; NUEVA EPS Y OTRO
# NUEVA EPSA Y OTROS
# ASOCIACION MUTUAL SER EPS ESS Y OTRO
# EMPRESA PROMOTORA DE SALUD EPS - SURAMERICANA S. A
# CAJA COPI EPS-S , CAJACOPI EPS
# RED VITAL EPS  Y OTRO
# UNIDAD PEDIATRICA SIMON BOLIVAR EPS SAS
# SERVICIO OCCIENTAL DE SALUD SOS EPS Y OTRO
# EMSSANAR EPS - S.AS
# EPS MEDICINA PREPAGADA SURAMERICANA SA Y OTROS
# COMFAGURAJIRA EPS
# RED VITAL - EPS SUMIMEDICAL
# EPS SURA Y DROGERIAS CRUZ VERDE
# EPS SANITAS S. A. S. Y OTRO
# EPS SAVIA SALUD SECRETARIA SECCIONAL DE SALUD
# NUEVA EPS SA DORCA SAS COLPENSIONES
# NUEVA EPS Y PROTECCION
# COMPENSAR EPS | ALEJANDRO FACCINI Y CIA. SAS.
# EPS CAJA DE COMPESACION FAMILIAR DEL CHOCÃ Y OTROS
# SAVIA  EPS SALUD
# EPS SURA Y FUNDACION VALLE DEL LILI
# EMSSANAR EPS, Y OTROS
# CAPITAL SALUD EPS  Y OTRO
# ADMINISTRADORA DE LOS RECURSOS DEL SISTEMA GENERAL DE SEGURIDAD SOCIAL EN SALUD ADRES , NUEVA EPS SA , Y OTROS DEMANDADOSS
# COMPENSAR EPS Y IMEVI SALUD VISUAL
# NUEVA EPS CAJA DE COMPENSACION FAMILIAR CAFAM DROGUERIAS
# EPS SURA YCLINICA DIAGNOSTICA ESPECIALIZADA VID
# PENSIONES PORVENIR Y FAMISANAR EPS
# ECOOPSOS EPS - S
# EPS SURAMERICANA SA Y PFIZER SAS
# MEDINAS EPS, SALUCOOP EPS EN LIQUIDACION, CAFESALUD EPS EN RESTRUCTURACION Y A LA JUNTA REGINAL DE CALIFICACION DE INVALIDEZ
# SALUD TOTAL EPS S SA , SURA ARL.
# IPS RIESGO DE FRACTURA S.A. CAYRE Y NUEVA EPS
# FUNDACIN VER SIN FRONTERAS , EPS FAMISANAR S.A.S
# EPSFAMISANAR S.A.S.
# MUEVA EPS Y OTROS
# NUEVA EPS Y VINCULADO AUDIFARMA
# NUEVA EPS Y PTROS
# MEDIMAS EPS. , OTROS.
# AGUAS DE CARTAGENA EPS ACUACAR Y OTRO
# CAPITAL SALUD EPSS S A S
# EMDISALUD EPS-S
# EPS CAPITAL SALUD Y EL HOSPITAL DE KENNEDY
# ASMET SALUD EPS Y CLINICA SAN RAFAEL
# ASMET SALUD  EPS DISTRIBUIDORA DE MEDICAMENTOS
# MUTUAL SER EPS. Y OTROS
# NUEVA EPS SA Y OTRAS
# CAFESALUD EPS  Y OTROS
# EPS SUMIMEDICAL SA
# MEDIMAS EPS - CLÃNICA UROS S.A.S.
# NUEVA EPS SA Y PORVENIR
# ALIANZA MEDELLIN ANTIOQUIA EPS  Y OTRO
# EPS ASMET EPS
# MEDIMAS EPS Y NUEVA EPS
# NUEVA EPS Y FUNDACIÃN CARDIOVASCULAR DE COLOMBIA
# COJACOPI EPS Y OTROS
# NUEVA EPS Y POSITIVA
# EPS CAPITAL SALUD Y HOSPITAL SAN BLAS
# NUEVA EPS | COLFONDOS S.A.
# COMPENSAR CAJA DE COMPENSACION - ALIANSALUD EPS
# NUEVA EPS A Y OTRO
# SURA EPS SA Y OTRAS
# EPS MALLAMÃS Y OTRO
# SANITAS EPS Y FARMACIA PHARMASAN SAS
# ASOCIACION INDIGENA DEL CAUCA AICEPSI Y MENNAR SAS
# EPS Y MEDICINA PREPAGADA SURAMERICANA SA Y OTROS
# FAMISANAR EPS SAS,
# SANITAS EPS CRECIENDO SAS
# EPS SALUD TOTAL Y PROTECCION SA
# ADMINISTRCION JUDICIAL SECCIONAL VALLE DEL CAUCA SANITAS EPS Y OTROS
# EPS SALUD TOTAL, VIRREY SOLIS IPS
# SURA EPS Y CLINICA LAS AMERICAS
# EPS Y MEDICINA PREPAGADA SURAMERICANA S.A.- EPS SURA
# DENUEVA EPS
# ASOCIACIÃN INDÃGENA DEL CAUCA EPS-I
# ASOCIACION MUTUAL EMPRESA SOLIDARIA EPS
# EPS COOMEVA S.A. Y OTROS
# EPS-S COMFAMILIAR DEL HUILA
# ASOCIACION INDIGENA DEL CAUCA AIC EPSS
# SAVIASA EPSLUD  Y OTROS
# ASOCIACION MUTUAL SER, MUTUAL SER EPS
# NUEVA EPSUNICA OFFIMEDICAS
# CONVIDA EPSS Y OTRO
# HERRERA MARTINEZ ADRIANA DEL PILAR , LA NUEVA EPS
# EPS SALUD Y OTROS
# FARMACIA UNICA COLSUBSIDIO Y NUEVA EPS
# EMSSANAR EPS.
# ASMET SALUD EPS Y CLINICA BELO HORIZONTE
# VIDANOVA SAS ASMET SALUD EPS MEDISFARMA SAS
# CAJACOPY EPS
# COOSALUD EPS-S S.A. Y OTROS
# EPS SALUD TOTAL S.A Y OTROS
# COOSALUD EPSS Y OTRAS
# MEDICALL TALENTO HUMANO SAS IPS VIRREY SOLIS EPS SALUD TOTAL
# CAPITAL SALUD EPS- Y OTROS
# INVERSIONES OHV SAS Y SANITAS EPS SUPERSALUD
# MUTUAL SER EPS SA  Y OTROS
# EMSSANAR EPSN Y OTROS
# AFP PORVENIR Y MEDIMAS EPS
# ASMETSALU EPS Y OTRO
# COLSUBSIDIO | FAMISANAR EPS
# ASOCIACION INDIGENA DEL CAUCA  AIC EPSI Y MENNAR SAS
# CAJACOPI EPS YO TROS
# COOMEVA EPSS Y OTROS
# INSERCOOP | NUEVA EPS
# SURA EPS CLINICA DE ESPECIALIDADES OFTALMOLOGICAS
# NUEVA EPS -Y OTRO
# SURAMERICANAEPS
# MUTUAL SER EPS Y ASOCIACION MUTUAL SER E.S.S.
# VIVA EPS
# PIJAOS SALUD EPS INDIGENAS ESE
# EPS COOSALUD ESE Y OTRO
# SANITAS EPS Y AUDICOM
# SALUD TOTAL EPS.
# FAMISANAR LTDA EPS Y OTROS
# COMFAMILIAR DEL HUILA  EPS Y OTRO
# FUNDACION SALUD MIA EPS
# COOSALUD EPS Y PROMOTORA DE SALUD IPS
# SURA SURAMERICANA EPS S.A
# UT RED VITAL SUMIMEDICAL EPS
# SANITAS EPS CORDOBA
# MEDIMA EPS
# SANITAS EPS - Y OTRO
# EMSSAMAN EPS
# CAPIAL SALUD EPS
# SERVICIO OCCIDENTAL DE SALUD SOS -EPS
# AFP PRTECCION SALUD TOTAL EPS
# AIR-E CARIBE SOL DE LA COSTA EPS Y OTRO
# EPS SERVICIO OCCIDENTAL DE SALUD SOS DROGUERIAS Y OTROS
# EPS SURA, E IPS MEDICARTE S.A.S
# CAJACOPI-EPS Y OTROS
# EPS CAPITAL SALUD Y AUDIFARMA
# SANITAS EPS - DROGUERIAS CRUZ VERDE C
# ASMET SALUD EPS - SECRETARIA DE SALUD DEPARTAMENTAL DEL CESAR
# HOSPITAL SAN RAFAEL DE ITAGUI | NUEVA EPS Y HOSPITAL DEL SUR DE ITAGUI | CLINICA MEDELLIN | CLINICA ANTIOQUIA DE ITAGUI | MANUEL URIBE ANGEL
# EPS MUTUAL SER
# CAJA DE COMPENSACION FAMILIAR CAFAM EPS
# SOS SERVICIO OCCIDENTAL DE SALUD EPS SOS
# SALUD TOTAL EPS - IPS MAPLE RESPIRATORY
# ASMETSALUD EPS Y OTRO
# SAVIA SALUD EPS MEDELLIN Y OTRO
# FUNDACION CLINICA DEL NORTE - EPS SURA
# NUEVA EPS Y LA CLÃNICA LAS AMERICAS
# COMPENSAR EPS SALUD TOTAL EPS
# SERVICIO OCCIDENTAL DE SALUD SA SOS EPS Y OTROS
# COMFAMILAIR DEL HUILA EPS
# EAPB MUTUAL SER EPS
# EPS SAVIASALUD Y OTROS
# DUKASAWI EPS
# EPS INDÃGENA MALLAMAS EPSI
# NNUEVA EPS  Y OTROS
# SANIDAD EPS; SECRETARIA DEPARTAMENTAL DEL SALUD
# SALUD TOAL EPS Y OTROS
# EPS RED VITAL- SUMIMEDICA
# SERVICIO OCCIDENTAL DE SALUDSOS SOS EPS Y OTROS
# SAVIA SALUD EPS Y CLINICA MEDELLIN DE OCCIDENTE
# SEGUROS DEL ESTADO S.A, Y VINCULADA LA EPS MEDIMAS
# AGUAS DEL ATRATO AGUA NACIONALES EPM SA EPS
# SURAMERICANA SURA ARL EPS SANITAS
# CLINICA NUEVA EPS Y CLINICA COLSUBSIDIO CALLE 94
# EPS UNION TEMPORAL SERVISALUD SAN JOSE
# SALUD TOTAL EPS Y CLÃ­NICA LOS ROSALES DE PEREIRA
# NUEVA EPS Y PROENSALUD
# SAVIA SALUD EPS IPS METROSALUD Y OTRO
# MUTUAL SER EPS , FLOREZ GALEANO EDUVITH BEATRIZ
# SALUD TOTAL SA EPS
# SURAMERICA EPS S.A
# EPS COMFASUCRE Y OTROS
# ECOOPSOS EPS SAS Y OTROS
# SALUD SALUD TOTAL EPS
# EPS SURA Y SALUD TOTAL
# ASMETA SALUD EPS
# EPS MEDIMÃS S.A.S. Y OTRO
# SALUD TOTAL EPS SA  Y OTROS
# SALUDTOTAL SA EPS
# COOSALUD EPS Y VISION INTEGRADOS
# SANITAS EPS CLINICA CARDIOINFANTIL
# ALIANZA MEDELLIN ANTIOQUIA  EPS Y OTROS
# FAMISANAR EPS I.P.S. COLSUBSIDIO
# COMPENSAR CAJA DE COMPENSACION FAMILIAR  EPS
# NUEVA EPS Y FARMACIA OFFIMEDICAS SA
# SURAMERICANAEPS Y OTROS
# SOCIEDAD MEDICA DE RIONEGRO YSANITAS EPS
# EPS COMPESAR Y IPS BIENESTAR
# EPS SURA SECRETARIA DE SALUD DEL VALLE Y OTROS
# EPS SANITAS Y  Y OTRO
# EPSS COMFACUMDI UNICAJAS
# SERVICIO OCCIDELTAL DE SALUD SOS EPS
# SANITAS EPS HUILA Y OTROS
# NUEVA EPS Y  FOSCAL
# SALUD TOTAL EPS NY OTROS
# EPS SURA Y COMFAMA IPS
# COMFAMILIAR EPS Y TROS
# S. O. S. SERVICIO OCCIDENTAL DE SALUD EPS
# COLPENSIONES-NUEVA EPS
# NUEVA EPS Y EL INSTITUTO DEPARTAMENTAL DE SALUD DE NORTE DE SANTANDER
# EPS S COOSALUD
# ASMET SAUD EPS Y OTRO
# MEDIMAS EPS | NUEVA EPS
# IPS NEURODINAMIA SA Y SALUD TOTAL EPS
# FUNDACION CONTRO COLOMBIANO DE EPILEPSIA Y ENFERMEDADES NEUROLOGICAS JAIME FANDIÃO FRANKY FIRE Y OTROS
# ENTIDAD PROMOTORA DE SALUD SERVICIO OCCIDENTAL DE SALUD SA EPS SOS SA
# COODSALUP EPS
# COMPENSAR Y EPS Y OTRO
# EPS CAJA DE COMPENSACION FAMILIAR CAJACOPI |
# ASMETSALUD EPS
# EMSSANNAR EPS
# BARRIOS UNIDOS DE QUIBDO AMBUQ EPS
# COMPENSAR EPS CONTRIBUTIVO
# ADMINISTRADORA COLOMBIANA DE PENSIONES COLPENSIONES COMPENSAR EPS
# COOSALUD EPS SA IPS METRODROGAS
# EPS CAJACOPI SUBSIDIADO
# SALUD TOTAL EPS Y LA IPS AIR LIQUIDE
# MUTUAL SER EPS EMPRESA SOLIDARIA DE SALUD
# SERVICIO OCCIDENTALDE SALUD EPS Y OTROS
# ASOCIACION DE BARRIOS UNIDOS DE QUIBDO EPS
# EPS COMFAMILIAR Y OTROS
# ECOSALUD EPS Y OTROS
# CAPITAL SALUD EPS Y  OTROS
# NUEVA EMPRESA PROMOTORA DE SLAUD NUEVA EPS
# NUEVA EPS FLORENCIA
# EPS MEDISALUD Y OTROS
# EPS Y MEDICINA PREPAGADA SURAMERICANA S.A - SURA EPS
# EPSS MUTUAL SER
# AUDIFARMA | COMPENSAR EPS
# IPS SUMIMEDICAL Y RED VITAL EPS
# EPS MUTUAL SER.
# SUPERINTENDENCIA NACIONAL DE SALUD SURA EPS Y MEDICINA PREPAGADA
# AMBUQ EPS S ESS
# NUEVA EPS - SURA ARL
# NUEVA EPSS Y AUDIFARMA
# ASOCIACION INDIGENA DEL CAUCA EPS-I
# COMFACUNDI EPSS
# FAMEDIC IPS - NUEVA EPS
# NUEVA EPS DE CARTAGENA
# EPS SANITAS Y LA IPS FRESENIUS MEDICAL CARE
# MUTUAL SER EPS E.S.S Y OTRO
# FUNDACION SALUD MIA EPS Y FUNDACION VER SIN FRONTERAS
# ASOCIACION MUTUAL SER EPS-S-S
# FIDUPREVISORA SA EPS SUMIMEDICAL
# EPSA SAVIA SALUD
# SAVIA SALUD EPS | PRODIAGNOSTICO IPS S.A. | COOPERATIVA DE HOSPITALES DE ANTIOQUIA COHAN
# COLPENSIONES S.A Y NUEVA EPS Y ESE HEQC
# NUEVA EPS Y CLINICA DE ALTA COMPLEJIDAD SANTA BARBARA S.A.S
# ALCALDIA DE JARDIN  Y EPSI BIENESTAR
# NUEVA EPS Y LINFOCAL IPS
# COMPARTA EPS S  Y OTRO
# SOS EPS Y FARMACIA CRUZ VERDE
# FAMISANAR EPS;  HOSPITAL SAN LORENZO DE ARAUQUITA Y OTROS
# COMFENALCO VALLE EPS -UNIVERSIDAD DEL VALLE.
# NUEVA EPS Y PORVENIR
# EPS ASMET SALUD Y  OTROS
# ALCALDIA MUNICIPAL DE GUEPSA, INSPECCIÃN MUNICIPAL Y  OTROS
# EPS SURA, FONDO DE PENSIONES Y CESANTÃAS ?COLPENSIONES?.
# NUEVA EPS, MINSALUD Y OTROS
# FAMISANAR EPS FAMISANAR COLSUBSIDIO
# SAVIA SALID EPS
# EPS SA SANITAS
# EPS AMBUQ ESS E.S.D
# COMARTA EPS EN LIQUIDACION Y OTRO
# CAPITAL SALUD EPS E  Y OTRO
# FAMISANAR EPS Y SECRETARIA DE SALUD DE FUSAGASUGA
# EPS EMSSANAR Y OTROS
# FAMISANAR EPS SAS CLINICA COMFAMILIAR
# SOCIEDAD AAA SA EPS
# EPSS CAJACOPI
# SANITAS EPS CLINICA CAFAM SEDES CALLE 90 Y 93
# EPS SALUD TOTAL | AFP PORVENIR
# EMSSANAR EPS - IDSN
# EPS ASMETSALUD S.A.S
# FAMISANAR EPS  Y CAFAM
# COMPENSAR EPS, COMPENSAR PLAN COMPLEMENTARIO
# CAPITAL SALUD EPSS YY OTROS
# EPS SALUD TOTAL. EPS
# EPS SALUD TOTAL SA
# RED VITAL EPS - SUMIMEDICAL S.A.S.
# ASEMET SALUD EPS Y OTROS
# CAJA DE COMPENSACION FAMILIAR EPS COMPENSAR
# EPS SANITAS Y COLFONDOS Y OTRO
# EPS SANITAS SAA Y OTROS
# EPS SAMISANAR Y OTROS
# AXA COLPATRIA ARL , LA NUEVA EPS. , PROTECCION PENSIONES Y CESANTIAS SA
# SERIVICIO EPS ,OCCIDENTAL DE SALUD SOS
# SALUD TOTAL EPS, PROTECCION SA
# NUEVA EPS Y  Y OTROS
# EMSERFUSA SA EPS
# AVANZAR MEDICO EPS
# ALIANZA MEDELLN ANTIOQUIA EPS SAS SAVIA SALUD EPS
# SU SALUD EPS
# NUEVA EPS | MANIZALES ACTIVA SAS
# EPS COOMEVA Y OTRO
# CAPRESOCA EPS Y ESE SALUD YOPAL
# CLINICA AVIDANTI SAS Y SURAMERICANA EPS S.A
# HOSPITAL UNIVERSITARIO SAN JORGE Y COOSALUD EPS
# EPS AMET SALUD
# ASOCIACIÃN MUTUAL BARRIOS UNIDOS DE QUIBDÃ EPS-S Y  OTROS
# SALUD TOTAL EPS Y COMFAMILIAR RISARALDA
# SANACION Y VIDA EPS S.A.S Y OTROS
# PROMOSALUD , SALUD TOTAL EPS
# SALUD TOTAL EPS, COLPENSIONES Y FORTOX SA
# EVEDISA COMPENSAR EPS
# NUEVA EMPRESA PROMOTORA DE SALUD NUEVA EPS SANITAS SA EPS
# SALUDTOTAL EPS | INSTITUTO MEDICO OFTALMOLOGICO DE COLOMBIA
# ALIANSALUD EPS  OTROS
# ALIANSALUD EPS NUEVA EPS
# COMFANDI SOS EPS
# EPS SALUD TOTAL RIONEGRO Y OTROS
# SERVICIO OCCIDENTAL DE SALUD EPS SOS CLINICA CALI Y OTROS
# EPSS SAVIA SALUD Y OTROS
# SANITAS EPS Y LA OTROS
# EPS SURA | PROTECCION Y OTROS
# SANIOTAS EPS
# SANITAS EPS Y GOBERNACION DE CASANARE
# AUDIFARMA Y NUEVA EPS
# COOMEVA EPS Y OTROA
# EPS COLSANITAS MEDICINA PREPAGADA
# EPS-S CAPITAL SALUD SECRETARIA DISTRITAL DE SALUD
# VEOLIA ASEO  DE CALI SA EPS  Y OTRO
# SURAMERICANA EPS S.A.S Y OTROS
# SANITAS EPS Y DROGUERIA PHARMASAN
# EPS SURAMERICANA S,.A.
# ECOOPSOSEPS-S Y COOPERATIVA DE SALUD SAN ESTEBAN
# CAJA DE COMPENSACIÃ³N FAMILIAR COMPENSAR - COMPENSAR EPS Y OTROS
# COMPARTA EPS EN LIQUIDADA Y OTRO
# SANITAS EPS Y CLINICA ASORSALUD
# EPS UT SERVISALUD SAN JOSE Y OTROS
# GAS NATURAL CUNDIBOYACENSE  EPS
# MUTUAL EPS Y AFP PROTECCION
# MEDISINU IPS , MUTUAL SER EPS
# IPS CLINICA INFANTIL COLSUBSIDIO Y FAMISANAR EPS
# COLMEDICA MEDICINA PREPAGADA SA ALIANSALUD EPS SA
# MALLAMAS - EPS-I Y OTROS
# MEDIMAS EPS-S Y OTRO
# SAVIA SALUD EPS S SECRETARIA SECCIONAL DE SALUD Y PROTECCION SOCIAL DE ANTIOQUIA
# ENTIDAD PROMOTORA DE SALUD TOTAL EPS
# EPS SURAMERICANA SA HOSPITAL ALMA MATER DE ANTIOQUIA
# SANITAS EPS | MINISTERIO DE SALUD
# NUEVA EPS SA Y DISPENSARIO CAFAM
# COLPENSIONES ,COMFENALCO VALLE EPS Y OTRO
# NUEVA EPS Y LA CLINICA BELO HORIZONTE SAS
# ASMET SALUD EPS Y LA AUDIOLOGIA CLINICA CLARA ISABEL GUERRERO
# EPS SURAMERICANA SA EPS SURA Y  HOSPITAL PABLO TOBON URIBE
# EPS SURA Y CIS COMFAMA ITAGUI Y OTRO
# EMPRESA DE ENERGIA DEL PACIFIGO EPSA SA - CELSIA COLOMBIA
# AIRE E SAS EPS Y OTROS
# COMPARTA EPS-
# ADMINISTRADORA COLOMBIANA DE PENSIONES - (COLPENSIONES) Y COMPENSAR EPS
# CAJA DE COMPENSACION FAMILIAR COMPENSAR EPS  Y OTROS
# NUEVA EPS CLINICA PALERMO
# AIRE - E SAS EPS
# ENTIDAD PROMOTORA DE SALUD SANITAS EPS S.A.
# ASOCIAION INDIGENA DEL CAUCA AIC EPS
# NUEVA EPS Y AUDIFARMA
# MUTUAL SER EPS-S   Y OTROS
# COOMEVA EPS- Y OTROS
# EPS SERVICIO OCCIDENTAL DE SALUD ESE HOSPITAL SANTA MONICA
# EAPB EMSSANAR EPS SAS
# TERMOCARIBE SAS EPS Y OTRO
# SAVIA SALUD EPS Y OTRO
# SOS EPS SA Y OTRO
# SALUD TOTAL EPSS SA Y OTROS
# EPS SALUD TOTAL Y IPS SAN ESTEBAN
# ADRES NUEVA EPS Y OTROS
# MUTUAL SER EPS CLINICA CRECER IPS
# SALUD TOTAL NUEVA EPS Y OTRO
# SUPERINTENDENCIA NACIONAL DE SALUD FAMISANAR EPS
# NUEVA EPS INTERVENTOR DE NUEVA EPS Y OTROS
# COMFAORIENTE EPS SUBSAIDADA
# COMPENSAR EPS CM
# INPEC Y EPS BELLAVISTA
# ALIANZA SALUD EPS
# ACCION SALUD IPS , DIAXEM SAS , MEDIMAS EPS. , VIDA SER
# CLINICA DEL NORTE EPS Y OTROS
# EPSI FAMILIAR DE COLOMBIA Y OTRO
# CAJACOPI EPS Y ESE MUNICIPIO DE VILLAVICENCIO Y OTROS
# SAVIA SALUD EPS - S
# COOSALUD EPS SECRETARIA DE SALUD MUNICIPAL DE PALMIRA SECRETARIA DEPARTAMENTAL DE SALUD DEL VA
# ASMETSALUD EPSS MANIZALES
# EMSSANAR EPS Y INSTITUTO DEPARTAMENTAL DE SALUD DE NARIÃO
# CAPITAL SALUD EPS SUBRED INTEGRADA DE SERVICIOS DE SALUD SUR ESE
# NUEVA EPS Y HOSPITAL DEL SARARE ESE
# EPS FAMISANAR EPS Y OTROS
# COOMEVA EPS CARTAGENA
# FAMISANAR EPS Y OTRPS
# NUEVA EPS NUEVA EMPRESA PROMOTORA DE SALUD SA Y OTROS
# LIGA CORDOBESA CONTRA LA EPILEPSIA IPS
# EPS SURA Y HOSPITAL PABLO TOBON URIBE
# FAMISANARE EPS Y OTRO
# ALIANZA MEDELLIN ANTIOQUIA EPS - SAS SAVIA SALUD EPS Y OTROS
# NUEVA EPS Y CENTRO DE CIRUGIA LASER OCULAR LTDA
# CAJACOPI  EPS SAS
# EPS BARRIOS UNIDOS DE QUIBDO
# MUTUAL SER EPS Y OTORS
# SANITAS EPS Y CINICA CAFAM
# EPS CAPRESOCA Y OTROS
# COOPSALUD EPS Y OTROS
# SANITASEPS Y OTROS
# ALIANZA MEDELLÃN ANTIOQUIA SAVIA SALUD EPS Y OTROS
# EPS SURA ESTUDIOS ENDOSCOPICOS
# EPS CLINICA LA TOSCANA DE LA POLICIA NACIONAL
# ALIANUD EPS Y OTROS
# EPS SERVICIO OCCIDENTAL DE SALUD S.O.S. S.A.
# ASOCIACION MUTUAL BARRIOS UNIDOS DE QUIBDO AMBUQ EPS Y OTROS
# NUEVA EPS HOSPITAL UNIVERSITARIO SAN JORGE
# FAMISANAR EPS SAS Y OTROS
# EPS SERVISALUD Y COLSANITAS
# COOSALUD EPS.S.
# SURA EPS Y ORS
# COOMEVA EPS SA Y OTROS
# DISPENSARIO MEDICO DISFARMA NUEVA EPS
# CAJA DE COMPENSACION FAMILIAR COMPENSAR | COMPENSAR EPS
# SURAMERICANA S.A , ASOCIACION INDIGENA DEL CAUCA EPS -I
# CAJACOPI EPS- EPS Y OTROS
# EPS SANITAS SAS Y MEDICINA TERAPIA DOMICILIARIA
# EPS RED VITAL UT Y OTRO
# EPS CAJACOPI SUBSIDIADO Y OTRO
# FAMISANAR EPS IPS CAJA DE COMPENSACION FAMILIAR CAFAM
# NUEVA EPS | ADMINISTRADORA COLOMBIANA DE PENSIONES -COLPENSIONES-
# EPSS SAVIASALUD Y OTROS
# NUEVA EPS Y GO PROYECTOS Y ESTRUCTURAS SAS
# SALUD TOTAL EPS S SAS
# EPS SURAMERICANA EPS SURA
# NUEVA EPS, AUDIFARMA
# MEDIMAS EPS S.A. S. Y OTROS
# EPS COFENALCO VALLE  DE LA GENTE Y OTROS
# AFINIA EPS
# EPS SERVICIO OCCIDENTAL DE SALUD SOS  Y OTROS
# CAPITAL SALUD EPS- Y LA SECRETARIA DISTRITAL DE SALUD
# EPS COMPENSAR SAS
# SURAMERICANA EPS S.A..
# EPS SERVICIO OCCIDENTAL DE SALUD S.O. S
# EPS SANITAS, SECRETARIA DE SALUD DEPARTAMENTAL , ADRES
# LA NUEVA EPS SA YO SU INTERVENTOR Y OTROS
# DIRECTORA DE OFICINA EPS SANITAS SAS
# SECRETARIA DE SALUD DEPARTAMENTAL DE SANTANDER | NUEVA EPS
# SURA EPS Y SALUD TOTAL
# NUEVA EPS ADRES VIVA1A SAS IPS
# ASMET SALUD EPS Y LA SECRETARÃA DE SALUD DEPARTAMENTAL DEL CESAR
# COLPENSIONES Y MEDIMAS EPS
# SERVICIO OCCIDENTAL DE SALUD SOS EPS Y TRO
# ALIANZA MEDELLIN  EPS SAS Y OTRO
# EMSANAR EPS SAS Y OTROS
# EMSSANAR ENTIDAD PROMOTORA DE SALUD EPS SAS
# MEDICALL TALENTO HUMANO SAS Y EPS FAMISANAR
# SERVICIO OCCIDENTAL DE SALUD EPS S.A
# EPS COMFAORIENTE Y OTRO
# SANITAS EPS 1
# COSMITET EPS Y OTRO
# ENELAR EPS Y OTRO
# MUTUAL SER EPS E.S.S. Y OTROS
# SURA EPS Y EL INSTITUTO ROOSEVELT
# GASES DEL CARIBE SA EPS
# NUEVA EPS Y AGRICOLA EL RETIRO
# SANITAS EPS OTRO
# EPS ECCOPSOS Y SSSYPSA
# CLINICA CEREN SAS Y FAMISANAR EPS
# EPS UT SERVISALUD QCL CAMPIN
# COLOMBIA TELECOMUNICACIONES SA EPS Y OTROS
# EMSSANAR EPS S.A.S. Y OTRO
# S.O.S. EPS
# HOSPITAL REGIONAL DE SOGAMOSO CAJACOPI EPS SAS SECRETARIA DE SALUD DE BOYACA MINISTERIO DE SALUD Y PROTECCION SOCIAL SUPERINTENDENCIA NACIONAL DE SALUD
# DIRECTOR MEDIMAS EPS
# SALUDTOTAL EPS-S Y OTRO
# CONSORCIO SALUD EPS COMFENALCO VALLE
# SALUD TOTAL EPS, SECRETARIA SALUD DEPARTAMENTAL, ADRES
# EPS SURAY OTROS
# EPS S MEDIMAS Y SECRETARIA DEPARTAMENTAL DE SALUD
# EPS ASMET SALUD S.A.S. Y OTRO
# EPS SANITAS FARMACIA CRUZ VERDE
# SAMUEL BAQUERO ARIAS, LA EMPRESA SERVITAXI SA Y LA EPS SALUD TOTAL
# COMPAÃÃA DE ENERGÃA CELSIA TOLIMA SA EPS
# COOSALUD EPS DE CARTAGO VALLE
# COMPENSAR EPS,  Y OTROS
# EMSSANAR EPS, ADRES Y OTROS
# FAMISANAR EPS Y RAMEDICAS SAS
# NUEVA EPS, PORVENIR Y FUTURASEO
# EPS SANITAS SUBSIDIADA
# EPSS FAMISANAR
# AFP PROTECCION Y EPS SALUD TOTAL
# SURA EPS PROTECCION
# SAVIA SALUD EPS Y SALUD TOTAL IPS
# NUEVA EPS | IPS CLINICA DEL PRADO SA
# ASOCIACION INDIGENA DEL CAUCA AIC EPS-1
# EPS SURAMERICANA SAGRUPO RENALUT SOFASA SAS
# COLSUBSIDIO Y NUEVA EPS
# NUEVA EPS. Y COLPENSIONES, ARL SURA
# NUEVA EPS ARL SURA
# COOSALUD EPS SA Y OTROS VINCULADOS
# SECRETARIA DE SALUD DE BOYACA, COMPARTA EPS-S Y HOSPITAL REGIONAL DE MONIQUIRA
# NUEVA EPS Y  IPS ONCOMEDICAL
# SAVIA EPS SALUD Y MEDICANCER
# COMPENSAR EPS Y  Y OTROS
# COOSALUD EPS. S.A. Y OTROS
# EPS SAVIA SALUD SAS Y OTRO
# EPS SALUD TOTAL E IPS AUDIFARMA
# SERVICIO OCCIDENTAL DE SALUD EPS SOS Y OTRO
# EMPRESA DE ENERGIA DEL PACIFICO ESP EPSA CELSIA
# LAS CEIBAS EMPRESAS PUBLICAS DE NEIVA EPS
# EPS SAS SAVIA SALUD Y OTROS
# EPS-MEDIMAS Y OTRA
# EPS - S SAVIA SALUD
# CLINICA BUENOS AIRES | CLINICA DEL CESAR | EPS SANITAS
# COODALUD EPS
# EPS COMFANDI ALAMEDA
# COOSALUD EPS Y PROMEDAN SA
# EPS UTERSERVICI SALUD SAN JORGE Y OTRO
# EPS SANITAS S.A.S OTRO
# SURTIGAS SA EPS
# BIOGER SAS EPS
# HOSPITAL CARDIOVASCULAR DE CUNDINAMARCA SA EPS-S CONVIDA
# LADMEDIS | COOSALUD EPS
# VANTI S.A. EPS Y OTRO
# CAJA DE COMPENSACION DEL ORIENTE COMFAORIENTE EPS Y OTROS
# FAMISANAR S.A.S EPS Y OTROS
# SALUD TOTAL EPS S.A. Y OTROS
# FAMISANAR EPS E IPS GLOBAL LIFE AMBULANCIAS SAS
# MONTAJES Y CONSTRUCCIONES FERMAR VINCULADO NUEVA EPS SA Y AXA COLPATRIA SEGUROS DE VIDA SAS
# EPS SURAMERICANA Y OTRAS
# ECCOPSOS EPS
# COOSALUD EPS   OTROS
# EPS SAVIA SALUD (ALIANZA MEDELLÃN ANTIOQUIA EPS S.A.S.)
# ALIANZA MEDELLIN ANTIOQUIA EPS S.A.S Y SAVIA SALUD EPS
# ECOOPSOS EPS, HOSPITAL SAN RAFAEL , SECRETARIA DE SALUD DE FUSAGASUGA Y SECRETARIA DE SALUD DE CUNDINAMARCA
# NUEVA EPS SA Y  SANITAS EPS
# SALUD TOTAL EPS Y OTRAS
# CAJACOPIAS EPS Y OTROS
# EMSSANAR EPS Y PORVENIR
# SANITAS EPS, BRILLADORA EL DIAMANTE
# MUTUAL SER ESS EPS
# SURA EPS IPS INSTITUTO DEL SISTEMA NERVIOSO DE RISARALDA
# COLPENSIONES, JUNTA REGIONAL DE CALIFICACION DE INVALIDEZ Y COMPENSAR EPS
# MEDIMAS EPSS
# ASMET SLAUD EPS Y OTROS
# POSITIVA ARL Y SANITAS EPS-S.
# FAMISANAR EPS IPS MEDICADIZ
# ALIANZA MEDELLIN- SAVIA SALUD EPS Y OTROS
# ENTIDAD PRESTADORA DE SALUD NUEVA EPS SA
# SALUT TOTAL EPSS Y OTROS
# SALULTOTAL EPS Y OTROS
# CCOMPARTA EPS EN LIQUIDACION Y OTROS
# EPS UT SERVICIOS SAN JOSE Y OTROS
# VEOLIA SA EPS Y OTROS
# EMPRESA DE ENERGIA DEL QUINDIO S.A EPS
# SURA ARL,  GRANELES Y CARGA SA Y EPS FAMISANAR
# SERVITEMPORALES LABORALES Y SANITAS EPS
# SANITAS EPS Y PROTECCION
# NUEVA EPS SA , OTTOBOCK HEALTH CARE SAS
# ALIANSALUD EPS  SA
# SAVIA SALUD EPS Y HOSPITAL SAN JUAN DE DIOS ESE RIONEGRO
# NUEVA EPS SUBSIDIDADO
# AVANZAR EPS
# EPS SAVIA SALUD Y OTORS
# EMSSANARE EPS
# RED VITAL EPS
# FAMISANAR EPS Y AFP PORVENIR
# NUEVA EPS - IDS
# MEDIMAS EPS Y COOSALUD EPS
# EPS SOSRC
# COMFAMILIAR  EPS Y OTRO
# COLMENA A.R.P , FAMISANAR EPS
# CAPRESOCA EPS Y ONCOLIFE IPS S.A.S.
# FUNDACION MEDICO PREVENTIVA EPS Y OTRO
# COOSALUD  EPS SA Y OTRO
# COOLSALUD EPS SA
# EPS SANITAS SAS Y CLINICA SANTA ANA SA
# ASOCIACION INDIGENA DEL CAUCA AIC EPS Y OTROS
# MUTUALSER EPS Y AUDIFARMA
# ALIANZA MEDELLIN ANTIOQUIA EPS SAS
# SANITAS EPS CENTRO MÃDICO CALLE 80
# LA NUEVA EPS , SECRETARIA DE SALUD DEL CAQUETA
# EPS UT RED INTEGRADA FOSCAL - CUB
# NUEVA EPS VISION TOTAL IPS
# CLINICA MEREDI Y EPS COMPENSAR
# CAPITAL SALUD EPS Y CAJACOPI CHITA BOYACA EPS
# FONDO DE PRESTACIONES SOCIALES DEL MAGISTERIO EPS
# NUEVA EPS SA COLSUBSIDIO
# CAPITAL SALUD EPS Y ARL SURA
# EPS SERVICIO OCCIDENTAL DE SALUD EPS S.O.S Y OTROS
# NUEVA EPS HEALTH LIFE IPS
# ASMET SALUD EPS Y ESE HOSPITAL MARIA INMACULADA
# SLUD TOTAL EPS Y OTROS
# NUEVA EPS SA, MINISTERIO DE SALUD Y PROTECCION SOCIAL Y SUPERINTENDENCIA NACIONAL DE SALUD
# CEHANI ESE EMSSANAR EPS
# ALIANZA MEDELLÃN ANTIOQUIA EPS S.A.S. - SAVIA SALUD Y OTROS
# COMPENSAR EPS-S
# EPS SAVIA SALUD (ALIANZA MEDELLÃN ANTIOQUIA EPSS.A.S.)
# SOLUCIONES EFECTIVAS TEMPORAL SAS Y EPS SURAMERICANA
# FAMISANAR EPS Y HEMATO ONCOLOGOS
# COMPARTA EPS-S SECCIONAL FUNDACION
# NUEVA EPS Y COLFONDOS S.A
# SALUD TOTAL EPS Y PALMA SALUD IPS LTDA
# CAJA DE COMPENSACION FAMILIAR DE SUCRE COMFASUCRE EPS Y OTRO
# EPS COOSALUD SAS Y OTROS
# INSTITUTO NIÃOS CIEGOS Y SORDOS SOS EPS
# CLINICA BUCARAMANGA | FAMISANAR EPS
# EPS SERVICIO OCCIDENTAL DE SALUD - S.O.S. S.A. Y OTROS
# DUSAKAWI EPSI Y CLNICA DE LA COSTA
# HOSPITAL ERAMOS MEOZ Y CAMFAORIENTE EPS
# FAMISANAR EPS CAFAM ZIPAQUIRA
# SURA EPS - FRESENIUS MEDICAL CENTER Y DAVITA COLOMBIA
# EPS SALUD TOAL
# FAMISANAR EPS, AFP PORVENIR Y TECNRED SAS
# CPITAL SALUD EPS
# SAVIA SALUD  EPS
# FAMISANAR EPS Y COLFONDOS AFP
# EPS COMPENSAR Y ARL AXA COLPATRIA
# EMSSANAR EPS Y CLINICA SANTA GRACIA
# LA NUEVA EPS Y CLINICA SAN JOSE DE CUCUTA
# SANITAS EPS Y COLSANITAS MEDICINA PREPAGADA
# ALIANZA MEDELLÃN ANTIOQUIA SAVIA SALUD EPS S.A Y OTRO
# NUEVA EPS SALUD SA
# NUEVA EPS SA Y DROGUERIA CAFAM
# EMSSANAR SAS EPS
# EPS SURA Y  CLINICA VIDA
# COMFENALCO VALLE EPS Y OTROS VINCULADOS
# NUEVA EPS | COOMEVA EPS EN LIQUIDACION
# COOSALUD  EPS  Y OTROS
# EMSSANAR EPS SOS
# FAMISANAR EPS CAFAM  Y OTROS
# COMFENALCO VALLE EPS.
# FARMACIA COLSUBSIDIO, SURA EPS Y OTROS
# MULTIASISTIR EAT EPS
# SURA EPS Y OTROSD
# ARL SURA | EPS SURA
# ENTIDAD PROMOTORA DE LA SALUD SALUDTOTAL EPS
# SURA EPS - YEPES RESTREPO OTORRINOS
# COMPAÃIA SEGUROS MUNDIAL S.A Y GRUPO EMPRESARIAL JARBSALUD IPS S.A.S, Y CAPITAL SALUD EPS-S.
# SAVIA SALUD EPS VISION INTEGRADOS SAS VISION TOTAL MEDELLIN SAS
# EPS SANITAS MEDICINA LABORAL
# IBAL EPS S.A
# ASMET SALUD -EPS
# SERVICCIO OCCIDENTAL DE SALUD EPS Y OTRO
# FAMISANAR EPS Y PORVENIR S.A.
# IPS UNIVERPLUS SA Y CAPITAL SALUD EPS
# EPS SERVISALUD QCL Y OTROS
# SANITAS EPS EPS Y OTROS
# CAJACIPI EPS Y OTRO
# SAVIA SALID EPS Y OTROS
# SUPERINTENDENCIA DE SALUD EPS SALUD TOTAL
# SALUD TOTAL EPS AUDIFARMA SA
# EPS COOSALUD E IPS ESTRIOS S.A.S
# NUEVA EPS REGIMEN SUBSIDIADO Y AUDIFARMA SA
# COMPENSAR EPS Y PORVENIR S.A.
# EPS SURA NEUROMEDICA SA Y OTROS
# SALUD TOTAL EPS SSA
# EMSSARAR EPS Y OTROS
# DIRECCION DE SANIDAD POLICIAL EPS
# NUEVA EPS REGIMEN CONTRIBUTIVO
# SAVIA SALUD EPS.S -SSSA
# EPS S MEDIMAS Y OTRO
# NUEVA EPS Y ASOCIACION INDIGENA DEL CAUCA AIC-EPSI Y OTRO
# COMPENSAR EPS S.A.
# EMSSANAR EPS SAS Y HOSPITAL SAN JUAN DE DIOS CALI
# EPS SURAMERICANA Y OTRIOS
# JUNTA REGIONAL DE CALIFICACION DE INVALIDEZ DEL ATLANTICO NIT 8020165032 EPS SURA NIT 80
# COMPARTA EPS-S SECRETARIA DE SALUD SANTANDER - ADRES
# ENTIDAD PROMOTORA DE SALUD EPS S.O.S. S.A.
# OFTALMOHELP Y FAMISANAR EPS
# AQUALIA SAS EPS Y OTROS
# EPS SANITAS AUDIOCOM IPS.
# SANITAS EPS Y  FARMACIA CRUZ VERDE
# MEDIMÃS EPS  Y OTROS
# FAMISANAR SEPS
# MALLAMAS EPS ARIMUYA
# NUEVA EPS Y LA IPS BIENESTAR
# EMSSANAR EPS ESP Y SECRETARIA DE SALUD DEPARTAMENTAL DEL PUTUMAYO
# ASMET EPS SALUD VINCULA ESE HOSPITAL UNIVERSITARIO SAN JORGE DE PEREIRA
# FAMISNAR EPS Y OTRO
# EPS MEDIMAS Y FONDO DE PENSIONES-COLPENSIONES
# SURA EPS ENTIDAD PROMOTORA DE SALUD
# SALUD TOTAL EPS Y ALTAMED
# SANITAS SAS EPS Y OTRO
# EPS EMSSANAR.
# NUEVEA EPS Y OTROS
# COOMEVA EPS S.A. BARRANQUILLA
# MEDI ES EPS FONDO DEL MAGISTERIO
# ASOCIACION INDIGENA DEL CAUCA - A.I.C EPS
# SAVIA SALUD EPS Y HOSPITAL GENERAL DE MEDELLÃ­N ESE
# FAMINASAR EPS Y OTROS
# SERVICIO OCCIDENTAL DE SALUD SA EPS SOS SA
# BARROSO SAS EPS
# ADMINISTRADORA COLOMBIANA DE PENSIONES COLPENSIONES | MEDIMAS EPS S.A.S
# EPS COOSALUD EPS Y OTROS
# CONVIDA EPSS
# EPS SAVIA SALUD | CLÃNICA DE CIRUGÃA AMBULATORIA CONQUISTADORES S.A.
# COMPENSAR EPS SAS Y OTRO
# EPS COMFENALCO Y  OTROS
# COMPENSAR PLAN COMPLEMENTARIO Y COMPENSAR EPS
# EMSSANAR EPS HOSPITAL UNIVERSITARIO DEL VALLE Y OTRO
# SANITAS EPS , MEDINUCLEAR SAS
# EMPRESA ELECTRIFICADORA  DEL META SA EPS
# EPS SURA Y MEDYSER IPS SAS
# EPSA FAMISANAR Y OTRO
# VIVA 1 IPS EPS Y OTRO
# ASMET SALUD EPSS SAS
# ATESA DE OCCIDENTE EPS
# GERENCIA REGIONAL NORTE DE LA NUEVA EPS
# EPS. SANITAS
# SURAMERICANA  EPS SA SURA CAJA DE COMPENSACION FAMILIAR DE ANTIOQUIA COMFAMA CIS COMFAMA PARQUE FABRICATO
# ARL POSITIVA Y SALUD TOTAL EPS-S S.A.
# EPS  SURAMERICANA S.A. Y OTRO
# EPSMUTUAL SER
# COMPENSAR EPS, VIVA 1A IPS Y OTRO
# EPS FAMISANAR - COLSUBSIDIO
# CAPITAL SALUD EPSS Y SUBRED INTEGRADA DE SERVICIOS DE SALUD CENTRO ORIENTE ESE
# FAMISANAR EPS, SANTA SOFIA IPS, RAMEDICAS SAS
# NUEVA EPS SAIPS MEDICUC
# EPS COSMITET POPAYAN
# DE LA EPS ASOCIACIÃN INDÃGENA DEL CAUCA, UN CABILDO INDÃGENA EN EL DEPARTAMENTO DEL CAUCA Y UNA IPS INDÃGENA.
# NUEVA EPS Y SANDRA MILENA VEGA GOMEZ
# SAVIA SALUD EPSS ALIANZA MEDELLIN ANTIOQUIA EPS SAS
# ALUD TOTAL EPSS SA
# COMPENSAR SALUD EPS Y OTROS
# EPS COOSALUD Y CLINICA BONADONA
# SALUD TOTAL EPS Y AUDIOFARMA
# EPS SANITAS - IPS CENTRO MEDICO NUEVO HORIZONTE Y UNIDAD DE URGENCIAS ALTO PRADO
# COOSALUD EPSS Y DROGUERIA PHARMASAN
# EMSSANAR EPS | IDSN
# NUEVA EPS SUBSIDIADO
# SANITAS EPS Y CLINICA SEBASTIAN DE BELALCAZAR
# ECOOPSOS EPS Y ECOIMAGEN SALUD
# EPS SOS SERVICIO DE SALUD OCCIDENTAL DE SALUD
# CLINICA SOMA MEDELLIN Y SURA EPS
# EPS SANTIAS
# \"ENTIDAD PROMOTORA DE SALUD SURA EPS
# NUEVA EPS - IPS HEALTH & LIFE
# NATIONAL TRUCK SERVISE S A S Y FAMISANAR EPS
# EPS SALUD TOTAL REGIONAL CALDAS
# AGUAS DE BOGOTA SA EPS
# NUEVA EPS Y OTROS NUEVA EPS MINSTERIO DE SALUD SUPER SALUD
# SURAMERICANA EPS SA ,SURA EPS
# NUEVA EPS - ARL SURA Y OTROS
# ANITAS EPS
# NUEVA EPS EN INTERVENCION Y OTRO
# JUZGADO 1 PROMISCUO MUNICIPAL CON FUNCION DE CONTROL DE GARANTIAS DE GUEPSA
# NUEVA EPS Y UNIÃN TEMPORAL VIVA SEDE MEDELLÃN
# EPS SALUD TOTAL S.A Y OTRO
# COMPENSAR EPS Y FARMACIA INSTITUCIONAL SAS
# ASMET SALUD EPS - SECRETARIA DE SALUD DEL CAQUETA
# SALUD EPS  TOTAL PROTECCION REDES HUMANAS SAS
# MINISTERIO DE SALUD, NUEVA EPS Y OTROS
# SALUD TOTAL EPS SA Y OTRA
# COLPENSIONES EPS
# EPS SURA Y SOMA
# LA NUEVA EPS Y ORTRO
# SALUD TOTAL EPS Y OTROS
# COOSALUD EPS-S E IPS Y OTROS
# NUEVA EPS, Y CUIDARTE EN CASA.
# EPS ASMETSALUD Y IPS CLINICA LOS ROSALES
# ENTIDAD PROMOTORA DE SALUD DEL RÃ©GIMEN SUBSIDIADO EPS-S
# NUEVA EPS Y ORA
# ADMINISTRADORA DE LOS RECURSOS DEL SISTEMA GENERAL DE SEGURIDAD SOCIAL EN SALUD (ADRES) , MUTUAL SER EPS
# SERVICIO DE OCCIDENTAL EPS
# EMSSANAR EPS SA Y OTRO
# EMSSANAR EPS Y ENSALUD GROUP
# ENTIDAD PROMOTORA DE SALUD COOSALUD EPS REGIMEN CONTRIBUTIVO
# EPS SOS OCCIDENTAL DEL VALLE
# CAMACHO RODRIGUEZ BERNARDO ARMANDO   Y NUEVA EPS
# COOSALUD  EPS SA VINCULADAS DE OFICIO, LA ESE HOSPITAL DEPARTAMENTAL UNIVERSITARIO SANTA SOFÃ­A DE CALDAS, CLÃ­NICA OSPEDALE MANIZALES SA, ANGIOSUR CLÃ­NICA NEUROCARDIOVASCULAR, RTS COLOMBIA SAS Y ONCÃ³LOGOS DEL OCCIDENTE SAS
# ALIANZA MEDELLIN ANTIOQUIA EPS S.A.
# COMFAMILAIR DE NARINO EPS Y OTRO
# EPS SAN GABRIEL
# AUDIFARMA SA Y SALUD TOTAL EPS S SA
# EPS SANITAS Y IPS NEUROMEDICA
# EPS-S MEDIMAS Y OTROS
# FAMISANAR EPS DISFARMA GC SAS
# EPS MEDIMAS Y SUPERSALUD
# ADMINISTRADORA COLOMBIANA DE PENSIONES COLPENSIONES | LA NUEVA EPS
# SALUD TOTAL S.A EPS Y OTRO
# EPS FIDEICOMISOS PATRIMONIOS AU FOMAG Y OTRO
# SALUD TOTAL EPS-S  Y OTROS
# ALIANZA MEDELLIN ANTIOQUIA EPS. S.A.S. Y OTRO
# SUERA EPS Y OTRO
# EPS COMFENALCO VALLE DE LA GENTE EPS Y OTROS
# COOSALUD EPS SA Y TRO
# COMFAGUAJIRA EPS
# COOSALUD EPS Y HOSPITAL SAN RAFAEL
# NUEVA EPS Y CLINICA ANTIOQUIA
# ECOOPSOS EPS Y HOSPITAL JOSE CAYETANO
# SALUD TOTAL EPS ALMUM SAS
# MUTUAL SER EPS CLINICA SAN MARTIN CLINICA DE LA COSTA IPS SECRETARIA DE SALUD MALAMBO
# IPS COLSUBSIDIO | FAMISANAR EPS
# NUEVA EPS- OTROS.
# SALUD TOTAL EPS REGIMEN CONTRIBUTIVO DE SALUD
# EPS SANIDAD PONAL REGIONAL ANTIOQUIA
# EMMSANAR EPS Y CLINICA SANTA SOFIA DEL PACIFICO
# ANAS WAYOO EPSI
# FAMISANAR EPS , DROGUERIA CAFAM
# SEVISIO OCCIDENTAL DE SALUD S.O.S EPS Y OTRO
# CENTRAL HIDROELECTRICA DE CALDAS CHECSA EPS BIC
# CAJACOPY EPS.
# PROVIDA EPS
# EPS CONFACUNDI  Y OTRO
# SANITAS EPSY OTROS
# AFINIA GRUPO EPM- CARIBE MAR DE LA COSTA SAS EPS
# MEDIMAS EPS  Y OTRO
# EPSS ASMET SALUD S.A.S.
# SANIDAD EPS POLICIA NACIONAL
# ASOCIACION INDIGENA DEL CAUCA EPSI
# EPS SURAMERICANA SA -EPS SURA
# EPS CAFESALUD EN LIQUIDACION Y OTROS
# ASOCIACION MUTUAL BARRIOS UNIDOS DE QUIBDO EPS-S
# FAMISANAR EPS Y OTR
# COOSALUD EPS SA.
# EPS SURA, AGRICOLA EL RETIRO
# CAPRESOCAE EPS
# MUTUAL SER EPS TURBANA
# COMPENSAR EPS, RIESGO DE FRACTURA SA CAYRE E IPS RANGEL
# EPSA
# EPS SURA Y SAVIA SALUD EPS
# EPS SANITAS Y CLINICA BLAS DE LEZO IPS
# EPS SANITAS COLPENSIONES
# SAVIA SALUD EPS Y OPROS
# FAMISANAR  EPSY OTROS
# EPSS MUTUALSER
# CAJACOP EPS Y OTROS
# AFP COLPENSIONES EPS
# EPS MUTUAL SER ESS EMPRESA SOLIDARIA DE SALUD
# NUEVA EPS, HOSPITAL DEL SARARE E.S.E.
# SAVIA SALUD EPS ? ESE SAN JUAN DE DIOS DE RIONEGRO ANTIOQUIA
# EPS SURAMERICANAENTACION DE SU HIJA MENOR DE EDAD SCSG
# NUEVA EPS Y DISCOLMETS
# SERVILENGUPA EPS Y OTRO
# REGISTRADURIA NACIONAL DEL ESTADO CIVIL Y LA EPS CAJACOPI
# FAMINSANR EPS
# ALIANZA MEDELLIN ANTIOQUIA EPS Y SAVIA SALUD EPS
# NUEVA EPS . SA. Y OTROS
# NUEVA EPS Y LA IPS COLSUBSIDIO
# EPSFAMISANARIPS CAFAM AMERICASVIDAMEDICAL IPS
# COOPERATIVA DE SALUD COMUNITARIA EMPRESA PROMOTORA DE SALUD SUBSIDIADA - COMPARTA EPS-S
# MEDITEP IPS Y NUEVA EPS
# MEDIMAS EPS Y HOSPITAL FEDERICO LLERAS ACOSTA
# EPS SERVICIO OCCIDENTAL DE SALUD Y OTROS
# SURAMERICANA  EPS  SA, EPS SURA
# EPS EMSSANAR S.A. Y OTROS
# SALUD TOTAL EPSS S.A.
# EPS FAMISAR Y COLSUBSIDIO
# ALCALDIA DE LETICIAS , EPS MALLAMAS Y OTROS
# EPS SANITAS - DEFENSOR DEL PUEBLO
# CAPITAL SALUD EPS SUBRED DE SERVICIOS DE SALUD SUR OCCIDENTE
# EPS COMFAMILIAR  DEL HUILA
# NUEVA EPS SANAMEDIC IPS
# SALUD VIDA EPS EN LIQUIDACION
# EPS COSMITET Y CLINICA PINARES MEDICA
# SAVIA SALUD EPS Y FISINOVA
# AXA COLPATRIA SEGUROS | COMFAMILIAR EPS
# NUEVA EPS REGIONAL PUTUMAYO Y NARIÃO Y OTROS
# EPS MEDIMAS Y ARL LIBERTY
# MALLAMAS EPSI CLINICA LAS LAJAS
# SANITAS EPS REGIMEN CONTRIBUTIVO
# EPS FAMISANAR Y IPS CAFAM
# AVANZAR FOS EPS  Y OTROS
# ALIANZA MEDELLÃN ANTIOQUIA EPS S.A.S. - SAVIA SALUD Y OTRO
# HOSPITAL SAN JUAN DE DIOS DE RIONEGRO Y SAVIA SALUD EPS
# REDVITAL EPS - SUMIMEDICAL
# SANITAS EPS Y ACTIDENT PLUS S.A.S
# EPS MEDIMAS SAS Y OTROS
# ASMET SALU EPS SA Y OTRO
# EPS SERVICIOS OCCIDENTALES DE SALUD SOS
# UNION TEMPORAL TOLIHUILA EPS Y OTRA
# NUEVA EPS Y CLINICA CHINITA
# COMPENSAR EPS | Y OTRO
# ARL AXA COLPATRIA, COOSALUD EPS
# COMPARTA EPS - S
# COMPENSAR EPS, IMEVI
# CLINICA SANTA ANA DE CUCUTA Y LA NUEVA EPS
# SANITAS EPS Y MINISTERIO DE LA PROTECCION SOCIAL- MI VACUNA-
# FAMISSANAR EPS Y OTRO
# MINISTERIO DE SALUD Y PROTECCION SOCIAL- COOMEVA EPS Y OTROS
# EPS SURA Y CLINICA SAMEIN SA
# CAPITAL SALUD EPSS SAS Y SUBRED INTEGRADA DE SERVICIOS DE SALUD CENTRO ORIENTE ESE
# CAJACOP EPS.
# SURA  EPS SA, SURAMERICANANA SA
# COMPENSAR EPS | FONDO DE PENSIONES COLPENSIONES
# SANITAS EPS - COFIN
# CLINICA GENERAL DEL CARIBE , NUEVA EPS CARTAGENA
# EPS SURAMERICANA SAS
# DAR AYUDA TEMPORAL Y NUEVA EPS
# NUEVA EPS Y ESE HOSPITAL HORACIO MUNOZ SUESCUN SOPETRAN
# SANITAS EPS Y HOSPITAL INTERNACIONAL DE COLOMBIA HIC
# EPS ASOCIACIÃN INDIGENA DEL CAUCA AIC
# SERVICIO OCCIDENTAL DE SALUD EPS SOS Y SURA ARL
# ALCALDIA DE ZONA BANANERA , COOSALUD EPS
# MEDIMAS EPS Y SALUD TOTAL EPS
# SALUD TOTAL EPS | CLINICA ANTIOQUIA
# EPS MEDICINA PREPAGADA SURAMERICANA S.A
# CAJACOPI EPSS  Y OTROS
# SALUD TOTAL EPS Y OTRA
# EPS DIRECCION DE SANIDAD POLICIA NACIONAL
# CLINICA LOS NOGALES EPS S Y OTRO
# ALCANOS DE COLOMBIA S.A  EPS
# SANITAS EPS  OCCIDENTAL CLINICA ODONTOLOGICA SAS
# EPS RED SALUD ARMENIA
# SURA EPSC
# INSTITUTO NACIONAL DE SALUD | COOSALUD EPS Y OTROS
# ADMINISTRADORA COLOMBIANA DE PENSIONES COLPENSIONES EPS SANITAS
# NUEVA EPS SA Y COLPENSIONES
# NUEVA EPS - HOSPITAL SAN ANDRES E.S.E.
# COMFENALCOVALLEEPS
# EPS COMPENSAR, POR INTERMEDIO DE SU REPRESENTANTE LEGAL YO QUIEN HAGA SUS VECES
# FONDO DE PENSIONES PORVENIR | EPS FAMISANAR
# EPS NUEVA E,P.S S.A. Y OTROS
# HOSPITAL MARIO CORREA Y ASMET SALUD EPS
# NUEVA EPS  S.A.
# SALUDTOTAL EPS S.A Y OTROS
# FERROCARRILES NACIONALES DE COLOMBIA EPS
# EPS COMFAMILIAR
# EPSS SALUD TOTAL SA
# COLMEDICA S.A EPS Y OTRO
# MUTUAL SER EPS.- MINISTERIO DE SALUD PROTECCION SOCIAL Y LA SECRETARA DE SALUD Y EL INSTITUTO NACIONAL DE VIGILANCIA DE MEDICAMENTOS Y ALIMENTOS INVIMA DE LA CIUDAD DE SINCELEJO.
# EPS COOPSALUD
# AUDIFARMA MUTUAL SER EPS
# NUEVA EPS REGIMEN SUBSIDIADO INTERVENTOR DE LA NUEVA EPS
# HOSPITAL INFANTIL UNIVERSITARIO DE SAN JOSE UNIDAD DE ESTUDIO Y TRATAMIENTO INTEGRAL DE LAS EPILEPSIAS UNIEPILEPSIAS
# EPSCOMPENSAR
# NUEVA EPS NEIVA Y OTROS
# SERVICIO OCCIDENTAL DE SALUD SOS  EPS
# POSITIVA ARL COMPAÃIA DE SEGUROS SA, CARBONES LA BRISA, EPS SURAMERICANA SA, AFP PROTECCION
# COOMEVA EPS, ADRES Y PROMEDAN
# COMFENALCO VALLE EPS IPS Y OTROS
# NUEVA EPS, COOSALUD EPS Y OTROS
# FAMISANAR EPS Y OTRAS
# FAMISANAR EPS  Y LA IPS COLSUBSIDIO
# COOSALUD EPS Y CLINICA ANGIOSUR
# NEUROCENTRO INSTITUTO DE EPILEPSIA Y PARKINSON DEL EJE CAFETERO SA
# ASSBASALUD E.S.E. Y ASMETSALUD EPS-S
# CAJACOPI EPS SAS REGIMEN SUBSIDIADO
# EPS SANITAS S. A. S. Y OTROS
# SURA EPS Y CAJA DE COMPENSACION FAMILIA DE CALDAS
# EPS INDEGENA MALLAMAS Y OTRO
# SALUD TOTAL EPS  SECRETARIA DE SALUD DEPARTAMENTAL , ADRES, SUPERSALUD
# COOMEVA EPS SERVICIOS ESPECIALIZADOS DEL CORAZON S.A
# FAMIASNAR EPS Y OTROS
# EPS SERVICIO OCCIDENTAL DEL SALUD S.O.S
# SERVI SALUD EPS Y OTROS
# SAVIA SALUD EPS REGIMEN SUBSIDIADO DE MEDELLIN
# NUEVA EPS SA Y IPS CLINICA SAN RAFAEL
# SURA MEDICINA PREPAGADA | SURA EPS
# EPS MUTUAL Y OTRO
# SURA EPS, COLFONDOS AFP S.A.
# NUEVA EMPRESA PROMOTORA DE SALUD -NUEVA EPS Y OTROS
# FAMISANAR LTDA EPS Y OTRO
# EPS SANIDAD MILITAR  Y OTRO
# SALUD TOTALEPS Y OTROS
# NUEVA E.P.S. Y COOSALUD EPS
# SOS EPS SA
# EPS SURA | SECRETARIA DE SALUD VALLE DEL CAUCA
# CAJACOPI  EPS Y OTRO
# SERVICIO OCCIDENTAL DE SALUD SOS - EPS
# EMDISALUD EPS ESS
# AGENTE LIQUIDADOR DE MEDIMAS EPS
# CAPRESOCA EPS OTROS
# SAVIA SALUD EPS REGIMEN SUBSIDIADO  Y OTROS
# AVANZAR EPS Y OTROS
# MINISTERIO DE DEFENSA, EPS SANIDAD DE POLICIA NACIONAL
# ENTIDAD ADMINISTRADORA DE PLANES DE BENEFICIO DE SALUD EAPB Y NUEVA EPS
# SAVIA SALUD EPS. Y OTROS
# SANITAS EPS S.A.S Y OTRO
# ADMINISTRADORA COLOMBIANA DE PENSIONES, NUEVA EPS Y OTROS
# COOSALUD EPS Y MAVEPHARMA
# SALUD TOTAL EPS A OTROS
# FAMISANAR EPS Y MCM COMPANY SAS
# EPS SERVICIO OOCIDENTAL DE SALUD
# COOMEVA EPS Y  EPS COOMEVA EN LIQUIDACION.-
# SANITAS EPS Y EFICIENCIA Y SERVICIOS S.A.
# SURA EPS - ARL
# SURAMERICANA EPS.
# EPS ASOCIACION INDIGENA DEL CAUCA AIC-EPS- Y OTROS
# ARL POSITIVA - EPS SURA
# FAMISANAR EPS Y A SECRETARÃA DE SALUD DEPARTAMENTAL DEL CESAR
# SANITAS  EPS AUDIFARMA Y OTROS
# EPS SANIDAD POLICIAL
# SERVICIO OCCIDENTAL DE SALU S..O.S. EPS
# SALUD TOTAL EPS Y  HEALTH AND LIFE IPS
# FAMISANAR EPS | MINISTERIO DE SALUD | COLSUBSIDIO IPS
# OCCIDENTAL DE SALUD EPS
# NUEVA EPS Y DISCOLMEDICA SAS
# EPS COOMEVA SA
# POSITIVA COMPANIA DE SEGUROS SA ASMET SALUD EPS
# EPS ASOCIACION MUTUAL BARRIOS UNIDOS DE QUIBDO ESS AMBUQ
# SURA  EPS ADRES
# AUDIFARMA SA EPS SALUD TOTAL
# COMPEENSAR EPS
# ASMED SALUD EPS SAS

# %%
display(df_eps.head())
# Out:
#   codigo_Eps                  Nombre_Eps       regimen  total_tutelas
# 0     ESSC24       COOSALUD EPS S.A. -CM  Contributivo              1
# 1     EPS037              NUEVA EPS S.A.  Contributivo           3907
# 2     EPS017        EPS FAMISANAR S.A.S.  Contributivo            212
# 3     ESSC62  ASMET SALUD EPS S.A.S. -CM  Contributivo              0
# 4     EPS042           COOSALUD EPS S.A.  Contributivo            320

# %% [markdown]
# #6.4 Eliminar variaciones a los nombres de las Eps

# %%
# 1. Función para construir una columna con un nombre más corto en cada EPS
def acortar_nombre_eps (df_eps, columna_nombre_eps):
    # Import the regular expression module
    import re
    # Creamos una lista de palabras a eliminar
    palabras_a_eliminar = ['SAS','SA','CM','EPS','REGIMEN','RÉGIMEN','CONTRIBUTIVO','SUBSIDIADO','CAJA','DE','COMPENSACION','COMPENSACIÓN','FAMILIAR',
                        'DEL','DE','Y','ENTIDAD','PROMOTORA','SALUD','ASOCIACION','ASOCIACIÓN','EMPRESA','SOLIDARIA']

    # Creamos una nueva columna 'nombre_corto'y le copiamos los nombres originales
    df_eps['Nombre_Corto'] = df_eps[columna_nombre_eps]

    # Eliminamos símbolos (.-) de la columna
    df_eps['Nombre_Corto'] = df_eps['Nombre_Corto'].str.replace(r'[^\w\s]', '', regex=True)

    # Iteramos sobre la lista palabras_a_eliminar y las quitamos en la columna Nombre_Corto
    for palabra in palabras_a_eliminar:
        # Usamos una expresión regular con \b para buscar la palabra completa
        patron = r'\b' + re.escape(palabra) + r'\b'

        # Eliminamos en la columna las palabras de la lista. re.IGNORECASE para no distinguir entre mayúsculas y minúsculas
        df_eps['Nombre_Corto'] = df_eps['Nombre_Corto'].str.replace(patron, '', regex=True, flags=re.IGNORECASE)

    # Eliminar espacios extra
    df_eps['Nombre_Corto'] = df_eps['Nombre_Corto'].str.strip().str.replace(r'\s+', ' ', regex=True)

    # Devolvemos el dataframe con la nueva columna
    return df_eps

# %%
df_eps_mejorado=acortar_nombre_eps(df_eps,'Nombre_Eps')
df_eps_mejorado = df_eps_mejorado.drop("Nombre_Eps", axis=1)

# %%
display(df_eps_mejorado.head())
# Out:
#   codigo_Eps       regimen  total_tutelas Nombre_Corto
# 0     ESSC24  Contributivo              1     COOSALUD
# 1     EPS037  Contributivo           3907        NUEVA
# 2     EPS017  Contributivo            212    FAMISANAR
# 3     ESSC62  Contributivo              0        ASMET
# 4     EPS042  Contributivo            320     COOSALUD
